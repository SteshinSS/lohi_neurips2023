# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
import chemprop

# %%
import sys
sys.path.append('../../../../code')

from metrics import get_hi_metrics

def chemprop_prepare_df(original_data):
    result = pd.DataFrame({
        'smiles': original_data['smiles'],
        'targets': original_data['value'].astype(float)
    })
    return result

def chemprop_process_folder(input_path, output_path):
    files = ['train_1.csv', 'train_2.csv', 'train_3.csv', 'test_1.csv', 'test_2.csv', 'test_3.csv']
    for file in files:
        input_data = pd.read_csv(input_path + file)
        output_data = chemprop_prepare_df(input_data)
        output_data.to_csv(output_path + file, index=False)
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_geometric'
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (/home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/deepchem/models/torch_models/__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'pytorch_lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'

# %%
train = pd.read_csv('../../../../data/hi/sol/train_1.csv')
test = pd.read_csv('../../../../data/hi/sol/test_1.csv')

train
# Out:
#       Unnamed: 0                                             smiles  value
# 0           2089                O=C(CN1C(=O)CCC1=O)Nc1ccc(F)c(F)c1F  False
# 1           2099       COc1ccc(-c2nnc(NC(=O)c3ccc4ccccc4c3)o2)cc1OC   True
# 2             61            O=C(Nc1ccc2ccccc2n1)c1ccc(N2CCOC2=O)cc1   True
# 3             89     Cc1c[nH]c(=O)n1-c1ccc(C(=O)Nc2ccc3ccccc3n2)cc1   True
# 4             97             O=C(C1CCC(O)CC1)N1CCCN(c2ccc(F)cc2)CC1  False
# ...          ...                                                ...    ...
# 1437        2143                            N#CCCn1nc(C(F)(F)F)cc1O  False
# 1438        2147       Cc1ccccc1N1C(=O)c2ccc(C(=O)NC(C)(C)C)cc2C1=O  False
# 1439        2160                    CC(C)(C)C(=O)Nc1sc2c(c1C#N)CCC2   True
# 1440        2165  C[C@@H](c1ccc(F)cc1)n1nnc2cnc3ccc(-c4ccc5ocnc5...   True
# 1441        2169                         CCc1noc(COc2c(C)ccnc2Cl)n1  False
#
# [1442 rows x 3 columns]

# %%
import os
import os
import shutil

temp_datapath = '/tmp/chemprop/'
if os.path.exists(temp_datapath) and os.path.isdir(temp_datapath):
    shutil.rmtree(temp_datapath)
os.mkdir(temp_datapath)

input_paths = [
    '/home/simon/papers/lohi/data/hi/sol/'
]

output_paths = [
    temp_datapath
]

for i in range(len(input_paths)):
    chemprop_process_folder(input_paths[i], output_paths[i])

# %%
base_arguments = [
    '--dataset_type', 'classification', 
    '--data_path', temp_datapath + 'train_1.csv',
    '--separate_val_path', temp_datapath + 'test_1.csv',
    '--separate_test_path', temp_datapath + 'test_1.csv',
    '--save_preds',
    '--metric', 'prc-auc',
    '--epochs', '100',
    '--gpu', '0',
    '--save_dir', temp_datapath + 'checkpoint',
    '--features_generator', 'rdkit_2d_normalized',
    '--no_features_scaling'
]

# %%
param_dict = {
    '--depth': ['3', '4', '5', '6'],
    '--dropout': ['0.0', '0.2', '0.3', '0.5', '0.7'],
    '--ffn_hidden_size': ['600', '1200', '2400', '3600'],
    '--ffn_num_layers': ['1', '2', '3'],
    '--hidden_size': ['600', '1200', '2400', '3600']
}

# %%
from copy import copy
from tqdm import tqdm
from sklearn.model_selection import ParameterSampler

hyperparam_list = list(ParameterSampler(param_dict, n_iter=20))

best_score = 0.0
best_hyperparams = None

for i, hyperparam in tqdm(enumerate(hyperparam_list)):
    print('HYPERPARAMETER', i)
    print(hyperparam)
    result_arguments = copy(base_arguments)
    for key, value in hyperparam.items():
        result_arguments.append(key)
        result_arguments.append(value)
    # Train
    args = chemprop.args.TrainArgs().parse_args(result_arguments)
    mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)

    test_preds = pd.read_csv(temp_datapath + 'checkpoint/test_preds.csv')
    metrics = get_hi_metrics(test, test_preds['targets'].to_list())

    score = metrics['prc_auc']
    if score > best_score:
        print('New best PRC AUC:', score)
        best_score = score
        best_hyperparams = hyperparam
# Out:
# 0it [00:00, ?it/s]Command line
# python /home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/ipykernel_launcher.py --ip=127.0.0.1 --stdin=9003 --control=9001 --hb=9000 --Session.signature_scheme="hmac-sha256" --Session.key=b"0fbbc264-b232-4363-ab26-cbd03fc47663" --shell=9002 --transport="tcp" --iopub=9004 --f=/home/simon/.local/share/jupyter/runtime/kernel-v2-283513zdsaee6PI6kh.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': True,
#  'data_path': '/tmp/chemprop/train_1.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cuda', index=0),
#  'dropout': 0.2,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 100,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': ['rdkit_2d_normalized'],
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': False,
#  'features_size': None,
#  'ffn_hidden_size': 3600,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': 0,
#  'grad_clip': None,
#  'hidden_size': 600,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'prc-auc',
#  'metrics': ['prc-auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': True,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': '/tmp/chemprop/checkpoint',
#  'save_preds': True,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': '/tmp/chemprop/test_1.csv',
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': '/tmp/chemprop/test_1.csv',
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [1.0, 0.0, 0.0],
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['targets'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': True,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# HYPERPARAMETER 0
# {'--hidden_size': '600', '--ffn_num_layers': '2', '--ffn_hidden_size': '3600', '--dropout': '0.2', '--depth': '3'}
# 1442it [00:00, 322621.56it/s]
# 100%|██████████| 1442/1442 [00:33<00:00, 43.44it/s]
# 100%|██████████| 1442/1442 [00:00<00:00, 264366.92it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# 721it [00:00, 439165.43it/s]
# 100%|██████████| 721/721 [00:16<00:00, 44.90it/s]
# 100%|██████████| 721/721 [00:00<00:00, 257918.40it/s]
# 721it [00:00, 471042.55it/s]
# 100%|██████████| 721/721 [00:15<00:00, 45.54it/s]
# 100%|██████████| 721/721 [00:00<00:00, 268164.69it/s]
# Class sizes
# targets 0: 78.64%, 1: 21.36%
# Total size = 1,442 | train size = 1,442 | val size = 721 | test size = 721
# Building model 0
# MoleculeModel(
#   (sigmoid): Sigmoid()
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout): Dropout(p=0.2, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=600, bias=False)
#         (W_h): Linear(in_features=600, out_features=600, bias=False)
#         (W_o): Linear(in_features=733, out_features=600, bias=True)
#       )
#     )
#   )
#   (readout): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=800, out_features=3600, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=3600, out_features=1, bias=True)
#   )
# )
# Number of parameters = 3,776,401
# Moving model to cuda
# Epoch 0
#
#
#
#
#
# Loss = 5.2747e-01, PNorm = 52.9679, GNorm = 2.5542, lr_0 = 2.7679e-04
#
#
#
#
# Loss = 4.7335e-01, PNorm = 53.0028, GNorm = 0.5907, lr_0 = 4.3750e-04
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.530441
# Epoch 1
#
# Loss = 4.7021e-01, PNorm = 53.0571, GNorm = 1.5221, lr_0 = 6.1429e-04
#
#
# Loss = 4.0958e-01, PNorm = 53.1241, GNorm = 0.4666, lr_0 = 7.7500e-04
#
#
# Loss = 4.0252e-01, PNorm = 53.2087, GNorm = 1.0990, lr_0 = 9.3571e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.523238
# Epoch 2
#
# Loss = 3.8303e-01, PNorm = 53.3007, GNorm = 0.6536, lr_0 = 9.9498e-04
#
#
# Loss = 4.0596e-01, PNorm = 53.4076, GNorm = 1.7657, lr_0 = 9.8666e-04
#
#
# Loss = 4.0557e-01, PNorm = 53.4956, GNorm = 0.7098, lr_0 = 9.7842e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.550983
# Epoch 3
#
# Loss = 4.0376e-01, PNorm = 53.5756, GNorm = 1.1706, lr_0 = 9.7024e-04
#
#
# Loss = 3.8957e-01, PNorm = 53.6550, GNorm = 0.4783, lr_0 = 9.6214e-04
#
#
# Loss = 3.9769e-01, PNorm = 53.7267, GNorm = 1.1209, lr_0 = 9.5410e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.580516
# Epoch 4
#
#
# Loss = 3.8255e-01, PNorm = 53.8047, GNorm = 0.7677, lr_0 = 9.4612e-04
#
#
# Loss = 4.1182e-01, PNorm = 53.8659, GNorm = 0.7592, lr_0 = 9.3822e-04
#
#
# Loss = 3.8368e-01, PNorm = 53.9356, GNorm = 1.1380, lr_0 = 9.3038e-04
#
#
#
#
#
#
# Validation prc-auc = 0.571170
# Epoch 5
#
#
# Loss = 3.8428e-01, PNorm = 54.0134, GNorm = 1.1548, lr_0 = 9.2260e-04
#
#
# Loss = 3.7922e-01, PNorm = 54.0880, GNorm = 2.0245, lr_0 = 9.1489e-04
#
#
# Loss = 4.0078e-01, PNorm = 54.1643, GNorm = 0.4558, lr_0 = 9.0725e-04
#
#
#
#
#
# Validation prc-auc = 0.571084
# Epoch 6
#
#
# Loss = 3.7464e-01, PNorm = 54.2530, GNorm = 0.4709, lr_0 = 8.9967e-04
#
#
# Loss = 3.4851e-01, PNorm = 54.3309, GNorm = 0.5929, lr_0 = 8.9215e-04
#
#
# Loss = 3.6230e-01, PNorm = 54.4010, GNorm = 1.1900, lr_0 = 8.8469e-04
#
#
#
#
#
#
# Validation prc-auc = 0.582528
# Epoch 7
#
#
# Loss = 3.7292e-01, PNorm = 54.4823, GNorm = 0.3597, lr_0 = 8.7657e-04
#
#
# Loss = 3.8154e-01, PNorm = 54.5563, GNorm = 0.4390, lr_0 = 8.6924e-04
#
#
# Loss = 3.4414e-01, PNorm = 54.6202, GNorm = 0.9740, lr_0 = 8.6198e-04
#
#
#
#
#
# Validation prc-auc = 0.585257
# Epoch 8
#
#
# Loss = 3.4475e-01, PNorm = 54.7146, GNorm = 1.1707, lr_0 = 8.5477e-04
#
#
# Loss = 3.8820e-01, PNorm = 54.8097, GNorm = 0.6227, lr_0 = 8.4763e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.595066
# Epoch 9
#
# Loss = 2.4948e-01, PNorm = 54.9169, GNorm = 0.3236, lr_0 = 8.4055e-04
#
#
# Loss = 3.5197e-01, PNorm = 55.0293, GNorm = 0.8311, lr_0 = 8.3352e-04
#
#
# Loss = 3.4943e-01, PNorm = 55.1245, GNorm = 0.4400, lr_0 = 8.2656e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.595465
# Epoch 10
#
# Loss = 2.8643e-01, PNorm = 55.2203, GNorm = 1.2083, lr_0 = 8.1965e-04
#
#
# Loss = 3.2951e-01, PNorm = 55.3470, GNorm = 0.4662, lr_0 = 8.1280e-04
#
#
#
# Loss = 3.4631e-01, PNorm = 55.4836, GNorm = 0.4996, lr_0 = 8.0601e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.599197
# Epoch 11
#
# Loss = 3.5689e-01, PNorm = 55.5584, GNorm = 0.8766, lr_0 = 7.9928e-04
#
#
#
# Loss = 3.3054e-01, PNorm = 55.6743, GNorm = 0.4020, lr_0 = 7.9260e-04
#
#
# Loss = 3.3600e-01, PNorm = 55.7761, GNorm = 1.6758, lr_0 = 7.8597e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.611674
# Epoch 12
#
# Loss = 3.2993e-01, PNorm = 55.8999, GNorm = 0.7035, lr_0 = 7.7941e-04
#
#
#
# Loss = 3.3881e-01, PNorm = 56.0271, GNorm = 1.5196, lr_0 = 7.7289e-04
#
#
# Loss = 3.3362e-01, PNorm = 56.1622, GNorm = 0.5566, lr_0 = 7.6643e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.611916
# Epoch 13
#
#
# Loss = 2.9594e-01, PNorm = 56.3128, GNorm = 0.4456, lr_0 = 7.5939e-04
#
#
# Loss = 2.9100e-01, PNorm = 56.4288, GNorm = 0.4470, lr_0 = 7.5305e-04
#
#
#
# Loss = 3.1428e-01, PNorm = 56.5716, GNorm = 0.6640, lr_0 = 7.4675e-04
#
#
#
#
#
#
# Validation prc-auc = 0.645761
# Epoch 14
#
#
# Loss = 3.0920e-01, PNorm = 56.7367, GNorm = 1.1763, lr_0 = 7.4051e-04
#
#
# Loss = 3.1794e-01, PNorm = 56.8810, GNorm = 1.6114, lr_0 = 7.3433e-04
#
#
#
# Loss = 3.0447e-01, PNorm = 57.0009, GNorm = 0.5622, lr_0 = 7.2819e-04
#
#
#
#
#
# Validation prc-auc = 0.620978
# Epoch 15
#
#
# Loss = 3.4011e-01, PNorm = 57.1336, GNorm = 1.6816, lr_0 = 7.2211e-04
#
#
#
# Loss = 2.8971e-01, PNorm = 57.2861, GNorm = 0.7974, lr_0 = 7.1607e-04
#
#
# Loss = 2.7643e-01, PNorm = 57.4034, GNorm = 0.9125, lr_0 = 7.1009e-04
#
#
#
#
#
#
# Validation prc-auc = 0.650791
# Epoch 16
#
#
#
# Loss = 3.0898e-01, PNorm = 57.5178, GNorm = 1.1705, lr_0 = 7.0415e-04
#
#
# Loss = 2.9539e-01, PNorm = 57.6819, GNorm = 0.5872, lr_0 = 6.9827e-04
#
#
# Loss = 3.1519e-01, PNorm = 57.8381, GNorm = 0.5833, lr_0 = 6.9243e-04
#
#
#
#
#
# Validation prc-auc = 0.637134
# Epoch 17
#
#
# Loss = 2.5800e-01, PNorm = 57.9804, GNorm = 0.7668, lr_0 = 6.8665e-04
#
#
# Loss = 2.7231e-01, PNorm = 58.1070, GNorm = 0.8330, lr_0 = 6.8091e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.621603
# Epoch 18
#
# Loss = 3.0518e-01, PNorm = 58.2564, GNorm = 0.8514, lr_0 = 6.7522e-04
#
#
# Loss = 2.6919e-01, PNorm = 58.3880, GNorm = 1.0015, lr_0 = 6.6958e-04
#
#
# Loss = 2.5319e-01, PNorm = 58.5140, GNorm = 0.6923, lr_0 = 6.6398e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.626981
# Epoch 19
#
# Loss = 2.1240e-01, PNorm = 58.6852, GNorm = 0.7011, lr_0 = 6.5788e-04
#
#
# Loss = 2.0921e-01, PNorm = 58.8103, GNorm = 0.8014, lr_0 = 6.5239e-04
#
#
#
# Loss = 2.9264e-01, PNorm = 58.9575, GNorm = 0.8454, lr_0 = 6.4693e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.658808
# Epoch 20
#
# Loss = 2.5276e-01, PNorm = 59.0725, GNorm = 1.2459, lr_0 = 6.4153e-04
#
#
#
# Loss = 2.6741e-01, PNorm = 59.2014, GNorm = 0.6165, lr_0 = 6.3617e-04
#
#
# Loss = 2.2291e-01, PNorm = 59.3424, GNorm = 0.5889, lr_0 = 6.3085e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.643760
# Epoch 21
#
# Loss = 2.7806e-01, PNorm = 59.4561, GNorm = 1.8388, lr_0 = 6.2558e-04
#
#
# Loss = 2.4320e-01, PNorm = 59.5753, GNorm = 0.4697, lr_0 = 6.2035e-04
#
#
# Loss = 2.4209e-01, PNorm = 59.7171, GNorm = 0.7741, lr_0 = 6.1517e-04
#
#
#
#
#
#
# Validation prc-auc = 0.637011
# Epoch 22
#
#
# Loss = 1.9758e-01, PNorm = 59.8697, GNorm = 0.9955, lr_0 = 6.1003e-04
#
#
# Loss = 2.0037e-01, PNorm = 60.0318, GNorm = 0.6673, lr_0 = 6.0493e-04
#
#
# Loss = 2.5600e-01, PNorm = 60.1270, GNorm = 0.9732, lr_0 = 5.9988e-04
#
#
#
#
#
#
# Validation prc-auc = 0.652961
# Epoch 23
#
#
# Loss = 2.2458e-01, PNorm = 60.2463, GNorm = 1.4706, lr_0 = 5.9486e-04
#
#
#
# Loss = 1.9224e-01, PNorm = 60.3875, GNorm = 0.4793, lr_0 = 5.8989e-04
#
#
# Loss = 2.2070e-01, PNorm = 60.5259, GNorm = 0.8465, lr_0 = 5.8496e-04
#
#
#
#
#
# Validation prc-auc = 0.630311
# Epoch 24
#
#
# Loss = 2.1336e-01, PNorm = 60.6355, GNorm = 1.6444, lr_0 = 5.8007e-04
#
#
# Loss = 2.3595e-01, PNorm = 60.7336, GNorm = 1.5975, lr_0 = 5.7523e-04
#
#
# Loss = 2.4013e-01, PNorm = 60.8678, GNorm = 1.1293, lr_0 = 5.7042e-04
#
#
#
#
#
# Validation prc-auc = 0.628805
# Epoch 25
#
#
# Loss = 2.0150e-01, PNorm = 61.0156, GNorm = 0.8252, lr_0 = 5.6565e-04
#
#
# Loss = 1.7862e-01, PNorm = 61.1372, GNorm = 0.6273, lr_0 = 5.6093e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.625715
# Epoch 26
#
# Loss = 3.4171e-01, PNorm = 61.2781, GNorm = 1.3539, lr_0 = 5.5577e-04
#
#
# Loss = 1.7872e-01, PNorm = 61.3836, GNorm = 1.1532, lr_0 = 5.5113e-04
#
#
# Loss = 1.6556e-01, PNorm = 61.4984, GNorm = 0.7921, lr_0 = 5.4652e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.653683
# Epoch 27
#
# Loss = 1.6623e-01, PNorm = 61.6043, GNorm = 0.6411, lr_0 = 5.4196e-04
#
#
# Loss = 1.5002e-01, PNorm = 61.7190, GNorm = 0.9072, lr_0 = 5.3743e-04
#
#
# Loss = 2.0336e-01, PNorm = 61.8334, GNorm = 0.9383, lr_0 = 5.3294e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.647631
# Epoch 28
#
# Loss = 1.8681e-01, PNorm = 61.9411, GNorm = 0.8068, lr_0 = 5.2848e-04
#
#
# Loss = 1.9039e-01, PNorm = 62.0499, GNorm = 0.5366, lr_0 = 5.2407e-04
#
#
# Loss = 1.4417e-01, PNorm = 62.1399, GNorm = 0.8023, lr_0 = 5.1969e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.643873
# Epoch 29
#
# Loss = 1.5419e-01, PNorm = 62.2570, GNorm = 0.4427, lr_0 = 5.1535e-04
#
#
#
# Loss = 1.6472e-01, PNorm = 62.3963, GNorm = 0.5898, lr_0 = 5.1104e-04
#
#
# Loss = 1.8410e-01, PNorm = 62.4931, GNorm = 1.2306, lr_0 = 5.0677e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.646260
# Epoch 30
#
# Loss = 1.6004e-01, PNorm = 62.6055, GNorm = 0.9649, lr_0 = 5.0253e-04
#
#
# Loss = 1.4723e-01, PNorm = 62.7200, GNorm = 0.7465, lr_0 = 4.9834e-04
#
#
#
# Loss = 1.5385e-01, PNorm = 62.8248, GNorm = 0.6221, lr_0 = 4.9417e-04
#
#
#
#
#
#
# Validation prc-auc = 0.640023
# Epoch 31
#
#
# Loss = 1.2491e-01, PNorm = 62.9350, GNorm = 1.1424, lr_0 = 4.9004e-04
#
#
# Loss = 1.5526e-01, PNorm = 63.0185, GNorm = 0.7916, lr_0 = 4.8595e-04
#
#
# Loss = 1.2809e-01, PNorm = 63.1080, GNorm = 1.3374, lr_0 = 4.8189e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.631682
# Epoch 32
#
#
# Loss = 1.3734e-01, PNorm = 63.2135, GNorm = 0.8140, lr_0 = 4.7746e-04
#
#
# Loss = 1.2873e-01, PNorm = 63.3156, GNorm = 1.1115, lr_0 = 4.7347e-04
#
#
# Loss = 1.6391e-01, PNorm = 63.4208, GNorm = 1.1372, lr_0 = 4.6951e-04
#
#
#
#
#
# Validation prc-auc = 0.622188
# Epoch 33
#
#
# Loss = 1.4702e-01, PNorm = 63.5365, GNorm = 1.5495, lr_0 = 4.6559e-04
#
#
# Loss = 1.1302e-01, PNorm = 63.6538, GNorm = 1.1591, lr_0 = 4.6170e-04
#
#
# Loss = 1.4628e-01, PNorm = 63.7354, GNorm = 0.4923, lr_0 = 4.5784e-04
#
#
#
#
#
#
# Validation prc-auc = 0.596870
# Epoch 34
#
#
# Loss = 1.4279e-01, PNorm = 63.8290, GNorm = 1.1964, lr_0 = 4.5401e-04
#
#
#
# Loss = 1.4661e-01, PNorm = 63.9269, GNorm = 0.6755, lr_0 = 4.5022e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.620359
# Epoch 35
#
# Loss = 6.0711e-02, PNorm = 64.0270, GNorm = 0.4539, lr_0 = 4.4646e-04
#
#
# Loss = 1.3325e-01, PNorm = 64.1001, GNorm = 0.8963, lr_0 = 4.4273e-04
#
#
# Loss = 1.0941e-01, PNorm = 64.1981, GNorm = 0.7780, lr_0 = 4.3903e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.620475
# Epoch 36
#
# Loss = 6.7485e-02, PNorm = 64.2907, GNorm = 0.6406, lr_0 = 4.3536e-04
#
#
# Loss = 8.5872e-02, PNorm = 64.3818, GNorm = 0.7888, lr_0 = 4.3172e-04
#
#
#
# Loss = 1.5126e-01, PNorm = 64.4469, GNorm = 0.9679, lr_0 = 4.2811e-04
#
#
#
#
#
#
# Validation prc-auc = 0.622827
# Epoch 37
#
# Loss = 9.8053e-02, PNorm = 64.5292, GNorm = 1.0560, lr_0 = 4.2454e-04
#
#
# Loss = 8.2856e-02, PNorm = 64.6109, GNorm = 0.5762, lr_0 = 4.2099e-04
#
#
#
# Loss = 1.2480e-01, PNorm = 64.7062, GNorm = 0.7234, lr_0 = 4.1747e-04
#
#
#
#
#
#
# Validation prc-auc = 0.629264
# Epoch 38
#
# Loss = 1.0417e-01, PNorm = 64.7963, GNorm = 0.9995, lr_0 = 4.1364e-04
#
#
# Loss = 9.6984e-02, PNorm = 64.8930, GNorm = 0.6123, lr_0 = 4.1018e-04
#
#
# Loss = 1.1994e-01, PNorm = 64.9648, GNorm = 1.0540, lr_0 = 4.0675e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.626608
# Epoch 39
#
#
# Loss = 8.0253e-02, PNorm = 65.0425, GNorm = 0.7565, lr_0 = 4.0335e-04
#
#
# Loss = 1.0934e-01, PNorm = 65.1285, GNorm = 0.5285, lr_0 = 3.9998e-04
#
#
#
# Loss = 1.1228e-01, PNorm = 65.2219, GNorm = 0.7965, lr_0 = 3.9664e-04
#
#
#
#
#
#
# Validation prc-auc = 0.601381
# Epoch 40
#
#
# Loss = 1.2509e-01, PNorm = 65.2996, GNorm = 0.9950, lr_0 = 3.9333e-04
#
#
# Loss = 1.0018e-01, PNorm = 65.3719, GNorm = 1.0198, lr_0 = 3.9004e-04
#
#
# Loss = 1.2168e-01, PNorm = 65.4653, GNorm = 0.7256, lr_0 = 3.8678e-04
#
#
#
#
#
# Validation prc-auc = 0.623113
# Epoch 41
#
#
# Loss = 9.2289e-02, PNorm = 65.5391, GNorm = 0.6282, lr_0 = 3.8355e-04
#
#
#
# Loss = 8.8480e-02, PNorm = 65.6030, GNorm = 0.4316, lr_0 = 3.8034e-04
#
#
# Loss = 8.8333e-02, PNorm = 65.6656, GNorm = 0.9284, lr_0 = 3.7716e-04
#
#
#
#
#
# Validation prc-auc = 0.617327
# Epoch 42
#
#
# Loss = 6.7107e-02, PNorm = 65.7452, GNorm = 0.5685, lr_0 = 3.7401e-04
#
#
# Loss = 8.9938e-02, PNorm = 65.8336, GNorm = 1.3911, lr_0 = 3.7089e-04
#
#
# Loss = 1.1455e-01, PNorm = 65.8856, GNorm = 1.1266, lr_0 = 3.6779e-04
#
#
#
#
#
# Validation prc-auc = 0.600519
# Epoch 43
#
#
# Loss = 9.7792e-02, PNorm = 65.9420, GNorm = 0.7329, lr_0 = 3.6471e-04
#
#
# Loss = 1.0085e-01, PNorm = 65.9956, GNorm = 1.3030, lr_0 = 3.6167e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.610407
# Epoch 44
#
# Loss = 6.7920e-02, PNorm = 66.0734, GNorm = 1.0134, lr_0 = 3.5834e-04
#
#
# Loss = 8.9380e-02, PNorm = 66.1833, GNorm = 0.6818, lr_0 = 3.5535e-04
#
#
# Loss = 9.8224e-02, PNorm = 66.2473, GNorm = 0.7848, lr_0 = 3.5238e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.595208
# Epoch 45
#
# Loss = 6.0412e-02, PNorm = 66.3020, GNorm = 0.9969, lr_0 = 3.4944e-04
#
#
# Loss = 7.9252e-02, PNorm = 66.3721, GNorm = 0.8311, lr_0 = 3.4652e-04
#
#
# Loss = 9.4985e-02, PNorm = 66.4578, GNorm = 0.7761, lr_0 = 3.4362e-04
#
#
#
#
#
#
# Validation prc-auc = 0.595194
# Epoch 46
#
# Loss = 7.8331e-02, PNorm = 66.5072, GNorm = 0.7020, lr_0 = 3.4075e-04
#
#
# Loss = 6.3930e-02, PNorm = 66.5677, GNorm = 0.5612, lr_0 = 3.3790e-04
#
#
# Loss = 6.7750e-02, PNorm = 66.6472, GNorm = 0.8673, lr_0 = 3.3508e-04
#
#
#
#
#
#
# Validation prc-auc = 0.595393
# Epoch 47
#
# Loss = 7.6321e-02, PNorm = 66.6910, GNorm = 1.1298, lr_0 = 3.3228e-04
#
#
# Loss = 6.6072e-02, PNorm = 66.7414, GNorm = 1.3308, lr_0 = 3.2950e-04
#
#
# Loss = 8.1740e-02, PNorm = 66.7996, GNorm = 0.7402, lr_0 = 3.2675e-04
#
#
#
#
#
#
# Validation prc-auc = 0.597609
# Epoch 48
#
#
# Loss = 6.9258e-02, PNorm = 66.8773, GNorm = 1.3546, lr_0 = 3.2402e-04
#
#
# Loss = 5.8418e-02, PNorm = 66.9282, GNorm = 0.2675, lr_0 = 3.2131e-04
#
#
# Loss = 7.5114e-02, PNorm = 66.9794, GNorm = 0.4835, lr_0 = 3.1863e-04
#
#
#
#
#
#
# Validation prc-auc = 0.609937
# Epoch 49
#
#
# Loss = 5.6087e-02, PNorm = 67.0495, GNorm = 0.4716, lr_0 = 3.1596e-04
#
#
# Loss = 7.0807e-02, PNorm = 67.0892, GNorm = 0.8787, lr_0 = 3.1332e-04
#
#
# Loss = 6.8846e-02, PNorm = 67.1517, GNorm = 1.0158, lr_0 = 3.1070e-04
#
#
#
#
#
#
# Validation prc-auc = 0.590434
# Epoch 50
#
#
# Loss = 5.1381e-02, PNorm = 67.1952, GNorm = 0.8845, lr_0 = 3.0811e-04
#
#
# Loss = 4.4352e-02, PNorm = 67.2460, GNorm = 0.3639, lr_0 = 3.0553e-04
#
#
# Loss = 5.2074e-02, PNorm = 67.3026, GNorm = 0.6185, lr_0 = 3.0298e-04
#
# Loss = 8.8207e-02, PNorm = 67.3059, GNorm = 1.4759, lr_0 = 3.0273e-04
#
#
#
#
#
# Validation prc-auc = 0.602737
# Epoch 51
#
#
# Loss = 5.7221e-02, PNorm = 67.3442, GNorm = 0.9264, lr_0 = 3.0020e-04
#
#
# Loss = 7.1137e-02, PNorm = 67.3857, GNorm = 1.5771, lr_0 = 2.9769e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.613403
# Epoch 52
#
# Loss = 3.9721e-02, PNorm = 67.4375, GNorm = 0.5981, lr_0 = 2.9520e-04
#
#
# Loss = 4.9957e-02, PNorm = 67.5098, GNorm = 1.1385, lr_0 = 2.9273e-04
#
#
# Loss = 6.6390e-02, PNorm = 67.5621, GNorm = 1.2337, lr_0 = 2.9029e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.589442
# Epoch 53
#
# Loss = 6.3947e-02, PNorm = 67.5762, GNorm = 1.5902, lr_0 = 2.8786e-04
#
#
# Loss = 5.6929e-02, PNorm = 67.6444, GNorm = 0.1793, lr_0 = 2.8546e-04
#
#
# Loss = 6.2870e-02, PNorm = 67.6736, GNorm = 1.4471, lr_0 = 2.8307e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.614275
# Epoch 54
#
# Loss = 4.4510e-02, PNorm = 67.7274, GNorm = 0.5049, lr_0 = 2.8071e-04
#
#
# Loss = 4.8259e-02, PNorm = 67.7788, GNorm = 0.4485, lr_0 = 2.7836e-04
#
#
# Loss = 4.4160e-02, PNorm = 67.8433, GNorm = 0.4081, lr_0 = 2.7603e-04
#
#
#
#
#
#
# Validation prc-auc = 0.610938
# Epoch 55
#
# Loss = 6.5524e-02, PNorm = 67.8776, GNorm = 1.3922, lr_0 = 2.7373e-04
#
#
# Loss = 4.8173e-02, PNorm = 67.9241, GNorm = 1.0661, lr_0 = 2.7144e-04
#
#
# Loss = 4.9117e-02, PNorm = 67.9637, GNorm = 0.4820, lr_0 = 2.6917e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.610946
# Epoch 56
#
# Loss = 3.5177e-02, PNorm = 68.0012, GNorm = 0.7010, lr_0 = 2.6692e-04
#
#
# Loss = 4.3813e-02, PNorm = 68.0383, GNorm = 0.3881, lr_0 = 2.6469e-04
#
#
# Loss = 4.5088e-02, PNorm = 68.0803, GNorm = 1.2090, lr_0 = 2.6248e-04
#
#
#
#
#
#
# Validation prc-auc = 0.624919
# Epoch 57
#
#
# Loss = 4.5170e-02, PNorm = 68.1215, GNorm = 0.5040, lr_0 = 2.6007e-04
#
#
# Loss = 5.4463e-02, PNorm = 68.1626, GNorm = 0.6492, lr_0 = 2.5790e-04
#
#
# Loss = 4.4890e-02, PNorm = 68.2029, GNorm = 0.7625, lr_0 = 2.5574e-04
#
#
#
#
#
#
# Validation prc-auc = 0.601804
# Epoch 58
#
#
# Loss = 3.3861e-02, PNorm = 68.2483, GNorm = 0.6206, lr_0 = 2.5360e-04
#
#
# Loss = 3.8976e-02, PNorm = 68.2899, GNorm = 0.9045, lr_0 = 2.5148e-04
#
#
# Loss = 5.0238e-02, PNorm = 68.3258, GNorm = 1.1155, lr_0 = 2.4938e-04
#
#
#
#
#
# Validation prc-auc = 0.601057
# Epoch 59
#
#
# Loss = 4.1252e-02, PNorm = 68.3588, GNorm = 1.6704, lr_0 = 2.4730e-04
#
#
# Loss = 4.0701e-02, PNorm = 68.4098, GNorm = 1.4120, lr_0 = 2.4523e-04
#
#
# Loss = 4.4388e-02, PNorm = 68.4351, GNorm = 0.3107, lr_0 = 2.4318e-04
#
#
#
#
#
# Validation prc-auc = 0.594380
# Epoch 60
#
#
# Loss = 3.0237e-02, PNorm = 68.4721, GNorm = 0.6990, lr_0 = 2.4115e-04
#
#
# Loss = 3.0991e-02, PNorm = 68.5045, GNorm = 0.4983, lr_0 = 2.3914e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.595341
# Epoch 61
#
# Loss = 3.5842e-02, PNorm = 68.5371, GNorm = 1.0676, lr_0 = 2.3714e-04
#
#
# Loss = 4.5413e-02, PNorm = 68.5860, GNorm = 0.8862, lr_0 = 2.3516e-04
#
#
# Loss = 4.0069e-02, PNorm = 68.6163, GNorm = 1.2284, lr_0 = 2.3319e-04
#
#
#
#
#
#
# Validation prc-auc = 0.581129
# Epoch 62
#
# Loss = 2.3523e-02, PNorm = 68.6540, GNorm = 0.6780, lr_0 = 2.3124e-04
#
#
# Loss = 4.8497e-02, PNorm = 68.6812, GNorm = 1.2757, lr_0 = 2.2931e-04
#
#
# Loss = 4.0443e-02, PNorm = 68.7093, GNorm = 0.2680, lr_0 = 2.2739e-04
#
#
#
#
#
#
# Validation prc-auc = 0.604311
# Epoch 63
#
# Loss = 2.8981e-02, PNorm = 68.7545, GNorm = 0.1769, lr_0 = 2.2530e-04
#
#
# Loss = 4.2056e-02, PNorm = 68.7718, GNorm = 0.9089, lr_0 = 2.2342e-04
#
#
# Loss = 2.9646e-02, PNorm = 68.8299, GNorm = 0.0612, lr_0 = 2.2155e-04
#
#
#
#
#
#
# Validation prc-auc = 0.593247
# Epoch 64
#
# Loss = 4.1926e-02, PNorm = 68.8452, GNorm = 0.4812, lr_0 = 2.1970e-04
#
#
# Loss = 3.4804e-02, PNorm = 68.8731, GNorm = 0.1262, lr_0 = 2.1787e-04
#
#
# Loss = 5.3485e-02, PNorm = 68.9189, GNorm = 0.7900, lr_0 = 2.1605e-04
#
#
#
#
#
#
# Validation prc-auc = 0.598952
# Epoch 65
#
#
# Loss = 2.4931e-02, PNorm = 68.9593, GNorm = 0.3586, lr_0 = 2.1424e-04
#
#
# Loss = 4.2392e-02, PNorm = 68.9807, GNorm = 0.5940, lr_0 = 2.1245e-04
#
#
# Loss = 3.8169e-02, PNorm = 69.0229, GNorm = 0.5448, lr_0 = 2.1068e-04
#
#
#
#
#
# Validation prc-auc = 0.595817
# Epoch 66
#
#
# Loss = 3.2703e-02, PNorm = 69.0497, GNorm = 0.4573, lr_0 = 2.0892e-04
#
#
# Loss = 3.0312e-02, PNorm = 69.0722, GNorm = 1.1924, lr_0 = 2.0717e-04
#
#
# Loss = 2.8775e-02, PNorm = 69.0988, GNorm = 0.8516, lr_0 = 2.0544e-04
#
#
#
#
#
# Validation prc-auc = 0.589926
# Epoch 67
#
#
# Loss = 3.5854e-02, PNorm = 69.1275, GNorm = 0.8861, lr_0 = 2.0372e-04
#
#
# Loss = 3.0621e-02, PNorm = 69.1562, GNorm = 0.5896, lr_0 = 2.0202e-04
#
#
# Loss = 2.8800e-02, PNorm = 69.1727, GNorm = 0.4632, lr_0 = 2.0033e-04
#
#
#
#
#
# Validation prc-auc = 0.591044
# Epoch 68
#
#
# Loss = 3.2266e-02, PNorm = 69.2084, GNorm = 0.6715, lr_0 = 1.9866e-04
#
#
# Loss = 3.1317e-02, PNorm = 69.2293, GNorm = 0.8230, lr_0 = 1.9700e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.586510
# Epoch 69
#
# Loss = 3.3166e-02, PNorm = 69.2576, GNorm = 0.6270, lr_0 = 1.9519e-04
#
#
# Loss = 2.8979e-02, PNorm = 69.2837, GNorm = 0.3157, lr_0 = 1.9356e-04
#
#
# Loss = 2.2778e-02, PNorm = 69.3177, GNorm = 0.8964, lr_0 = 1.9194e-04
#
#
#
#
#
#
# Validation prc-auc = 0.589731
# Epoch 70
#
# Loss = 5.0327e-02, PNorm = 69.3498, GNorm = 1.2028, lr_0 = 1.9034e-04
#
#
# Loss = 2.3055e-02, PNorm = 69.3671, GNorm = 0.2870, lr_0 = 1.8874e-04
#
#
# Loss = 2.5152e-02, PNorm = 69.4028, GNorm = 1.8551, lr_0 = 1.8717e-04
#
#
#
#
#
#
# Validation prc-auc = 0.604934
# Epoch 71
#
# Loss = 3.6139e-02, PNorm = 69.4208, GNorm = 0.8728, lr_0 = 1.8560e-04
#
#
# Loss = 2.3072e-02, PNorm = 69.4427, GNorm = 0.5897, lr_0 = 1.8405e-04
#
#
# Loss = 4.4419e-02, PNorm = 69.4723, GNorm = 1.0407, lr_0 = 1.8251e-04
#
#
#
#
#
#
# Validation prc-auc = 0.601869
# Epoch 72
#
# Loss = 1.0370e-02, PNorm = 69.5046, GNorm = 0.2607, lr_0 = 1.8099e-04
#
#
# Loss = 2.9309e-02, PNorm = 69.5196, GNorm = 0.8822, lr_0 = 1.7948e-04
#
#
# Loss = 6.3954e-02, PNorm = 69.5512, GNorm = 1.2660, lr_0 = 1.7798e-04
#
#
#
#
#
#
# Validation prc-auc = 0.613437
# Epoch 73
#
# Loss = 2.9741e-02, PNorm = 69.5591, GNorm = 1.0716, lr_0 = 1.7649e-04
#
#
# Loss = 2.1890e-02, PNorm = 69.5780, GNorm = 0.2889, lr_0 = 1.7502e-04
#
#
# Loss = 3.2640e-02, PNorm = 69.5966, GNorm = 0.5012, lr_0 = 1.7355e-04
#
#
#
#
#
#
# Validation prc-auc = 0.610858
# Epoch 74
#
#
# Loss = 1.4890e-02, PNorm = 69.6383, GNorm = 0.4974, lr_0 = 1.7210e-04
#
#
# Loss = 3.7859e-02, PNorm = 69.6425, GNorm = 0.2376, lr_0 = 1.7066e-04
#
#
# Loss = 4.1012e-02, PNorm = 69.6724, GNorm = 1.1006, lr_0 = 1.6924e-04
#
#
#
#
#
# Validation prc-auc = 0.600932
# Epoch 75
#
#
# Loss = 2.7964e-02, PNorm = 69.6946, GNorm = 0.5928, lr_0 = 1.6782e-04
#
#
# Loss = 2.6070e-02, PNorm = 69.7226, GNorm = 0.6097, lr_0 = 1.6642e-04
#
#
# Loss = 3.5380e-02, PNorm = 69.7319, GNorm = 0.9541, lr_0 = 1.6503e-04
#
#
#
#
#
# Validation prc-auc = 0.585449
# Epoch 76
#
#
# Loss = 1.5836e-02, PNorm = 69.7540, GNorm = 0.0897, lr_0 = 1.6351e-04
#
#
# Loss = 2.1231e-02, PNorm = 69.7732, GNorm = 0.3587, lr_0 = 1.6215e-04
#
#
# Loss = 3.0917e-02, PNorm = 69.7910, GNorm = 2.0314, lr_0 = 1.6079e-04
#
#
#
#
#
# Validation prc-auc = 0.610317
# Epoch 77
#
#
#
# Loss = 3.3826e-02, PNorm = 69.7995, GNorm = 0.3452, lr_0 = 1.5945e-04
#
#
# Loss = 1.8095e-02, PNorm = 69.8158, GNorm = 0.2453, lr_0 = 1.5812e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.603884
# Epoch 78
#
# Loss = 5.6292e-03, PNorm = 69.8425, GNorm = 0.1117, lr_0 = 1.5680e-04
#
#
# Loss = 2.5969e-02, PNorm = 69.8456, GNorm = 1.1590, lr_0 = 1.5549e-04
#
#
# Loss = 3.2068e-02, PNorm = 69.8769, GNorm = 0.8056, lr_0 = 1.5419e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.587079
# Epoch 79
#
# Loss = 2.4010e-02, PNorm = 69.8820, GNorm = 0.9359, lr_0 = 1.5290e-04
#
#
# Loss = 2.0172e-02, PNorm = 69.9068, GNorm = 0.5040, lr_0 = 1.5162e-04
#
#
# Loss = 1.8303e-02, PNorm = 69.9309, GNorm = 0.2106, lr_0 = 1.5035e-04
#
#
#
#
#
#
# Validation prc-auc = 0.605634
# Epoch 80
#
# Loss = 1.8469e-02, PNorm = 69.9380, GNorm = 0.4811, lr_0 = 1.4910e-04
#
#
# Loss = 2.9385e-02, PNorm = 69.9737, GNorm = 0.4098, lr_0 = 1.4785e-04
#
#
# Loss = 1.9287e-02, PNorm = 69.9865, GNorm = 0.2924, lr_0 = 1.4662e-04
#
#
#
#
#
#
# Validation prc-auc = 0.603729
# Epoch 81
#
# Loss = 3.0107e-02, PNorm = 70.0077, GNorm = 0.1175, lr_0 = 1.4539e-04
#
#
# Loss = 2.3634e-02, PNorm = 70.0302, GNorm = 0.7960, lr_0 = 1.4418e-04
#
#
# Loss = 2.2718e-02, PNorm = 70.0406, GNorm = 0.1619, lr_0 = 1.4297e-04
#
#
#
#
#
#
# Validation prc-auc = 0.602264
# Epoch 82
#
#
# Loss = 3.9102e-02, PNorm = 70.0561, GNorm = 0.0239, lr_0 = 1.4166e-04
#
#
# Loss = 1.9433e-02, PNorm = 70.0706, GNorm = 0.7942, lr_0 = 1.4047e-04
#
#
# Loss = 2.9397e-02, PNorm = 70.0917, GNorm = 0.1159, lr_0 = 1.3930e-04
#
#
#
#
#
# Validation prc-auc = 0.594424
# Epoch 83
#
#
# Loss = 3.3252e-02, PNorm = 70.1012, GNorm = 0.9120, lr_0 = 1.3814e-04
#
#
# Loss = 1.0161e-02, PNorm = 70.1118, GNorm = 0.3136, lr_0 = 1.3698e-04
#
#
# Loss = 2.0964e-02, PNorm = 70.1272, GNorm = 0.2874, lr_0 = 1.3584e-04
#
#
#
#
#
# Validation prc-auc = 0.603116
# Epoch 84
#
#
# Loss = 1.9375e-02, PNorm = 70.1429, GNorm = 0.1967, lr_0 = 1.3470e-04
#
#
# Loss = 1.8710e-02, PNorm = 70.1542, GNorm = 0.4115, lr_0 = 1.3358e-04
#
#
# Loss = 2.8613e-02, PNorm = 70.1702, GNorm = 0.0341, lr_0 = 1.3246e-04
#
#
#
#
#
# Validation prc-auc = 0.591153
# Epoch 85
#
#
# Loss = 1.4193e-02, PNorm = 70.1778, GNorm = 0.4472, lr_0 = 1.3135e-04
#
#
# Loss = 1.8293e-02, PNorm = 70.1929, GNorm = 0.5597, lr_0 = 1.3026e-04
#
#
# Loss = 2.4779e-02, PNorm = 70.2092, GNorm = 0.6518, lr_0 = 1.2917e-04
#
#
#
#
#
# Validation prc-auc = 0.594654
# Epoch 86
#
#
# Loss = 3.5806e-02, PNorm = 70.2239, GNorm = 1.7095, lr_0 = 1.2809e-04
#
#
# Loss = 1.7887e-02, PNorm = 70.2434, GNorm = 0.2223, lr_0 = 1.2702e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.579808
# Epoch 87
#
# Loss = 1.2902e-02, PNorm = 70.2602, GNorm = 0.3909, lr_0 = 1.2596e-04
#
#
# Loss = 1.0433e-02, PNorm = 70.2688, GNorm = 0.1310, lr_0 = 1.2490e-04
#
#
# Loss = 1.0144e-02, PNorm = 70.2825, GNorm = 0.5290, lr_0 = 1.2386e-04
#
#
#
#
#
#
# Validation prc-auc = 0.589886
# Epoch 88
#
# Loss = 9.8368e-03, PNorm = 70.2924, GNorm = 0.4386, lr_0 = 1.2272e-04
#
#
# Loss = 1.6037e-02, PNorm = 70.3092, GNorm = 0.4282, lr_0 = 1.2170e-04
#
#
# Loss = 1.3466e-02, PNorm = 70.3166, GNorm = 0.3012, lr_0 = 1.2068e-04
#
#
#
#
#
#
# Validation prc-auc = 0.599092
# Epoch 89
#
# Loss = 2.1852e-02, PNorm = 70.3333, GNorm = 0.1735, lr_0 = 1.1967e-04
#
#
# Loss = 2.7953e-02, PNorm = 70.3277, GNorm = 1.0947, lr_0 = 1.1867e-04
#
#
# Loss = 1.5841e-02, PNorm = 70.3462, GNorm = 0.3013, lr_0 = 1.1768e-04
#
#
#
#
#
#
# Validation prc-auc = 0.575805
# Epoch 90
#
# Loss = 2.6103e-02, PNorm = 70.3605, GNorm = 0.6070, lr_0 = 1.1670e-04
#
#
# Loss = 2.3660e-02, PNorm = 70.3715, GNorm = 0.1393, lr_0 = 1.1572e-04
#
#
# Loss = 3.4190e-02, PNorm = 70.3736, GNorm = 1.5331, lr_0 = 1.1475e-04
#
#
#
#
#
#
# Validation prc-auc = 0.587242
# Epoch 91
#
#
# Loss = 1.4589e-02, PNorm = 70.3947, GNorm = 0.1088, lr_0 = 1.1379e-04
#
#
# Loss = 2.1304e-02, PNorm = 70.4039, GNorm = 1.1301, lr_0 = 1.1284e-04
#
#
# Loss = 1.6045e-02, PNorm = 70.4117, GNorm = 0.1646, lr_0 = 1.1190e-04
#
#
#
#
#
# Validation prc-auc = 0.591216
# Epoch 92
#
#
# Loss = 1.0302e-02, PNorm = 70.4306, GNorm = 0.3065, lr_0 = 1.1097e-04
#
#
# Loss = 1.4572e-02, PNorm = 70.4450, GNorm = 0.1563, lr_0 = 1.1004e-04
#
#
# Loss = 1.6278e-02, PNorm = 70.4484, GNorm = 0.1589, lr_0 = 1.0912e-04
#
#
#
#
#
# Validation prc-auc = 0.589132
# Epoch 93
#
#
# Loss = 1.5837e-02, PNorm = 70.4677, GNorm = 0.5706, lr_0 = 1.0821e-04
#
#
# Loss = 2.2962e-02, PNorm = 70.4740, GNorm = 0.1506, lr_0 = 1.0730e-04
#
#
# Loss = 2.2845e-02, PNorm = 70.4791, GNorm = 1.7816, lr_0 = 1.0641e-04
# Loss = 9.7140e-03, PNorm = 70.4824, GNorm = 0.2697, lr_0 = 1.0632e-04
#
#
#
#
#
# Validation prc-auc = 0.592652
# Epoch 94
#
#
# Loss = 1.5355e-02, PNorm = 70.5028, GNorm = 1.3939, lr_0 = 1.0543e-04
#
#
# Loss = 1.2094e-02, PNorm = 70.5048, GNorm = 0.9277, lr_0 = 1.0455e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.595990
# Epoch 95
#
# Loss = 1.3910e-02, PNorm = 70.5321, GNorm = 0.6301, lr_0 = 1.0367e-04
#
#
# Loss = 2.1225e-02, PNorm = 70.5328, GNorm = 0.5309, lr_0 = 1.0281e-04
#
#
# Loss = 1.6462e-02, PNorm = 70.5463, GNorm = 0.6822, lr_0 = 1.0195e-04
#
#
#
#
#
#
# Validation prc-auc = 0.594281
# Epoch 96
#
# Loss = 1.8794e-02, PNorm = 70.5574, GNorm = 0.2829, lr_0 = 1.0110e-04
#
#
# Loss = 1.1172e-02, PNorm = 70.5690, GNorm = 0.4422, lr_0 = 1.0025e-04
#
#
# Loss = 1.6257e-02, PNorm = 70.5757, GNorm = 0.0735, lr_0 = 1.0000e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.583119
# Epoch 97
#
# Loss = 1.3569e-02, PNorm = 70.5853, GNorm = 1.0677, lr_0 = 1.0000e-04
#
#
# Loss = 1.6224e-02, PNorm = 70.6047, GNorm = 1.0711, lr_0 = 1.0000e-04
#
#
# Loss = 1.3695e-02, PNorm = 70.6154, GNorm = 0.5035, lr_0 = 1.0000e-04
#
#
#
#
#
#
# Validation prc-auc = 0.590307
# Epoch 98
#
# Loss = 1.1112e-02, PNorm = 70.6223, GNorm = 0.9974, lr_0 = 1.0000e-04
#
#
# Loss = 1.0065e-02, PNorm = 70.6375, GNorm = 0.1805, lr_0 = 1.0000e-04
#
#
# Loss = 1.5550e-02, PNorm = 70.6515, GNorm = 0.1622, lr_0 = 1.0000e-04
#
#
#
#
#
#
# Validation prc-auc = 0.592493
# Epoch 99
#
# Loss = 8.1529e-03, PNorm = 70.6535, GNorm = 0.2527, lr_0 = 1.0000e-04
#
#
# Loss = 1.2001e-02, PNorm = 70.6615, GNorm = 0.2557, lr_0 = 1.0000e-04
#
#
# Loss = 1.1280e-02, PNorm = 70.6751, GNorm = 0.4215, lr_0 = 1.0000e-04
#
#
#
#
#
#
# Validation prc-auc = 0.590440
# 100%|██████████| 100/100 [01:44<00:00,  1.04s/it]
# Model 0 best validation prc-auc = 0.658808 on epoch 19
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
# Moving model to cuda
# Model 0 test prc-auc = 0.658808
# Ensemble test prc-auc = 0.658808
# 1-fold cross validation
# 	Seed 0 ==> test prc-auc = 0.658808
# Overall test prc-auc = 0.658808 +/- 0.000000
# Elapsed time = 0:02:51
# 1it [02:50, 170.59s/it]Command line
# python /home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/ipykernel_launcher.py --ip=127.0.0.1 --stdin=9003 --control=9001 --hb=9000 --Session.signature_scheme="hmac-sha256" --Session.key=b"0fbbc264-b232-4363-ab26-cbd03fc47663" --shell=9002 --transport="tcp" --iopub=9004 --f=/home/simon/.local/share/jupyter/runtime/kernel-v2-283513zdsaee6PI6kh.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': True,
#  'data_path': '/tmp/chemprop/train_1.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 4,
#  'depth_solvent': 3,
#  'device': device(type='cuda', index=0),
#  'dropout': 0.2,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 100,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': ['rdkit_2d_normalized'],
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': False,
#  'features_size': None,
#  'ffn_hidden_size': 1200,
#  'ffn_num_layers': 1,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': 0,
#  'grad_clip': None,
#  'hidden_size': 1200,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'prc-auc',
#  'metrics': ['prc-auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': True,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': '/tmp/chemprop/checkpoint',
#  'save_preds': True,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': '/tmp/chemprop/test_1.csv',
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': '/tmp/chemprop/test_1.csv',
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [1.0, 0.0, 0.0],
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['targets'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': True,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# New best PRC AUC: 0.6605853929566027
# HYPERPARAMETER 1
# {'--hidden_size': '1200', '--ffn_num_layers': '1', '--ffn_hidden_size': '1200', '--dropout': '0.2', '--depth': '4'}
# 1442it [00:00, 429436.69it/s]
# 100%|██████████| 1442/1442 [00:29<00:00, 48.87it/s]
# 100%|██████████| 1442/1442 [00:00<00:00, 252639.36it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# 721it [00:00, 423958.11it/s]
# 100%|██████████| 721/721 [00:14<00:00, 49.57it/s]
# 100%|██████████| 721/721 [00:00<00:00, 277109.24it/s]
# 721it [00:00, 431766.59it/s]
# 100%|██████████| 721/721 [00:14<00:00, 49.95it/s]
# 100%|██████████| 721/721 [00:00<00:00, 277975.29it/s]
# Class sizes
# targets 0: 78.64%, 1: 21.36%
# Total size = 1,442 | train size = 1,442 | val size = 721 | test size = 721
# Building model 0
# MoleculeModel(
#   (sigmoid): Sigmoid()
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout): Dropout(p=0.2, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=1200, bias=False)
#         (W_h): Linear(in_features=1200, out_features=1200, bias=False)
#         (W_o): Linear(in_features=1333, out_features=1200, bias=True)
#       )
#     )
#   )
#   (readout): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1400, out_features=1, bias=True)
#   )
# )
# Number of parameters = 3,219,801
# Moving model to cuda
# Epoch 0
#
#
#
# Loss = 5.4072e-01, PNorm = 52.2598, GNorm = 2.6784, lr_0 = 2.7679e-04
#
#
# Loss = 5.0277e-01, PNorm = 52.2836, GNorm = 0.4784, lr_0 = 4.3750e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.373403
# Epoch 1
#
# Loss = 5.4361e-01, PNorm = 52.3181, GNorm = 2.0122, lr_0 = 6.1429e-04
#
#
# Loss = 4.4956e-01, PNorm = 52.3607, GNorm = 0.8673, lr_0 = 7.7500e-04
#
#
#
# Loss = 4.5318e-01, PNorm = 52.4197, GNorm = 0.5651, lr_0 = 9.3571e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.424842
# Epoch 2
#
# Loss = 4.4576e-01, PNorm = 52.4948, GNorm = 0.7075, lr_0 = 9.9498e-04
#
#
#
# Loss = 4.5962e-01, PNorm = 52.5840, GNorm = 1.5256, lr_0 = 9.8666e-04
#
#
# Loss = 4.5282e-01, PNorm = 52.6672, GNorm = 0.7641, lr_0 = 9.7842e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.456376
# Epoch 3
#
# Loss = 4.4705e-01, PNorm = 52.7520, GNorm = 0.4169, lr_0 = 9.7024e-04
#
#
#
# Loss = 4.2090e-01, PNorm = 52.8437, GNorm = 0.5045, lr_0 = 9.6214e-04
#
#
# Loss = 4.4531e-01, PNorm = 52.9417, GNorm = 0.4096, lr_0 = 9.5410e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.481666
# Epoch 4
#
#
# Loss = 3.9108e-01, PNorm = 53.0572, GNorm = 0.5246, lr_0 = 9.4612e-04
#
#
# Loss = 4.4521e-01, PNorm = 53.1427, GNorm = 0.4794, lr_0 = 9.3822e-04
#
#
#
# Loss = 4.1792e-01, PNorm = 53.2688, GNorm = 0.8580, lr_0 = 9.3038e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.534997
# Epoch 5
#
#
# Loss = 4.0287e-01, PNorm = 53.3722, GNorm = 0.7397, lr_0 = 9.2260e-04
#
#
# Loss = 4.2017e-01, PNorm = 53.4689, GNorm = 1.5528, lr_0 = 9.1489e-04
#
#
#
# Loss = 4.2978e-01, PNorm = 53.5965, GNorm = 1.0254, lr_0 = 9.0725e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.547593
# Epoch 6
#
#
# Loss = 4.1532e-01, PNorm = 53.7370, GNorm = 0.3510, lr_0 = 8.9967e-04
#
#
#
# Loss = 3.7404e-01, PNorm = 53.8516, GNorm = 0.3453, lr_0 = 8.9215e-04
#
#
# Loss = 4.0670e-01, PNorm = 53.9719, GNorm = 0.9559, lr_0 = 8.8469e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.569800
# Epoch 7
#
#
#
# Loss = 3.8464e-01, PNorm = 54.1098, GNorm = 0.4472, lr_0 = 8.7657e-04
#
#
# Loss = 4.0796e-01, PNorm = 54.1998, GNorm = 0.7501, lr_0 = 8.6924e-04
#
#
#
# Loss = 3.6161e-01, PNorm = 54.3390, GNorm = 0.5273, lr_0 = 8.6198e-04
#
#
#
#
#
#
# Validation prc-auc = 0.594413
# Epoch 8
#
#
#
# Loss = 3.7458e-01, PNorm = 54.4745, GNorm = 0.8491, lr_0 = 8.5477e-04
#
#
# Loss = 3.8870e-01, PNorm = 54.6216, GNorm = 0.3006, lr_0 = 8.4763e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.603769
# Epoch 9
#
# Loss = 2.3211e-01, PNorm = 54.7616, GNorm = 0.2809, lr_0 = 8.4055e-04
#
#
# Loss = 3.5591e-01, PNorm = 54.8952, GNorm = 0.4476, lr_0 = 8.3352e-04
#
#
#
# Loss = 3.5776e-01, PNorm = 55.0252, GNorm = 0.7471, lr_0 = 8.2656e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.619522
# Epoch 10
#
# Loss = 3.0522e-01, PNorm = 55.1432, GNorm = 1.3041, lr_0 = 8.1965e-04
#
#
# Loss = 3.3436e-01, PNorm = 55.2763, GNorm = 0.6460, lr_0 = 8.1280e-04
#
#
#
# Loss = 3.4958e-01, PNorm = 55.4208, GNorm = 0.4578, lr_0 = 8.0601e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.637389
# Epoch 11
#
# Loss = 3.2907e-01, PNorm = 55.5898, GNorm = 1.0940, lr_0 = 7.9928e-04
#
#
#
# Loss = 3.2490e-01, PNorm = 55.7464, GNorm = 0.4545, lr_0 = 7.9260e-04
#
#
# Loss = 3.3584e-01, PNorm = 55.8865, GNorm = 1.5712, lr_0 = 7.8597e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.663679
# Epoch 12
#
# Loss = 3.0132e-01, PNorm = 56.0605, GNorm = 0.4522, lr_0 = 7.7941e-04
#
#
#
# Loss = 3.2959e-01, PNorm = 56.2352, GNorm = 1.3522, lr_0 = 7.7289e-04
#
#
# Loss = 3.4289e-01, PNorm = 56.4326, GNorm = 0.4780, lr_0 = 7.6643e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.662996
# Epoch 13
#
#
# Loss = 3.0049e-01, PNorm = 56.6353, GNorm = 0.4981, lr_0 = 7.5939e-04
#
#
# Loss = 3.0166e-01, PNorm = 56.7955, GNorm = 0.4565, lr_0 = 7.5305e-04
#
#
#
# Loss = 2.9865e-01, PNorm = 56.9614, GNorm = 0.5812, lr_0 = 7.4675e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.636596
# Epoch 14
#
#
# Loss = 2.8598e-01, PNorm = 57.1562, GNorm = 1.1734, lr_0 = 7.4051e-04
#
#
#
# Loss = 3.3183e-01, PNorm = 57.3639, GNorm = 2.3950, lr_0 = 7.3433e-04
#
#
# Loss = 3.1422e-01, PNorm = 57.6115, GNorm = 1.2766, lr_0 = 7.2819e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.672714
# Epoch 15
#
#
# Loss = 3.2544e-01, PNorm = 57.7715, GNorm = 1.2827, lr_0 = 7.2211e-04
#
#
#
# Loss = 2.7889e-01, PNorm = 57.9405, GNorm = 1.2339, lr_0 = 7.1607e-04
#
#
# Loss = 2.7788e-01, PNorm = 58.1095, GNorm = 0.8380, lr_0 = 7.1009e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.676890
# Epoch 16
#
#
#
# Loss = 2.9326e-01, PNorm = 58.2613, GNorm = 0.8522, lr_0 = 7.0415e-04
#
#
# Loss = 2.6594e-01, PNorm = 58.4484, GNorm = 0.4789, lr_0 = 6.9827e-04
#
#
#
# Loss = 2.8655e-01, PNorm = 58.6447, GNorm = 0.3996, lr_0 = 6.9243e-04
#
#
#
#
#
#
# Validation prc-auc = 0.653100
# Epoch 17
#
#
#
# Loss = 2.2301e-01, PNorm = 58.8154, GNorm = 0.9935, lr_0 = 6.8665e-04
#
#
# Loss = 2.5145e-01, PNorm = 58.9846, GNorm = 0.8077, lr_0 = 6.8091e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.655955
# Epoch 18
#
# Loss = 2.5433e-01, PNorm = 59.1522, GNorm = 0.6613, lr_0 = 6.7522e-04
#
#
# Loss = 2.2749e-01, PNorm = 59.3264, GNorm = 0.7271, lr_0 = 6.6958e-04
#
#
#
# Loss = 2.4264e-01, PNorm = 59.4731, GNorm = 0.6907, lr_0 = 6.6398e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.682761
# Epoch 19
#
# Loss = 1.8710e-01, PNorm = 59.6736, GNorm = 0.9712, lr_0 = 6.5788e-04
#
#
#
# Loss = 1.9632e-01, PNorm = 59.8488, GNorm = 0.7258, lr_0 = 6.5239e-04
#
#
# Loss = 2.5290e-01, PNorm = 60.0460, GNorm = 1.2821, lr_0 = 6.4693e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.640012
# Epoch 20
#
# Loss = 2.2694e-01, PNorm = 60.2430, GNorm = 1.0044, lr_0 = 6.4153e-04
#
#
#
# Loss = 2.5387e-01, PNorm = 60.4509, GNorm = 0.7161, lr_0 = 6.3617e-04
#
#
# Loss = 2.0924e-01, PNorm = 60.6194, GNorm = 0.4500, lr_0 = 6.3085e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.647683
# Epoch 21
#
#
# Loss = 1.9963e-01, PNorm = 60.7820, GNorm = 1.0894, lr_0 = 6.2558e-04
#
#
# Loss = 2.0647e-01, PNorm = 60.9438, GNorm = 0.6191, lr_0 = 6.2035e-04
#
#
#
# Loss = 2.2385e-01, PNorm = 61.0802, GNorm = 1.2051, lr_0 = 6.1517e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.625756
# Epoch 22
#
#
# Loss = 1.7762e-01, PNorm = 61.2574, GNorm = 0.5723, lr_0 = 6.1003e-04
#
#
# Loss = 2.1403e-01, PNorm = 61.4239, GNorm = 0.8942, lr_0 = 6.0493e-04
#
#
#
# Loss = 1.9634e-01, PNorm = 61.5647, GNorm = 0.9403, lr_0 = 5.9988e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.650047
# Epoch 23
#
#
# Loss = 1.7792e-01, PNorm = 61.7146, GNorm = 1.4995, lr_0 = 5.9486e-04
#
#
#
# Loss = 1.4183e-01, PNorm = 61.8905, GNorm = 0.7107, lr_0 = 5.8989e-04
#
#
# Loss = 1.9144e-01, PNorm = 62.0234, GNorm = 0.8597, lr_0 = 5.8496e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.623844
# Epoch 24
#
#
# Loss = 1.7796e-01, PNorm = 62.1690, GNorm = 1.2323, lr_0 = 5.8007e-04
#
#
#
# Loss = 1.6302e-01, PNorm = 62.3160, GNorm = 1.0212, lr_0 = 5.7523e-04
#
#
# Loss = 1.7299e-01, PNorm = 62.4803, GNorm = 0.7538, lr_0 = 5.7042e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.617691
# Epoch 25
#
#
#
# Loss = 1.3066e-01, PNorm = 62.6376, GNorm = 0.6256, lr_0 = 5.6565e-04
#
#
# Loss = 1.5534e-01, PNorm = 62.7925, GNorm = 0.6046, lr_0 = 5.6093e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.611578
# Epoch 26
#
# Loss = 2.1665e-01, PNorm = 62.9329, GNorm = 1.5499, lr_0 = 5.5577e-04
#
#
# Loss = 1.3616e-01, PNorm = 63.0799, GNorm = 0.8150, lr_0 = 5.5113e-04
#
#
#
# Loss = 1.3495e-01, PNorm = 63.2158, GNorm = 0.5902, lr_0 = 5.4652e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.600574
# Epoch 27
#
# Loss = 1.5808e-01, PNorm = 63.3515, GNorm = 0.8116, lr_0 = 5.4196e-04
#
#
# Loss = 1.0657e-01, PNorm = 63.4957, GNorm = 0.6417, lr_0 = 5.3743e-04
#
#
#
# Loss = 1.2630e-01, PNorm = 63.6145, GNorm = 1.4311, lr_0 = 5.3294e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.617073
# Epoch 28
#
# Loss = 1.1046e-01, PNorm = 63.7368, GNorm = 0.6929, lr_0 = 5.2848e-04
#
#
#
# Loss = 1.1401e-01, PNorm = 63.8642, GNorm = 1.0246, lr_0 = 5.2407e-04
#
#
# Loss = 1.0782e-01, PNorm = 63.9734, GNorm = 0.6948, lr_0 = 5.1969e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.629787
# Epoch 29
#
# Loss = 8.6523e-02, PNorm = 64.0977, GNorm = 0.5247, lr_0 = 5.1535e-04
#
#
#
# Loss = 1.2179e-01, PNorm = 64.2320, GNorm = 0.5478, lr_0 = 5.1104e-04
#
#
# Loss = 1.2978e-01, PNorm = 64.3513, GNorm = 1.1699, lr_0 = 5.0677e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.607925
# Epoch 30
#
#
# Loss = 1.1301e-01, PNorm = 64.4716, GNorm = 0.8686, lr_0 = 5.0253e-04
#
#
# Loss = 1.1401e-01, PNorm = 64.6026, GNorm = 0.4146, lr_0 = 4.9834e-04
#
#
#
# Loss = 1.2331e-01, PNorm = 64.7089, GNorm = 0.5725, lr_0 = 4.9417e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.626095
# Epoch 31
#
#
# Loss = 7.3797e-02, PNorm = 64.8208, GNorm = 0.4769, lr_0 = 4.9004e-04
#
#
# Loss = 1.1521e-01, PNorm = 64.9357, GNorm = 1.0224, lr_0 = 4.8595e-04
#
#
#
# Loss = 1.0657e-01, PNorm = 65.0577, GNorm = 1.1015, lr_0 = 4.8189e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.618717
# Epoch 32
#
#
# Loss = 8.0604e-02, PNorm = 65.1859, GNorm = 0.7570, lr_0 = 4.7746e-04
#
#
#
# Loss = 1.1407e-01, PNorm = 65.2910, GNorm = 1.2360, lr_0 = 4.7347e-04
#
#
# Loss = 1.1934e-01, PNorm = 65.3712, GNorm = 1.3440, lr_0 = 4.6951e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.618028
# Epoch 33
#
#
#
# Loss = 8.9234e-02, PNorm = 65.4747, GNorm = 1.3609, lr_0 = 4.6559e-04
#
#
# Loss = 8.8135e-02, PNorm = 65.5967, GNorm = 1.1428, lr_0 = 4.6170e-04
#
#
#
# Loss = 1.1675e-01, PNorm = 65.6936, GNorm = 0.8867, lr_0 = 4.5784e-04
#
#
#
#
#
#
# Validation prc-auc = 0.611445
# Epoch 34
#
#
#
# Loss = 1.0074e-01, PNorm = 65.8156, GNorm = 0.7404, lr_0 = 4.5401e-04
#
#
# Loss = 1.1569e-01, PNorm = 65.9298, GNorm = 0.7034, lr_0 = 4.5022e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.605559
# Epoch 35
#
# Loss = 4.8166e-02, PNorm = 66.0581, GNorm = 0.5279, lr_0 = 4.4646e-04
#
#
# Loss = 6.7686e-02, PNorm = 66.1391, GNorm = 0.5897, lr_0 = 4.4273e-04
#
#
#
# Loss = 7.5541e-02, PNorm = 66.2215, GNorm = 0.8696, lr_0 = 4.3903e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.607052
# Epoch 36
#
# Loss = 5.2709e-02, PNorm = 66.3148, GNorm = 0.5304, lr_0 = 4.3536e-04
#
#
# Loss = 5.0196e-02, PNorm = 66.3918, GNorm = 0.6125, lr_0 = 4.3172e-04
#
#
#
# Loss = 7.2500e-02, PNorm = 66.4604, GNorm = 1.0355, lr_0 = 4.2811e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.591277
# Epoch 37
#
# Loss = 4.8437e-02, PNorm = 66.5403, GNorm = 1.3215, lr_0 = 4.2454e-04
#
#
#
# Loss = 3.8841e-02, PNorm = 66.6328, GNorm = 0.4176, lr_0 = 4.2099e-04
#
#
# Loss = 4.4731e-02, PNorm = 66.6960, GNorm = 0.4370, lr_0 = 4.1747e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.623254
# Epoch 38
#
#
# Loss = 6.9294e-02, PNorm = 66.7906, GNorm = 0.6206, lr_0 = 4.1364e-04
#
#
# Loss = 5.2540e-02, PNorm = 66.8660, GNorm = 0.4211, lr_0 = 4.1018e-04
#
#
#
# Loss = 4.8050e-02, PNorm = 66.9466, GNorm = 1.3295, lr_0 = 4.0675e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.621905
# Epoch 39
#
#
# Loss = 3.9591e-02, PNorm = 67.0183, GNorm = 0.9912, lr_0 = 4.0335e-04
#
#
# Loss = 5.2515e-02, PNorm = 67.0828, GNorm = 0.8508, lr_0 = 3.9998e-04
#
#
#
# Loss = 3.9604e-02, PNorm = 67.1404, GNorm = 0.7701, lr_0 = 3.9664e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.586935
# Epoch 40
#
#
# Loss = 5.0250e-02, PNorm = 67.2068, GNorm = 0.7783, lr_0 = 3.9333e-04
#
#
#
# Loss = 4.5611e-02, PNorm = 67.2809, GNorm = 0.4176, lr_0 = 3.9004e-04
#
#
# Loss = 4.8406e-02, PNorm = 67.3407, GNorm = 1.5630, lr_0 = 3.8678e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.599943
# Epoch 41
#
#
# Loss = 3.6766e-02, PNorm = 67.3726, GNorm = 0.7210, lr_0 = 3.8355e-04
#
#
#
# Loss = 5.1999e-02, PNorm = 67.4544, GNorm = 0.6182, lr_0 = 3.8034e-04
#
#
# Loss = 5.1310e-02, PNorm = 67.5217, GNorm = 0.5298, lr_0 = 3.7716e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.570380
# Epoch 42
#
#
#
# ...
#
#
#
#
#
# Loss = 2.1459e-02, PNorm = 118.9327, GNorm = 1.5341, lr_0 = 3.5535e-04
#
#
#
#
#
# Loss = 1.7902e-02, PNorm = 118.9776, GNorm = 1.1631, lr_0 = 3.5238e-04
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.569058
# Epoch 45
#
#
# Loss = 9.9736e-04, PNorm = 119.0106, GNorm = 0.0537, lr_0 = 3.4944e-04
#
#
#
#
#
# Loss = 2.4415e-02, PNorm = 119.0387, GNorm = 0.6454, lr_0 = 3.4652e-04
#
#
#
#
#
# Loss = 1.3797e-02, PNorm = 119.0670, GNorm = 2.8050, lr_0 = 3.4362e-04
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.550974
# Epoch 46
#
#
# Loss = 2.9144e-02, PNorm = 119.1075, GNorm = 1.6246, lr_0 = 3.4075e-04
#
#
#
#
#
# Loss = 4.7391e-02, PNorm = 119.1587, GNorm = 1.8342, lr_0 = 3.3790e-04
#
#
#
#
#
# Loss = 4.7916e-02, PNorm = 119.2001, GNorm = 1.4936, lr_0 = 3.3508e-04
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.570557
# Epoch 47
#
#
#
# Loss = 2.1527e-02, PNorm = 119.2448, GNorm = 0.3675, lr_0 = 3.3228e-04
#
#
#
#
#
# Loss = 2.1308e-02, PNorm = 119.2883, GNorm = 0.9283, lr_0 = 3.2950e-04
#
#
#
#
#
# Loss = 1.8389e-02, PNorm = 119.3238, GNorm = 1.1777, lr_0 = 3.2675e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.569466
# Epoch 48
#
#
#
# Loss = 1.3517e-02, PNorm = 119.3424, GNorm = 0.0098, lr_0 = 3.2402e-04
#
#
#
#
#
# Loss = 2.7254e-02, PNorm = 119.3714, GNorm = 0.5694, lr_0 = 3.2131e-04
#
#
#
#
#
# Loss = 1.6902e-02, PNorm = 119.3999, GNorm = 1.0026, lr_0 = 3.1863e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.584731
# Epoch 49
#
#
#
# Loss = 2.0232e-02, PNorm = 119.4173, GNorm = 0.5524, lr_0 = 3.1596e-04
#
#
#
#
#
# Loss = 6.0703e-03, PNorm = 119.4414, GNorm = 0.6327, lr_0 = 3.1332e-04
#
#
#
#
#
# Loss = 2.2801e-02, PNorm = 119.4705, GNorm = 0.1318, lr_0 = 3.1070e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.597689
# Epoch 50
#
#
#
#
# Loss = 1.4518e-02, PNorm = 119.4926, GNorm = 0.2169, lr_0 = 3.0811e-04
#
#
#
#
#
# Loss = 1.9802e-02, PNorm = 119.5141, GNorm = 0.1371, lr_0 = 3.0553e-04
#
#
#
#
#
# Loss = 1.3553e-02, PNorm = 119.5279, GNorm = 0.3329, lr_0 = 3.0298e-04
# Loss = 3.4828e-03, PNorm = 119.5293, GNorm = 0.1264, lr_0 = 3.0273e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.593813
# Epoch 51
#
#
#
#
#
# Loss = 8.6868e-03, PNorm = 119.5477, GNorm = 0.8381, lr_0 = 3.0020e-04
#
#
#
#
#
# Loss = 4.4153e-03, PNorm = 119.5601, GNorm = 0.1712, lr_0 = 2.9769e-04
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.581657
# Epoch 52
#
# Loss = 1.1326e-03, PNorm = 119.5709, GNorm = 0.0530, lr_0 = 2.9520e-04
#
#
#
#
#
# Loss = 3.4818e-03, PNorm = 119.5867, GNorm = 0.0420, lr_0 = 2.9273e-04
#
#
#
#
#
# Loss = 1.3057e-02, PNorm = 119.5913, GNorm = 0.0451, lr_0 = 2.9029e-04
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.568370
# Epoch 53
#
# Loss = 1.5989e-02, PNorm = 119.6265, GNorm = 0.1630, lr_0 = 2.8786e-04
#
#
#
#
#
# Loss = 1.7751e-02, PNorm = 119.6528, GNorm = 1.3915, lr_0 = 2.8546e-04
#
#
#
#
#
# Loss = 2.0840e-02, PNorm = 119.6680, GNorm = 0.8987, lr_0 = 2.8307e-04
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.579647
# Epoch 54
#
#
# Loss = 5.6966e-03, PNorm = 119.6869, GNorm = 1.0720, lr_0 = 2.8071e-04
#
#
#
#
#
# Loss = 6.3014e-03, PNorm = 119.6959, GNorm = 0.0858, lr_0 = 2.7836e-04
#
#
#
#
#
# Loss = 5.6281e-03, PNorm = 119.7123, GNorm = 0.1043, lr_0 = 2.7603e-04
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.575241
# Epoch 55
#
#
# Loss = 2.0937e-03, PNorm = 119.7240, GNorm = 0.2299, lr_0 = 2.7373e-04
#
#
#
#
#
# Loss = 5.2414e-03, PNorm = 119.7316, GNorm = 0.0682, lr_0 = 2.7144e-04
#
#
#
#
#
# Loss = 3.7170e-03, PNorm = 119.7399, GNorm = 0.4551, lr_0 = 2.6917e-04
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.575589
# Epoch 56
#
#
#
# Loss = 1.3392e-03, PNorm = 119.7526, GNorm = 0.0434, lr_0 = 2.6692e-04
#
#
#
#
#
# Loss = 2.1146e-03, PNorm = 119.7651, GNorm = 0.0135, lr_0 = 2.6469e-04
#
#
#
#
#
# Loss = 5.1740e-03, PNorm = 119.7697, GNorm = 2.4658, lr_0 = 2.6248e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.583807
# Epoch 57
#
#
#
#
# Loss = 4.0515e-03, PNorm = 119.7818, GNorm = 0.0295, lr_0 = 2.6007e-04
#
#
#
#
#
# Loss = 1.0883e-02, PNorm = 119.7909, GNorm = 0.2413, lr_0 = 2.5790e-04
#
#
#
#
#
# Loss = 2.6051e-02, PNorm = 119.7964, GNorm = 0.0472, lr_0 = 2.5574e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.582662
# Epoch 58
#
#
#
#
# Loss = 3.9359e-03, PNorm = 119.8243, GNorm = 0.0305, lr_0 = 2.5360e-04
#
#
#
#
#
# Loss = 1.0074e-02, PNorm = 119.8376, GNorm = 0.0378, lr_0 = 2.5148e-04
#
#
#
#
#
# Loss = 1.4011e-02, PNorm = 119.8479, GNorm = 0.6437, lr_0 = 2.4938e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.576774
# Epoch 59
#
#
#
#
#
# Loss = 5.5761e-03, PNorm = 119.8595, GNorm = 1.1164, lr_0 = 2.4730e-04
#
#
#
#
#
# Loss = 1.4369e-02, PNorm = 119.8674, GNorm = 0.0707, lr_0 = 2.4523e-04
#
#
#
#
#
# Loss = 4.8923e-03, PNorm = 119.8743, GNorm = 0.0382, lr_0 = 2.4318e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.579598
# Epoch 60
#
#
#
#
#
# Loss = 2.8811e-03, PNorm = 119.8810, GNorm = 0.4359, lr_0 = 2.4115e-04
#
#
#
#
#
# Loss = 3.4819e-03, PNorm = 119.8916, GNorm = 0.0428, lr_0 = 2.3914e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.585500
# Epoch 61
#
# Loss = 2.4098e-04, PNorm = 119.8958, GNorm = 0.0067, lr_0 = 2.3714e-04
#
#
#
#
#
# Loss = 6.1238e-03, PNorm = 119.8990, GNorm = 0.8459, lr_0 = 2.3516e-04
#
#
#
#
#
# Loss = 4.4704e-03, PNorm = 119.9083, GNorm = 0.1834, lr_0 = 2.3319e-04
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.580141
# Epoch 62
#
# Loss = 1.9571e-03, PNorm = 119.9154, GNorm = 0.0241, lr_0 = 2.3124e-04
#
#
#
#
#
# Loss = 3.5863e-03, PNorm = 119.9173, GNorm = 0.0389, lr_0 = 2.2931e-04
#
#
#
#
#
# Loss = 9.8692e-03, PNorm = 119.9259, GNorm = 0.0136, lr_0 = 2.2739e-04
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.586977
# Epoch 63
#
#
# Loss = 2.6003e-03, PNorm = 119.9328, GNorm = 0.0111, lr_0 = 2.2530e-04
#
#
#
#
#
# Loss = 2.2743e-03, PNorm = 119.9372, GNorm = 0.2112, lr_0 = 2.2342e-04
#
#
#
#
#
# Loss = 3.9592e-03, PNorm = 119.9483, GNorm = 0.0106, lr_0 = 2.2155e-04
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.578726
# Epoch 64
#
#
#
# Loss = 1.5112e-02, PNorm = 119.9542, GNorm = 2.4219, lr_0 = 2.1970e-04
#
#
#
#
#
# Loss = 2.0573e-03, PNorm = 119.9557, GNorm = 0.0039, lr_0 = 2.1787e-04
#
#
#
#
#
# Loss = 1.0094e-02, PNorm = 119.9713, GNorm = 0.0710, lr_0 = 2.1605e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.601511
# Epoch 65
#
#
#
# Loss = 1.8547e-03, PNorm = 119.9885, GNorm = 0.0124, lr_0 = 2.1424e-04
#
#
#
#
#
# Loss = 6.9098e-03, PNorm = 119.9933, GNorm = 0.8468, lr_0 = 2.1245e-04
#
#
#
#
#
# Loss = 8.4178e-03, PNorm = 119.9968, GNorm = 0.3713, lr_0 = 2.1068e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.607078
# Epoch 66
#
#
#
#
# Loss = 2.3971e-03, PNorm = 120.0107, GNorm = 0.1050, lr_0 = 2.0892e-04
#
#
#
#
#
# Loss = 7.9829e-03, PNorm = 120.0150, GNorm = 0.2785, lr_0 = 2.0717e-04
#
#
#
#
#
# Loss = 9.6326e-03, PNorm = 120.0237, GNorm = 0.6748, lr_0 = 2.0544e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.597102
# Epoch 67
#
#
#
#
# Loss = 6.4980e-03, PNorm = 120.0457, GNorm = 0.0415, lr_0 = 2.0372e-04
#
#
#
#
#
# Loss = 3.4392e-03, PNorm = 120.0555, GNorm = 0.0852, lr_0 = 2.0202e-04
#
#
#
#
#
# Loss = 3.2531e-03, PNorm = 120.0596, GNorm = 0.0459, lr_0 = 2.0033e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.602396
# Epoch 68
#
#
#
#
# Loss = 1.0750e-02, PNorm = 120.0701, GNorm = 2.2625, lr_0 = 1.9866e-04
#
#
#
#
#
# Loss = 6.6842e-03, PNorm = 120.0868, GNorm = 0.0526, lr_0 = 1.9700e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.584560
# Epoch 69
#
# Loss = 2.3082e-03, PNorm = 120.0915, GNorm = 0.0895, lr_0 = 1.9519e-04
#
#
#
#
#
# Loss = 8.6928e-03, PNorm = 120.1048, GNorm = 0.0142, lr_0 = 1.9356e-04
#
#
#
#
#
# Loss = 1.5328e-03, PNorm = 120.1156, GNorm = 0.0153, lr_0 = 1.9194e-04
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.587808
# Epoch 70
#
# Loss = 1.0601e-02, PNorm = 120.1209, GNorm = 0.0076, lr_0 = 1.9034e-04
#
#
#
#
#
# Loss = 1.4176e-03, PNorm = 120.1303, GNorm = 0.0075, lr_0 = 1.8874e-04
#
#
#
#
#
# Loss = 7.5272e-03, PNorm = 120.1351, GNorm = 0.1297, lr_0 = 1.8717e-04
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.587657
# Epoch 71
#
#
# Loss = 2.4373e-03, PNorm = 120.1389, GNorm = 0.3526, lr_0 = 1.8560e-04
#
#
#
#
#
# Loss = 3.8931e-03, PNorm = 120.1431, GNorm = 0.0097, lr_0 = 1.8405e-04
#
#
#
#
#
# Loss = 6.2950e-03, PNorm = 120.1571, GNorm = 0.0080, lr_0 = 1.8251e-04
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.578144
# Epoch 72
#
#
# Loss = 6.2604e-03, PNorm = 120.1651, GNorm = 0.0997, lr_0 = 1.8099e-04
#
#
#
#
#
# Loss = 1.5014e-03, PNorm = 120.1695, GNorm = 0.0222, lr_0 = 1.7948e-04
#
#
#
#
#
# Loss = 4.6200e-03, PNorm = 120.1762, GNorm = 0.4229, lr_0 = 1.7798e-04
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.582883
# Epoch 73
#
#
#
# Loss = 1.2700e-03, PNorm = 120.1847, GNorm = 0.0376, lr_0 = 1.7649e-04
#
#
#
#
#
# Loss = 2.2893e-03, PNorm = 120.1898, GNorm = 1.1641, lr_0 = 1.7502e-04
#
#
#
#
#
# Loss = 1.8155e-03, PNorm = 120.1920, GNorm = 0.0113, lr_0 = 1.7355e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.580187
# Epoch 74
#
#
#
# Loss = 1.9554e-03, PNorm = 120.1952, GNorm = 0.4723, lr_0 = 1.7210e-04
#
#
#
#
#
# Loss = 5.2474e-03, PNorm = 120.1945, GNorm = 0.0290, lr_0 = 1.7066e-04
#
#
#
#
#
# Loss = 9.6741e-03, PNorm = 120.2031, GNorm = 2.6616, lr_0 = 1.6924e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.585019
# Epoch 75
#
#
#
# Loss = 3.9225e-03, PNorm = 120.2175, GNorm = 0.0089, lr_0 = 1.6782e-04
#
#
#
#
#
# Loss = 2.0821e-03, PNorm = 120.2252, GNorm = 1.1054, lr_0 = 1.6642e-04
#
#
#
#
#
# Loss = 2.7085e-03, PNorm = 120.2294, GNorm = 0.0395, lr_0 = 1.6503e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.590707
# Epoch 76
#
#
#
#
#
# Loss = 2.7910e-03, PNorm = 120.2347, GNorm = 0.1285, lr_0 = 1.6351e-04
#
#
#
#
#
# Loss = 1.6472e-03, PNorm = 120.2427, GNorm = 0.0425, lr_0 = 1.6215e-04
#
#
#
#
#
# Loss = 4.8857e-04, PNorm = 120.2476, GNorm = 0.0784, lr_0 = 1.6079e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.589663
# Epoch 77
#
#
#
#
#
# Loss = 1.0914e-03, PNorm = 120.2505, GNorm = 0.0155, lr_0 = 1.5945e-04
#
#
#
#
#
# Loss = 3.1734e-03, PNorm = 120.2542, GNorm = 0.0147, lr_0 = 1.5812e-04
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.589941
# Epoch 78
#
# Loss = 1.1435e-05, PNorm = 120.2596, GNorm = 0.0008, lr_0 = 1.5680e-04
#
#
#
#
#
# Loss = 3.0654e-03, PNorm = 120.2614, GNorm = 0.0834, lr_0 = 1.5549e-04
#
#
#
#
#
# Loss = 3.4770e-04, PNorm = 120.2632, GNorm = 0.0219, lr_0 = 1.5419e-04
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.589086
# Epoch 79
#
# Loss = 1.1483e-04, PNorm = 120.2668, GNorm = 0.0036, lr_0 = 1.5290e-04
#
#
#
#
#
# Loss = 1.2178e-03, PNorm = 120.2714, GNorm = 0.0088, lr_0 = 1.5162e-04
#
#
#
#
#
# Loss = 6.6844e-03, PNorm = 120.2797, GNorm = 0.0470, lr_0 = 1.5035e-04
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.578062
# Epoch 80
#
#
# Loss = 6.9093e-05, PNorm = 120.2859, GNorm = 0.0023, lr_0 = 1.4910e-04
#
#
#
#
#
# Loss = 9.7057e-03, PNorm = 120.2928, GNorm = 0.1796, lr_0 = 1.4785e-04
#
#
#
#
#
# Loss = 5.2734e-03, PNorm = 120.3006, GNorm = 0.3398, lr_0 = 1.4662e-04
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.580077
# Epoch 81
#
#
# Loss = 6.5792e-04, PNorm = 120.3025, GNorm = 0.0145, lr_0 = 1.4539e-04
#
#
#
#
#
# Loss = 3.9759e-03, PNorm = 120.3067, GNorm = 0.0080, lr_0 = 1.4418e-04
#
#
#
#
#
# Loss = 2.1391e-03, PNorm = 120.3138, GNorm = 0.0254, lr_0 = 1.4297e-04
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.582729
# Epoch 82
#
#
#
# Loss = 1.2013e-03, PNorm = 120.3186, GNorm = 0.0044, lr_0 = 1.4166e-04
#
#
#
#
#
# Loss = 3.4771e-03, PNorm = 120.3196, GNorm = 0.1932, lr_0 = 1.4047e-04
#
#
#
#
#
# Loss = 1.0320e-03, PNorm = 120.3223, GNorm = 0.1422, lr_0 = 1.3930e-04
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.580609
# Epoch 83
#
#
#
#
# Loss = 9.4439e-03, PNorm = 120.3250, GNorm = 0.2710, lr_0 = 1.3814e-04
#
#
#
#
#
# Loss = 1.8478e-03, PNorm = 120.3335, GNorm = 0.0867, lr_0 = 1.3698e-04
#
#
#
#
#
# Loss = 5.3386e-03, PNorm = 120.3387, GNorm = 0.0103, lr_0 = 1.3584e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.580141
# Epoch 84
#
#
#
#
# Loss = 1.5720e-03, PNorm = 120.3431, GNorm = 0.0028, lr_0 = 1.3470e-04
#
#
#
#
#
# Loss = 1.2681e-03, PNorm = 120.3479, GNorm = 0.0037, lr_0 = 1.3358e-04
#
#
#
#
#
# Loss = 1.9602e-03, PNorm = 120.3528, GNorm = 0.0065, lr_0 = 1.3246e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.580747
# Epoch 85
#
#
#
#
#
# Loss = 1.1996e-03, PNorm = 120.3555, GNorm = 0.0053, lr_0 = 1.3135e-04
#
#
#
#
#
# Loss = 5.6264e-03, PNorm = 120.3598, GNorm = 0.1726, lr_0 = 1.3026e-04
#
#
#
#
#
# Loss = 1.6963e-02, PNorm = 120.3629, GNorm = 5.2209, lr_0 = 1.2917e-04
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.571395
# Epoch 86
#
#
#
#
#
# Loss = 2.6672e-03, PNorm = 120.3620, GNorm = 2.3240, lr_0 = 1.2809e-04
#
#
#
#
#
# Loss = 1.8387e-02, PNorm = 120.3839, GNorm = 0.0071, lr_0 = 1.2702e-04
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.574912
# Epoch 87
#
# Loss = 6.8433e-05, PNorm = 120.3954, GNorm = 0.0038, lr_0 = 1.2596e-04
#
#
#
#
#
# Loss = 1.0062e-03, PNorm = 120.3993, GNorm = 0.1224, lr_0 = 1.2490e-04
#
#
#
#
#
# Loss = 2.3643e-03, PNorm = 120.4063, GNorm = 0.0994, lr_0 = 1.2386e-04
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.571943
# Epoch 88
#
#
# Loss = 3.2156e-04, PNorm = 120.4148, GNorm = 0.0071, lr_0 = 1.2272e-04
#
#
#
#
#
# Loss = 7.6885e-03, PNorm = 120.4196, GNorm = 1.8504, lr_0 = 1.2170e-04
#
#
#
#
#
# Loss = 3.6112e-04, PNorm = 120.4184, GNorm = 0.0025, lr_0 = 1.2068e-04
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.582905
# Epoch 89
#
#
# Loss = 1.5880e-03, PNorm = 120.4199, GNorm = 0.0009, lr_0 = 1.1967e-04
#
#
#
#
#
# Loss = 6.2517e-03, PNorm = 120.4224, GNorm = 1.6787, lr_0 = 1.1867e-04
#
#
#
#
#
# Loss = 3.5352e-03, PNorm = 120.4281, GNorm = 0.0013, lr_0 = 1.1768e-04
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.580096
# Epoch 90
#
#
# Loss = 1.8781e-03, PNorm = 120.4330, GNorm = 0.3141, lr_0 = 1.1670e-04
#
#
#
#
#
# Loss = 1.5046e-03, PNorm = 120.4366, GNorm = 1.0362, lr_0 = 1.1572e-04
#
#
#
#
#
# Loss = 1.3331e-03, PNorm = 120.4368, GNorm = 0.0317, lr_0 = 1.1475e-04
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.577106
# Epoch 91
#
#
#
# Loss = 9.0190e-04, PNorm = 120.4383, GNorm = 0.0179, lr_0 = 1.1379e-04
#
#
#
#
#
# Loss = 2.9550e-03, PNorm = 120.4429, GNorm = 0.0271, lr_0 = 1.1284e-04
#
#
#
#
#
# Loss = 9.9670e-04, PNorm = 120.4467, GNorm = 0.0290, lr_0 = 1.1190e-04
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.576500
# Epoch 92
#
#
#
# Loss = 3.7771e-04, PNorm = 120.4463, GNorm = 0.0457, lr_0 = 1.1097e-04
#
#
#
#
#
# Loss = 4.0373e-03, PNorm = 120.4498, GNorm = 0.0336, lr_0 = 1.1004e-04
#
#
#
#
#
# Loss = 6.5344e-03, PNorm = 120.4519, GNorm = 0.0323, lr_0 = 1.0912e-04
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.566516
# Epoch 93
#
#
#
#
# Loss = 8.3179e-04, PNorm = 120.4592, GNorm = 0.0019, lr_0 = 1.0821e-04
#
#
#
#
#
# Loss = 5.0984e-04, PNorm = 120.4637, GNorm = 0.0116, lr_0 = 1.0730e-04
#
#
#
#
#
# Loss = 5.0412e-03, PNorm = 120.4658, GNorm = 1.0731, lr_0 = 1.0641e-04
#
# Loss = 3.9452e-04, PNorm = 120.4658, GNorm = 0.0302, lr_0 = 1.0632e-04
#
#
#
#
#
#
#
# Validation prc-auc = 0.560202
# Epoch 94
#
#
#
#
#
# Loss = 3.4423e-03, PNorm = 120.4673, GNorm = 0.1435, lr_0 = 1.0543e-04
#
#
#
#
#
# Loss = 7.6864e-03, PNorm = 120.4679, GNorm = 0.0114, lr_0 = 1.0455e-04
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.555231
# Epoch 95
#
# Loss = 1.5428e-04, PNorm = 120.4712, GNorm = 0.0105, lr_0 = 1.0367e-04
#
#
#
#
#
# Loss = 1.0336e-03, PNorm = 120.4739, GNorm = 0.0010, lr_0 = 1.0281e-04
#
#
#
#
#
# Loss = 1.5725e-03, PNorm = 120.4752, GNorm = 0.0034, lr_0 = 1.0195e-04
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.552629
# Epoch 96
#
# Loss = 5.7685e-04, PNorm = 120.4783, GNorm = 0.0038, lr_0 = 1.0110e-04
#
#
#
#
#
# Loss = 3.2100e-04, PNorm = 120.4805, GNorm = 0.2315, lr_0 = 1.0025e-04
#
#
#
#
#
# Loss = 1.0713e-03, PNorm = 120.4819, GNorm = 0.0035, lr_0 = 1.0000e-04
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.558864
# Epoch 97
#
# Loss = 1.9101e-04, PNorm = 120.4825, GNorm = 0.0509, lr_0 = 1.0000e-04
#
#
#
#
#
# Loss = 4.8311e-04, PNorm = 120.4833, GNorm = 0.0780, lr_0 = 1.0000e-04
#
#
#
#
#
# Loss = 2.0485e-03, PNorm = 120.4850, GNorm = 0.0246, lr_0 = 1.0000e-04
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.556617
# Epoch 98
#
#
# Loss = 6.6222e-04, PNorm = 120.4861, GNorm = 0.1637, lr_0 = 1.0000e-04
#
#
#
#
#
# Loss = 8.9593e-04, PNorm = 120.4873, GNorm = 0.6191, lr_0 = 1.0000e-04
#
#
#
#
#
# Loss = 5.0215e-04, PNorm = 120.4885, GNorm = 0.0027, lr_0 = 1.0000e-04
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.555002
# Epoch 99
#
#
# Loss = 6.4636e-03, PNorm = 120.4941, GNorm = 0.0086, lr_0 = 1.0000e-04
#
#
#
#
#
# Loss = 6.8121e-03, PNorm = 120.4968, GNorm = 0.4917, lr_0 = 1.0000e-04
#
#
#
#
#
# Loss = 3.5751e-03, PNorm = 120.4979, GNorm = 0.5739, lr_0 = 1.0000e-04
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.562374
# 100%|██████████| 100/100 [03:57<00:00,  2.37s/it]
# Model 0 best validation prc-auc = 0.637947 on epoch 15
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
# Loading pretrained parameter "readout.7.weight".
# Loading pretrained parameter "readout.7.bias".
# Moving model to cuda
# Model 0 test prc-auc = 0.637947
# Ensemble test prc-auc = 0.637947
# 1-fold cross validation
# 	Seed 0 ==> test prc-auc = 0.637947
# Overall test prc-auc = 0.637947 +/- 0.000000
# Elapsed time = 0:05:17
# 20it [2:11:31, 394.57s/it]

# %%
print(best_hyperparams)
# Out:
# {'--hidden_size': '600', '--ffn_num_layers': '1', '--ffn_hidden_size': '600', '--dropout': '0.3', '--depth': '5'}

# %%
print(best_score)
# Out:
# 0.6926138745668395

# %%
from copy import copy

result_arguments = copy(base_arguments)
result_arguments.extend([
    '--hidden_size', '600',
    '--ffn_num_layers', '1',
    '--ffn_hidden_size', '600',
    '--dropout', '0.3',
    '--depth', '5'
])

args = chemprop.args.TrainArgs().parse_args(result_arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python /home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/ipykernel_launcher.py --ip=127.0.0.1 --stdin=9003 --control=9001 --hb=9000 --Session.signature_scheme="hmac-sha256" --Session.key=b"0fbbc264-b232-4363-ab26-cbd03fc47663" --shell=9002 --transport="tcp" --iopub=9004 --f=/home/simon/.local/share/jupyter/runtime/kernel-v2-283513zdsaee6PI6kh.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': True,
#  'data_path': '/tmp/chemprop/train_1.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 5,
#  'depth_solvent': 3,
#  'device': device(type='cuda', index=0),
#  'dropout': 0.3,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 100,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': ['rdkit_2d_normalized'],
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': False,
#  'features_size': None,
#  'ffn_hidden_size': 600,
#  'ffn_num_layers': 1,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': 0,
#  'grad_clip': None,
#  'hidden_size': 600,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'prc-auc',
#  'metrics': ['prc-auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': True,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': '/tmp/chemprop/checkpoint',
#  'save_preds': True,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': '/tmp/chemprop/test_1.csv',
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': '/tmp/chemprop/test_1.csv',
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [1.0, 0.0, 0.0],
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['targets'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': True,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# 1442it [00:00, 393608.38it/s]
# 100%|██████████| 1442/1442 [00:36<00:00, 39.36it/s]
# 100%|██████████| 1442/1442 [00:00<00:00, 259857.63it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# 721it [00:00, 460849.31it/s]
# 100%|██████████| 721/721 [00:21<00:00, 32.83it/s]
# 100%|██████████| 721/721 [00:00<00:00, 202456.53it/s]
# 721it [00:00, 372517.02it/s]
# 100%|██████████| 721/721 [00:22<00:00, 32.45it/s]
# 100%|██████████| 721/721 [00:00<00:00, 120294.89it/s]
# Class sizes
# targets 0: 78.64%, 1: 21.36%
# Total size = 1,442 | train size = 1,442 | val size = 721 | test size = 721
# Building model 0
# MoleculeModel(
#   (sigmoid): Sigmoid()
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout): Dropout(p=0.3, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=600, bias=False)
#         (W_h): Linear(in_features=600, out_features=600, bias=False)
#         (W_o): Linear(in_features=733, out_features=600, bias=True)
#       )
#     )
#   )
#   (readout): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Linear(in_features=800, out_features=1, bias=True)
#   )
# )
# Number of parameters = 890,001
# Moving model to cuda
#   0%|          | 0/100 [00:00<?, ?it/s]Epoch 0
# Loss = 5.9565e-01, PNorm = 38.6542, GNorm = 0.8989, lr_0 = 2.7679e-04
# Loss = 5.4407e-01, PNorm = 38.6653, GNorm = 0.5728, lr_0 = 4.3750e-04
# Validation prc-auc = 0.304622
#   1%|          | 1/100 [00:01<02:30,  1.52s/it]Epoch 1
# Loss = 5.2820e-01, PNorm = 38.6813, GNorm = 0.6343, lr_0 = 6.1429e-04
# Loss = 4.7457e-01, PNorm = 38.7025, GNorm = 0.5062, lr_0 = 7.7500e-04
# Loss = 4.7167e-01, PNorm = 38.7273, GNorm = 1.0601, lr_0 = 9.3571e-04
# Validation prc-auc = 0.390395
#   2%|▏         | 2/100 [00:03<02:42,  1.66s/it]Epoch 2
# Loss = 4.4536e-01, PNorm = 38.7601, GNorm = 0.7632, lr_0 = 9.9498e-04
# Loss = 5.0160e-01, PNorm = 38.7962, GNorm = 0.5358, lr_0 = 9.8666e-04
# Loss = 4.7377e-01, PNorm = 38.8281, GNorm = 0.4574, lr_0 = 9.7842e-04
# Validation prc-auc = 0.427423
#   3%|▎         | 3/100 [00:04<02:35,  1.61s/it]Epoch 3
# Loss = 4.7560e-01, PNorm = 38.8573, GNorm = 0.4979, lr_0 = 9.7024e-04
# Loss = 4.3317e-01, PNorm = 38.8825, GNorm = 0.4315, lr_0 = 9.6214e-04
# Loss = 4.6260e-01, PNorm = 38.9132, GNorm = 0.4558, lr_0 = 9.5410e-04
# Validation prc-auc = 0.456217
#   4%|▍         | 4/100 [00:06<02:37,  1.64s/it]Epoch 4
# Loss = 4.0368e-01, PNorm = 38.9523, GNorm = 0.6592, lr_0 = 9.4612e-04
# Loss = 4.6973e-01, PNorm = 38.9801, GNorm = 0.6139, lr_0 = 9.3822e-04
# Loss = 4.3102e-01, PNorm = 39.0179, GNorm = 0.5077, lr_0 = 9.3038e-04
# Validation prc-auc = 0.484457
#   5%|▌         | 5/100 [00:08<02:33,  1.61s/it]Epoch 5
# Loss = 4.0685e-01, PNorm = 39.0518, GNorm = 0.5554, lr_0 = 9.2260e-04
# Loss = 4.3297e-01, PNorm = 39.0841, GNorm = 1.4149, lr_0 = 9.1489e-04
# Loss = 4.4745e-01, PNorm = 39.1224, GNorm = 1.1978, lr_0 = 9.0725e-04
# Validation prc-auc = 0.517877
#   6%|▌         | 6/100 [00:09<02:29,  1.59s/it]Epoch 6
# Loss = 4.6277e-01, PNorm = 39.1596, GNorm = 0.6890, lr_0 = 8.9967e-04
# Loss = 3.9871e-01, PNorm = 39.2022, GNorm = 0.9167, lr_0 = 8.9215e-04
# Loss = 4.4625e-01, PNorm = 39.2304, GNorm = 0.6447, lr_0 = 8.8469e-04
# Validation prc-auc = 0.514007
#   7%|▋         | 7/100 [00:11<02:28,  1.59s/it]Epoch 7
# Loss = 4.0384e-01, PNorm = 39.2690, GNorm = 0.3767, lr_0 = 8.7657e-04
# Loss = 4.4063e-01, PNorm = 39.2969, GNorm = 0.9076, lr_0 = 8.6924e-04
# Loss = 3.9911e-01, PNorm = 39.3419, GNorm = 0.5326, lr_0 = 8.6198e-04
# Validation prc-auc = 0.531992
#   8%|▊         | 8/100 [00:12<02:25,  1.58s/it]Epoch 8
# Loss = 3.8192e-01, PNorm = 39.3894, GNorm = 0.7152, lr_0 = 8.5477e-04
# Loss = 4.1002e-01, PNorm = 39.4321, GNorm = 0.4403, lr_0 = 8.4763e-04
# Validation prc-auc = 0.535251
#   9%|▉         | 9/100 [00:14<02:30,  1.65s/it]Epoch 9
# Loss = 2.7817e-01, PNorm = 39.4925, GNorm = 0.3015, lr_0 = 8.4055e-04
# Loss = 3.8155e-01, PNorm = 39.5491, GNorm = 0.4615, lr_0 = 8.3352e-04
# Loss = 3.9844e-01, PNorm = 39.6079, GNorm = 0.6541, lr_0 = 8.2656e-04
# Validation prc-auc = 0.570096
#  10%|█         | 10/100 [00:16<02:31,  1.68s/it]Epoch 10
# Loss = 3.2501e-01, PNorm = 39.6621, GNorm = 1.2156, lr_0 = 8.1965e-04
# Loss = 3.7307e-01, PNorm = 39.7231, GNorm = 0.9327, lr_0 = 8.1280e-04
# Loss = 4.0503e-01, PNorm = 39.7835, GNorm = 0.5154, lr_0 = 8.0601e-04
# Validation prc-auc = 0.584647
#  11%|█         | 11/100 [00:18<02:30,  1.70s/it]Epoch 11
# Loss = 4.0569e-01, PNorm = 39.8467, GNorm = 0.6415, lr_0 = 7.9928e-04
# Loss = 3.8329e-01, PNorm = 39.9113, GNorm = 0.7242, lr_0 = 7.9260e-04
# Loss = 3.6431e-01, PNorm = 39.9799, GNorm = 0.9579, lr_0 = 7.8597e-04
# Validation prc-auc = 0.602602
#  12%|█▏        | 12/100 [00:20<02:35,  1.77s/it]Epoch 12
# Loss = 3.6172e-01, PNorm = 40.0485, GNorm = 1.0112, lr_0 = 7.7941e-04
# Loss = 3.7937e-01, PNorm = 40.0966, GNorm = 0.8548, lr_0 = 7.7289e-04
# Loss = 3.7026e-01, PNorm = 40.1621, GNorm = 0.4482, lr_0 = 7.6643e-04
# Validation prc-auc = 0.594896
#  13%|█▎        | 13/100 [00:21<02:28,  1.71s/it]Epoch 13
# Loss = 3.5260e-01, PNorm = 40.2334, GNorm = 0.5029, lr_0 = 7.5939e-04
# Loss = 3.5992e-01, PNorm = 40.2938, GNorm = 0.5287, lr_0 = 7.5305e-04
# Loss = 3.5382e-01, PNorm = 40.3573, GNorm = 0.4802, lr_0 = 7.4675e-04
# Validation prc-auc = 0.600161
#  14%|█▍        | 14/100 [00:23<02:23,  1.67s/it]Epoch 14
# Loss = 3.5073e-01, PNorm = 40.4342, GNorm = 1.1024, lr_0 = 7.4051e-04
# Loss = 3.6730e-01, PNorm = 40.5054, GNorm = 2.4472, lr_0 = 7.3433e-04
# Loss = 3.6020e-01, PNorm = 40.5948, GNorm = 1.3374, lr_0 = 7.2819e-04
# Validation prc-auc = 0.634830
#  15%|█▌        | 15/100 [00:24<02:23,  1.68s/it]Epoch 15
# Loss = 3.8581e-01, PNorm = 40.6529, GNorm = 0.7902, lr_0 = 7.2211e-04
# Loss = 3.4925e-01, PNorm = 40.7230, GNorm = 1.3144, lr_0 = 7.1607e-04
# Loss = 3.1905e-01, PNorm = 40.7939, GNorm = 0.4423, lr_0 = 7.1009e-04
# Validation prc-auc = 0.629272
#  16%|█▌        | 16/100 [00:26<02:16,  1.62s/it]Epoch 16
# Loss = 3.3349e-01, PNorm = 40.8579, GNorm = 0.6245, lr_0 = 7.0415e-04
# Loss = 3.2436e-01, PNorm = 40.9281, GNorm = 0.6104, lr_0 = 6.9827e-04
# Loss = 3.5454e-01, PNorm = 41.0104, GNorm = 0.4607, lr_0 = 6.9243e-04
# Validation prc-auc = 0.613180
#  17%|█▋        | 17/100 [00:27<02:11,  1.59s/it]Epoch 17
# Loss = 3.1364e-01, PNorm = 41.0906, GNorm = 0.7551, lr_0 = 6.8665e-04
# Loss = 3.3323e-01, PNorm = 41.1567, GNorm = 0.5937, lr_0 = 6.8091e-04
# Validation prc-auc = 0.656903
#  18%|█▊        | 18/100 [00:29<02:13,  1.63s/it]Epoch 18
# Loss = 3.6848e-01, PNorm = 41.2268, GNorm = 0.8297, lr_0 = 6.7522e-04
# Loss = 3.1338e-01, PNorm = 41.2964, GNorm = 0.9249, lr_0 = 6.6958e-04
# Loss = 3.1132e-01, PNorm = 41.3689, GNorm = 0.6277, lr_0 = 6.6398e-04
# Validation prc-auc = 0.661910
#  19%|█▉        | 19/100 [00:31<02:08,  1.59s/it]Epoch 19
# Loss = 2.6872e-01, PNorm = 41.4560, GNorm = 0.5527, lr_0 = 6.5788e-04
# Loss = 2.7579e-01, PNorm = 41.5415, GNorm = 1.3832, lr_0 = 6.5239e-04
# Loss = 3.3589e-01, PNorm = 41.6322, GNorm = 1.1848, lr_0 = 6.4693e-04
# Validation prc-auc = 0.670695
#  20%|██        | 20/100 [00:32<02:05,  1.57s/it]Epoch 20
# Loss = 2.4885e-01, PNorm = 41.7147, GNorm = 0.7945, lr_0 = 6.4153e-04
# Loss = 3.3136e-01, PNorm = 41.8067, GNorm = 0.5327, lr_0 = 6.3617e-04
# Loss = 3.0199e-01, PNorm = 41.8866, GNorm = 0.7860, lr_0 = 6.3085e-04
# Validation prc-auc = 0.654269
#  21%|██        | 21/100 [00:34<02:01,  1.53s/it]Epoch 21
# Loss = 3.0612e-01, PNorm = 41.9566, GNorm = 0.7620, lr_0 = 6.2558e-04
# Loss = 2.8385e-01, PNorm = 42.0249, GNorm = 0.5325, lr_0 = 6.2035e-04
# Loss = 2.9370e-01, PNorm = 42.0981, GNorm = 0.6151, lr_0 = 6.1517e-04
# Validation prc-auc = 0.650670
#  22%|██▏       | 22/100 [00:35<01:58,  1.52s/it]Epoch 22
# Loss = 2.9012e-01, PNorm = 42.1759, GNorm = 1.2360, lr_0 = 6.1003e-04
# Loss = 2.7557e-01, PNorm = 42.2511, GNorm = 1.0635, lr_0 = 6.0493e-04
# Loss = 3.0252e-01, PNorm = 42.3073, GNorm = 1.1761, lr_0 = 5.9988e-04
# Validation prc-auc = 0.646697
#  23%|██▎       | 23/100 [00:37<01:56,  1.51s/it]Epoch 23
# Loss = 2.8455e-01, PNorm = 42.3802, GNorm = 1.8065, lr_0 = 5.9486e-04
# Loss = 2.6158e-01, PNorm = 42.4650, GNorm = 0.6535, lr_0 = 5.8989e-04
# Loss = 2.4973e-01, PNorm = 42.5466, GNorm = 0.7682, lr_0 = 5.8496e-04
# Validation prc-auc = 0.656020
#  24%|██▍       | 24/100 [00:38<01:54,  1.50s/it]Epoch 24
# Loss = 2.4701e-01, PNorm = 42.6227, GNorm = 0.9896, lr_0 = 5.8007e-04
# Loss = 2.5983e-01, PNorm = 42.6983, GNorm = 1.5700, lr_0 = 5.7523e-04
# Loss = 2.4469e-01, PNorm = 42.7811, GNorm = 0.8080, lr_0 = 5.7042e-04
# Validation prc-auc = 0.643065
#  25%|██▌       | 25/100 [00:39<01:51,  1.49s/it]Epoch 25
# Loss = 2.3000e-01, PNorm = 42.8760, GNorm = 0.7309, lr_0 = 5.6565e-04
# Loss = 2.2863e-01, PNorm = 42.9585, GNorm = 0.9677, lr_0 = 5.6093e-04
# Validation prc-auc = 0.659681
#  26%|██▌       | 26/100 [00:41<01:50,  1.50s/it]Epoch 26
# Loss = 2.7268e-01, PNorm = 43.0385, GNorm = 1.6362, lr_0 = 5.5577e-04
# Loss = 2.1099e-01, PNorm = 43.1138, GNorm = 0.5103, lr_0 = 5.5113e-04
# Loss = 2.3304e-01, PNorm = 43.1882, GNorm = 0.7252, lr_0 = 5.4652e-04
# Validation prc-auc = 0.675367
#  27%|██▋       | 27/100 [00:43<01:53,  1.55s/it]Epoch 27
# Loss = 2.7309e-01, PNorm = 43.2560, GNorm = 0.9019, lr_0 = 5.4196e-04
# Loss = 2.2149e-01, PNorm = 43.3426, GNorm = 0.6093, lr_0 = 5.3743e-04
# Loss = 2.4627e-01, PNorm = 43.4187, GNorm = 0.7459, lr_0 = 5.3294e-04
# Validation prc-auc = 0.690704
#  28%|██▊       | 28/100 [00:44<01:50,  1.54s/it]Epoch 28
# Loss = 2.6883e-01, PNorm = 43.4850, GNorm = 1.0483, lr_0 = 5.2848e-04
# Loss = 2.3172e-01, PNorm = 43.5547, GNorm = 1.4140, lr_0 = 5.2407e-04
# Loss = 1.9913e-01, PNorm = 43.6202, GNorm = 1.0220, lr_0 = 5.1969e-04
# Validation prc-auc = 0.652783
#  29%|██▉       | 29/100 [00:46<01:48,  1.53s/it]Epoch 29
# Loss = 2.0353e-01, PNorm = 43.6881, GNorm = 0.6919, lr_0 = 5.1535e-04
# Loss = 2.4934e-01, PNorm = 43.7590, GNorm = 0.6657, lr_0 = 5.1104e-04
# Loss = 1.9014e-01, PNorm = 43.8147, GNorm = 1.1516, lr_0 = 5.0677e-04
# Validation prc-auc = 0.679982
#  30%|███       | 30/100 [00:47<01:45,  1.51s/it]Epoch 30
# Loss = 1.9246e-01, PNorm = 43.8744, GNorm = 1.8092, lr_0 = 5.0253e-04
# Loss = 2.0324e-01, PNorm = 43.9268, GNorm = 1.3147, lr_0 = 4.9834e-04
# Loss = 1.9230e-01, PNorm = 43.9896, GNorm = 0.9166, lr_0 = 4.9417e-04
# Validation prc-auc = 0.654738
#  31%|███       | 31/100 [00:49<01:43,  1.50s/it]Epoch 31
# Loss = 1.6445e-01, PNorm = 44.0565, GNorm = 1.2045, lr_0 = 4.9004e-04
# Loss = 1.8067e-01, PNorm = 44.1276, GNorm = 0.8885, lr_0 = 4.8595e-04
# Loss = 1.8226e-01, PNorm = 44.1853, GNorm = 0.8741, lr_0 = 4.8189e-04
# Validation prc-auc = 0.632321
#  32%|███▏      | 32/100 [00:50<01:41,  1.49s/it]Epoch 32
# Loss = 1.8989e-01, PNorm = 44.2463, GNorm = 1.4043, lr_0 = 4.7746e-04
# Loss = 1.8550e-01, PNorm = 44.3052, GNorm = 0.6920, lr_0 = 4.7347e-04
# Loss = 2.0783e-01, PNorm = 44.3614, GNorm = 1.3532, lr_0 = 4.6951e-04
# Validation prc-auc = 0.635175
#  33%|███▎      | 33/100 [00:52<01:39,  1.48s/it]Epoch 33
# Loss = 2.1265e-01, PNorm = 44.4167, GNorm = 1.8228, lr_0 = 4.6559e-04
# Loss = 1.5406e-01, PNorm = 44.4684, GNorm = 0.6910, lr_0 = 4.6170e-04
# Loss = 1.7157e-01, PNorm = 44.5228, GNorm = 0.9184, lr_0 = 4.5784e-04
# Validation prc-auc = 0.652239
#  34%|███▍      | 34/100 [00:53<01:38,  1.49s/it]Epoch 34
# Loss = 1.6248e-01, PNorm = 44.5777, GNorm = 1.2788, lr_0 = 4.5401e-04
# Loss = 2.1159e-01, PNorm = 44.6258, GNorm = 1.7089, lr_0 = 4.5022e-04
# Validation prc-auc = 0.634993
#  35%|███▌      | 35/100 [00:55<01:39,  1.53s/it]Epoch 35
# Loss = 1.0607e-01, PNorm = 44.6925, GNorm = 0.5523, lr_0 = 4.4646e-04
# Loss = 1.5907e-01, PNorm = 44.7397, GNorm = 1.5035, lr_0 = 4.4273e-04
# Loss = 1.5943e-01, PNorm = 44.7889, GNorm = 0.9440, lr_0 = 4.3903e-04
# Validation prc-auc = 0.642214
#  36%|███▌      | 36/100 [00:56<01:36,  1.51s/it]Epoch 36
# Loss = 1.4369e-01, PNorm = 44.8384, GNorm = 1.1241, lr_0 = 4.3536e-04
# Loss = 1.2616e-01, PNorm = 44.8787, GNorm = 1.4610, lr_0 = 4.3172e-04
# Loss = 1.7843e-01, PNorm = 44.9172, GNorm = 1.3523, lr_0 = 4.2811e-04
# Validation prc-auc = 0.662367
#  37%|███▋      | 37/100 [00:58<01:34,  1.50s/it]Epoch 37
# Loss = 1.7684e-01, PNorm = 44.9614, GNorm = 1.9806, lr_0 = 4.2454e-04
# Loss = 1.3874e-01, PNorm = 45.0084, GNorm = 1.0118, lr_0 = 4.2099e-04
# Loss = 1.9323e-01, PNorm = 45.0604, GNorm = 1.8018, lr_0 = 4.1747e-04
# Validation prc-auc = 0.665599
#  38%|███▊      | 38/100 [00:59<01:32,  1.49s/it]Epoch 38
# Loss = 1.7747e-01, PNorm = 45.1165, GNorm = 1.9788, lr_0 = 4.1364e-04
# Loss = 1.5131e-01, PNorm = 45.1610, GNorm = 1.2700, lr_0 = 4.1018e-04
# Loss = 1.3607e-01, PNorm = 45.1966, GNorm = 0.8951, lr_0 = 4.0675e-04
# Validation prc-auc = 0.646443
#  39%|███▉      | 39/100 [01:01<01:30,  1.49s/it]Epoch 39
# Loss = 1.5133e-01, PNorm = 45.2434, GNorm = 1.2889, lr_0 = 4.0335e-04
# Loss = 1.5359e-01, PNorm = 45.2815, GNorm = 1.9281, lr_0 = 3.9998e-04
# Loss = 1.2322e-01, PNorm = 45.3174, GNorm = 1.2450, lr_0 = 3.9664e-04
# Validation prc-auc = 0.630302
#  40%|████      | 40/100 [01:02<01:28,  1.48s/it]Epoch 40
# Loss = 1.3452e-01, PNorm = 45.3534, GNorm = 1.4174, lr_0 = 3.9333e-04
# Loss = 1.4545e-01, PNorm = 45.3946, GNorm = 1.5416, lr_0 = 3.9004e-04
# Loss = 1.3744e-01, PNorm = 45.4248, GNorm = 1.0318, lr_0 = 3.8678e-04
# Validation prc-auc = 0.620964
#  41%|████      | 41/100 [01:03<01:26,  1.47s/it]Epoch 41
# Loss = 1.0335e-01, PNorm = 45.4598, GNorm = 0.9615, lr_0 = 3.8355e-04
# Loss = 1.3636e-01, PNorm = 45.5026, GNorm = 1.0840, lr_0 = 3.8034e-04
# Loss = 1.5398e-01, PNorm = 45.5432, GNorm = 1.0909, lr_0 = 3.7716e-04
# Validation prc-auc = 0.650325
#  42%|████▏     | 42/100 [01:05<01:25,  1.48s/it]Epoch 42
# Loss = 9.7371e-02, PNorm = 45.5791, GNorm = 0.6429, lr_0 = 3.7401e-04
# Loss = 1.0065e-01, PNorm = 45.6169, GNorm = 0.9577, lr_0 = 3.7089e-04
# Loss = 1.6236e-01, PNorm = 45.6616, GNorm = 2.6112, lr_0 = 3.6779e-04
# Validation prc-auc = 0.614122
#  43%|████▎     | 43/100 [01:07<01:27,  1.54s/it]Epoch 43
# Loss = 1.2788e-01, PNorm = 45.6917, GNorm = 1.0915, lr_0 = 3.6471e-04
# Loss = 1.3418e-01, PNorm = 45.7304, GNorm = 0.9512, lr_0 = 3.6167e-04
# Validation prc-auc = 0.612838
#  44%|████▍     | 44/100 [01:08<01:25,  1.53s/it]Epoch 44
# Loss = 9.8721e-02, PNorm = 45.7588, GNorm = 0.9065, lr_0 = 3.5834e-04
# Loss = 1.1736e-01, PNorm = 45.7998, GNorm = 1.3196, lr_0 = 3.5535e-04
# Loss = 1.1034e-01, PNorm = 45.8311, GNorm = 1.6063, lr_0 = 3.5238e-04
# Validation prc-auc = 0.636941
#  45%|████▌     | 45/100 [01:10<01:23,  1.52s/it]Epoch 45
# Loss = 6.2198e-02, PNorm = 45.8549, GNorm = 0.7187, lr_0 = 3.4944e-04
# Loss = 1.3183e-01, PNorm = 45.8907, GNorm = 1.5346, lr_0 = 3.4652e-04
# Loss = 1.2121e-01, PNorm = 45.9205, GNorm = 1.4419, lr_0 = 3.4362e-04
# Validation prc-auc = 0.622586
#  46%|████▌     | 46/100 [01:11<01:22,  1.52s/it]Epoch 46
# Loss = 9.3605e-02, PNorm = 45.9533, GNorm = 1.3962, lr_0 = 3.4075e-04
# Loss = 8.7572e-02, PNorm = 45.9808, GNorm = 0.6437, lr_0 = 3.3790e-04
# Loss = 1.0627e-01, PNorm = 46.0155, GNorm = 1.1303, lr_0 = 3.3508e-04
# Validation prc-auc = 0.626012
#  47%|████▋     | 47/100 [01:13<01:20,  1.52s/it]Epoch 47
# Loss = 8.6642e-02, PNorm = 46.0454, GNorm = 1.3302, lr_0 = 3.3228e-04
# Loss = 1.0940e-01, PNorm = 46.0715, GNorm = 1.4501, lr_0 = 3.2950e-04
# Loss = 9.3336e-02, PNorm = 46.0957, GNorm = 0.9251, lr_0 = 3.2675e-04
# Validation prc-auc = 0.622233
#  48%|████▊     | 48/100 [01:14<01:20,  1.55s/it]Epoch 48
# Loss = 8.3350e-02, PNorm = 46.1250, GNorm = 0.9024, lr_0 = 3.2402e-04
# Loss = 7.1102e-02, PNorm = 46.1522, GNorm = 1.2532, lr_0 = 3.2131e-04
# Loss = 1.0750e-01, PNorm = 46.1750, GNorm = 1.6396, lr_0 = 3.1863e-04
# Validation prc-auc = 0.597424
#  49%|████▉     | 49/100 [01:16<01:18,  1.54s/it]Epoch 49
# Loss = 1.0759e-01, PNorm = 46.2051, GNorm = 1.0854, lr_0 = 3.1596e-04
# Loss = 9.2583e-02, PNorm = 46.2332, GNorm = 0.8390, lr_0 = 3.1332e-04
# Loss = 9.8646e-02, PNorm = 46.2596, GNorm = 1.2984, lr_0 = 3.1070e-04
# Validation prc-auc = 0.622731
#  50%|█████     | 50/100 [01:17<01:17,  1.55s/it]Epoch 50
# Loss = 9.0968e-02, PNorm = 46.2818, GNorm = 1.9729, lr_0 = 3.0811e-04
# Loss = 9.6455e-02, PNorm = 46.3044, GNorm = 1.3508, lr_0 = 3.0553e-04
# Loss = 9.4769e-02, PNorm = 46.3327, GNorm = 1.5193, lr_0 = 3.0298e-04
# Loss = 1.7528e-01, PNorm = 46.3340, GNorm = 2.6910, lr_0 = 3.0273e-04
# Validation prc-auc = 0.600745
#  51%|█████     | 51/100 [01:19<01:17,  1.59s/it]Epoch 51
# Loss = 8.4938e-02, PNorm = 46.3572, GNorm = 1.0074, lr_0 = 3.0020e-04
# Loss = 7.8557e-02, PNorm = 46.3838, GNorm = 0.8891, lr_0 = 2.9769e-04
# Validation prc-auc = 0.633971
#  52%|█████▏    | 52/100 [01:21<01:15,  1.57s/it]Epoch 52
# Loss = 6.9619e-02, PNorm = 46.4065, GNorm = 0.9268, lr_0 = 2.9520e-04
# Loss = 7.0184e-02, PNorm = 46.4327, GNorm = 1.2110, lr_0 = 2.9273e-04
# Loss = 9.3785e-02, PNorm = 46.4574, GNorm = 2.1942, lr_0 = 2.9029e-04
# Validation prc-auc = 0.583955
#  53%|█████▎    | 53/100 [01:22<01:13,  1.56s/it]Epoch 53
# Loss = 1.0405e-01, PNorm = 46.4760, GNorm = 1.8110, lr_0 = 2.8786e-04
# Loss = 5.4687e-02, PNorm = 46.5017, GNorm = 1.2497, lr_0 = 2.8546e-04
# Loss = 1.1843e-01, PNorm = 46.5188, GNorm = 1.4804, lr_0 = 2.8307e-04
# Validation prc-auc = 0.586032
#  54%|█████▍    | 54/100 [01:24<01:11,  1.55s/it]Epoch 54
# Loss = 8.1614e-02, PNorm = 46.5390, GNorm = 0.9979, lr_0 = 2.8071e-04
# Loss = 7.4389e-02, PNorm = 46.5730, GNorm = 1.0178, lr_0 = 2.7836e-04
# Loss = 7.2267e-02, PNorm = 46.5925, GNorm = 1.1109, lr_0 = 2.7603e-04
# Validation prc-auc = 0.600714
#  55%|█████▌    | 55/100 [01:25<01:09,  1.54s/it]Epoch 55
# Loss = 9.0190e-02, PNorm = 46.6123, GNorm = 3.2433, lr_0 = 2.7373e-04
# Loss = 6.5996e-02, PNorm = 46.6404, GNorm = 1.5280, lr_0 = 2.7144e-04
# Loss = 9.2833e-02, PNorm = 46.6594, GNorm = 2.3051, lr_0 = 2.6917e-04
# Validation prc-auc = 0.609479
#  56%|█████▌    | 56/100 [01:27<01:08,  1.55s/it]Epoch 56
# Loss = 8.8755e-02, PNorm = 46.6795, GNorm = 0.7833, lr_0 = 2.6692e-04
# Loss = 7.0581e-02, PNorm = 46.6999, GNorm = 0.3597, lr_0 = 2.6469e-04
# Loss = 8.6600e-02, PNorm = 46.7131, GNorm = 2.0453, lr_0 = 2.6248e-04
# Validation prc-auc = 0.599050
#  57%|█████▋    | 57/100 [01:28<01:06,  1.54s/it]Epoch 57
# Loss = 9.7233e-02, PNorm = 46.7284, GNorm = 0.5627, lr_0 = 2.6007e-04
# Loss = 8.9121e-02, PNorm = 46.7462, GNorm = 1.1354, lr_0 = 2.5790e-04
# Loss = 9.9437e-02, PNorm = 46.7711, GNorm = 3.1805, lr_0 = 2.5574e-04
# Validation prc-auc = 0.601955
#  58%|█████▊    | 58/100 [01:30<01:04,  1.54s/it]Epoch 58
# Loss = 8.0649e-02, PNorm = 46.7830, GNorm = 1.7326, lr_0 = 2.5360e-04
# Loss = 6.1473e-02, PNorm = 46.8082, GNorm = 1.2251, lr_0 = 2.5148e-04
# Loss = 7.6247e-02, PNorm = 46.8275, GNorm = 0.9243, lr_0 = 2.4938e-04
# Validation prc-auc = 0.594590
#  59%|█████▉    | 59/100 [01:32<01:05,  1.60s/it]Epoch 59
# Loss = 6.6292e-02, PNorm = 46.8543, GNorm = 1.5151, lr_0 = 2.4730e-04
# Loss = 6.5575e-02, PNorm = 46.8623, GNorm = 0.8365, lr_0 = 2.4523e-04
# Loss = 8.5971e-02, PNorm = 46.8845, GNorm = 0.7121, lr_0 = 2.4318e-04
# Validation prc-auc = 0.607132
#  60%|██████    | 60/100 [01:33<01:03,  1.59s/it]Epoch 60
# Loss = 7.0917e-02, PNorm = 46.9018, GNorm = 2.0303, lr_0 = 2.4115e-04
# Loss = 6.8608e-02, PNorm = 46.9218, GNorm = 0.6248, lr_0 = 2.3914e-04
# Validation prc-auc = 0.611960
#  61%|██████    | 61/100 [01:35<01:01,  1.57s/it]Epoch 61
# Loss = 6.4729e-02, PNorm = 46.9349, GNorm = 0.8689, lr_0 = 2.3714e-04
# Loss = 4.8981e-02, PNorm = 46.9486, GNorm = 1.3161, lr_0 = 2.3516e-04
# Loss = 5.5184e-02, PNorm = 46.9630, GNorm = 2.4913, lr_0 = 2.3319e-04
# Validation prc-auc = 0.617971
#  62%|██████▏   | 62/100 [01:36<00:59,  1.56s/it]Epoch 62
# Loss = 7.2851e-02, PNorm = 46.9785, GNorm = 1.5893, lr_0 = 2.3124e-04
# Loss = 6.5946e-02, PNorm = 46.9891, GNorm = 1.6815, lr_0 = 2.2931e-04
# Loss = 7.1251e-02, PNorm = 47.0042, GNorm = 1.4178, lr_0 = 2.2739e-04
# Validation prc-auc = 0.599264
#  63%|██████▎   | 63/100 [01:38<00:57,  1.55s/it]Epoch 63
# Loss = 5.4068e-02, PNorm = 47.0303, GNorm = 1.8634, lr_0 = 2.2530e-04
# Loss = 7.0656e-02, PNorm = 47.0447, GNorm = 0.5881, lr_0 = 2.2342e-04
# Loss = 5.2405e-02, PNorm = 47.0637, GNorm = 1.2201, lr_0 = 2.2155e-04
# Validation prc-auc = 0.589454
#  64%|██████▍   | 64/100 [01:39<00:55,  1.54s/it]Epoch 64
# Loss = 7.3558e-02, PNorm = 47.0810, GNorm = 1.4395, lr_0 = 2.1970e-04
# Loss = 5.2668e-02, PNorm = 47.0953, GNorm = 2.1723, lr_0 = 2.1787e-04
# Loss = 5.8956e-02, PNorm = 47.1051, GNorm = 0.6190, lr_0 = 2.1605e-04
# Validation prc-auc = 0.604881
#  65%|██████▌   | 65/100 [01:41<00:54,  1.54s/it]Epoch 65
# Loss = 4.1394e-02, PNorm = 47.1223, GNorm = 0.6033, lr_0 = 2.1424e-04
# Loss = 8.0502e-02, PNorm = 47.1235, GNorm = 2.5864, lr_0 = 2.1245e-04
# Loss = 7.1421e-02, PNorm = 47.1399, GNorm = 0.6147, lr_0 = 2.1068e-04
# Validation prc-auc = 0.585762
#  66%|██████▌   | 66/100 [01:42<00:53,  1.58s/it]Epoch 66
# Loss = 4.6470e-02, PNorm = 47.1574, GNorm = 0.5201, lr_0 = 2.0892e-04
# Loss = 5.4265e-02, PNorm = 47.1648, GNorm = 1.7628, lr_0 = 2.0717e-04
# Loss = 6.4251e-02, PNorm = 47.1794, GNorm = 0.6668, lr_0 = 2.0544e-04
# Validation prc-auc = 0.595224
#  67%|██████▋   | 67/100 [01:44<00:53,  1.62s/it]Epoch 67
# Loss = 5.6687e-02, PNorm = 47.1904, GNorm = 1.6130, lr_0 = 2.0372e-04
# Loss = 6.3394e-02, PNorm = 47.2075, GNorm = 1.3266, lr_0 = 2.0202e-04
# Loss = 5.9178e-02, PNorm = 47.2131, GNorm = 1.3051, lr_0 = 2.0033e-04
# Validation prc-auc = 0.585411
#  68%|██████▊   | 68/100 [01:46<00:51,  1.61s/it]Epoch 68
# Loss = 8.1537e-02, PNorm = 47.2325, GNorm = 1.9256, lr_0 = 1.9866e-04
# Loss = 7.9903e-02, PNorm = 47.2442, GNorm = 0.4559, lr_0 = 1.9700e-04
# Validation prc-auc = 0.603083
#  69%|██████▉   | 69/100 [01:47<00:49,  1.59s/it]Epoch 69
# Loss = 8.5830e-02, PNorm = 47.2552, GNorm = 1.4864, lr_0 = 1.9519e-04
# Loss = 4.8655e-02, PNorm = 47.2713, GNorm = 0.5815, lr_0 = 1.9356e-04
# Loss = 5.6764e-02, PNorm = 47.2869, GNorm = 0.6831, lr_0 = 1.9194e-04
# Validation prc-auc = 0.581626
#  70%|███████   | 70/100 [01:49<00:47,  1.59s/it]Epoch 70
# Loss = 4.4094e-02, PNorm = 47.2978, GNorm = 0.7158, lr_0 = 1.9034e-04
# Loss = 4.0543e-02, PNorm = 47.3061, GNorm = 0.4533, lr_0 = 1.8874e-04
# Loss = 5.9768e-02, PNorm = 47.3242, GNorm = 1.1016, lr_0 = 1.8717e-04
# Validation prc-auc = 0.593577
#  71%|███████   | 71/100 [01:50<00:45,  1.58s/it]Epoch 71
# Loss = 4.5434e-02, PNorm = 47.3353, GNorm = 1.6025, lr_0 = 1.8560e-04
# Loss = 5.3016e-02, PNorm = 47.3458, GNorm = 0.3019, lr_0 = 1.8405e-04
# Loss = 6.4760e-02, PNorm = 47.3581, GNorm = 1.1746, lr_0 = 1.8251e-04
# Validation prc-auc = 0.596725
#  72%|███████▏  | 72/100 [01:52<00:43,  1.57s/it]Epoch 72
# Loss = 3.0051e-02, PNorm = 47.3676, GNorm = 0.5887, lr_0 = 1.8099e-04
# Loss = 5.9782e-02, PNorm = 47.3690, GNorm = 2.2897, lr_0 = 1.7948e-04
# Loss = 6.9900e-02, PNorm = 47.3909, GNorm = 3.1914, lr_0 = 1.7798e-04
# Validation prc-auc = 0.607950
#  73%|███████▎  | 73/100 [01:54<00:42,  1.58s/it]Epoch 73
# Loss = 8.2619e-02, PNorm = 47.3980, GNorm = 1.5981, lr_0 = 1.7649e-04
# Loss = 4.5284e-02, PNorm = 47.4110, GNorm = 0.2209, lr_0 = 1.7502e-04
# Loss = 6.9418e-02, PNorm = 47.4172, GNorm = 1.0023, lr_0 = 1.7355e-04
# Validation prc-auc = 0.583435
#  74%|███████▍  | 74/100 [01:55<00:41,  1.58s/it]Epoch 74
# Loss = 6.2906e-02, PNorm = 47.4272, GNorm = 1.1913, lr_0 = 1.7210e-04
# Loss = 4.3646e-02, PNorm = 47.4392, GNorm = 1.0261, lr_0 = 1.7066e-04
# Loss = 5.2339e-02, PNorm = 47.4478, GNorm = 0.8993, lr_0 = 1.6924e-04
# Validation prc-auc = 0.600253
#  75%|███████▌  | 75/100 [01:57<00:40,  1.62s/it]Epoch 75
# Loss = 3.4449e-02, PNorm = 47.4568, GNorm = 0.7409, lr_0 = 1.6782e-04
# Loss = 3.7399e-02, PNorm = 47.4689, GNorm = 1.3314, lr_0 = 1.6642e-04
# Loss = 4.7175e-02, PNorm = 47.4768, GNorm = 0.9274, lr_0 = 1.6503e-04
# Validation prc-auc = 0.608456
#  76%|███████▌  | 76/100 [01:59<00:39,  1.63s/it]Epoch 76
# Loss = 5.0141e-02, PNorm = 47.4909, GNorm = 0.0741, lr_0 = 1.6351e-04
# Loss = 4.2469e-02, PNorm = 47.4938, GNorm = 1.2759, lr_0 = 1.6215e-04
# Loss = 6.4362e-02, PNorm = 47.5046, GNorm = 3.2468, lr_0 = 1.6079e-04
# Validation prc-auc = 0.601587
#  77%|███████▋  | 77/100 [02:00<00:36,  1.59s/it]Epoch 77
# Loss = 5.3112e-02, PNorm = 47.5065, GNorm = 1.8005, lr_0 = 1.5945e-04
# Loss = 6.6479e-02, PNorm = 47.5056, GNorm = 0.8335, lr_0 = 1.5812e-04
# Validation prc-auc = 0.585594
#  78%|███████▊  | 78/100 [02:02<00:34,  1.58s/it]Epoch 78
# Loss = 2.2389e-02, PNorm = 47.5247, GNorm = 0.7414, lr_0 = 1.5680e-04
# Loss = 5.4298e-02, PNorm = 47.5213, GNorm = 2.0283, lr_0 = 1.5549e-04
# Loss = 4.5102e-02, PNorm = 47.5416, GNorm = 0.8810, lr_0 = 1.5419e-04
# Validation prc-auc = 0.601161
#  79%|███████▉  | 79/100 [02:03<00:33,  1.58s/it]Epoch 79
# Loss = 1.7109e-02, PNorm = 47.5432, GNorm = 0.4162, lr_0 = 1.5290e-04
# Loss = 3.3072e-02, PNorm = 47.5549, GNorm = 0.4734, lr_0 = 1.5162e-04
# Loss = 6.5460e-02, PNorm = 47.5605, GNorm = 1.1838, lr_0 = 1.5035e-04
# Validation prc-auc = 0.605419
#  80%|████████  | 80/100 [02:05<00:31,  1.58s/it]Epoch 80
# Loss = 3.3933e-02, PNorm = 47.5719, GNorm = 1.2158, lr_0 = 1.4910e-04
# Loss = 5.8323e-02, PNorm = 47.5811, GNorm = 2.0206, lr_0 = 1.4785e-04
# Loss = 5.7418e-02, PNorm = 47.5906, GNorm = 1.0933, lr_0 = 1.4662e-04
# Validation prc-auc = 0.607389
#  81%|████████  | 81/100 [02:06<00:29,  1.57s/it]Epoch 81
# Loss = 6.1921e-02, PNorm = 47.5916, GNorm = 1.1759, lr_0 = 1.4539e-04
# Loss = 6.3231e-02, PNorm = 47.6052, GNorm = 3.2676, lr_0 = 1.4418e-04
# Loss = 5.2387e-02, PNorm = 47.6120, GNorm = 0.7620, lr_0 = 1.4297e-04
# Validation prc-auc = 0.588045
#  82%|████████▏ | 82/100 [02:08<00:28,  1.57s/it]Epoch 82
# Loss = 4.6344e-02, PNorm = 47.6212, GNorm = 0.6413, lr_0 = 1.4166e-04
# Loss = 3.9628e-02, PNorm = 47.6270, GNorm = 1.2182, lr_0 = 1.4047e-04
# Loss = 5.1193e-02, PNorm = 47.6316, GNorm = 0.2554, lr_0 = 1.3930e-04
# Validation prc-auc = 0.592123
#  83%|████████▎ | 83/100 [02:10<00:27,  1.61s/it]Epoch 83
# Loss = 4.1241e-02, PNorm = 47.6379, GNorm = 0.2059, lr_0 = 1.3814e-04
# Loss = 3.0558e-02, PNorm = 47.6454, GNorm = 0.6033, lr_0 = 1.3698e-04
# Loss = 4.8052e-02, PNorm = 47.6514, GNorm = 2.1013, lr_0 = 1.3584e-04
# Validation prc-auc = 0.588389
#  84%|████████▍ | 84/100 [02:11<00:25,  1.59s/it]Epoch 84
# Loss = 5.7868e-02, PNorm = 47.6589, GNorm = 1.7590, lr_0 = 1.3470e-04
# Loss = 4.6493e-02, PNorm = 47.6611, GNorm = 1.1852, lr_0 = 1.3358e-04
# Loss = 4.8865e-02, PNorm = 47.6713, GNorm = 1.7535, lr_0 = 1.3246e-04
# Validation prc-auc = 0.596597
#  85%|████████▌ | 85/100 [02:13<00:23,  1.58s/it]Epoch 85
# Loss = 3.1635e-02, PNorm = 47.6742, GNorm = 0.8994, lr_0 = 1.3135e-04
# Loss = 3.8270e-02, PNorm = 47.6868, GNorm = 1.8540, lr_0 = 1.3026e-04
# Loss = 4.1162e-02, PNorm = 47.6906, GNorm = 2.5718, lr_0 = 1.2917e-04
# Validation prc-auc = 0.599277
#  86%|████████▌ | 86/100 [02:14<00:22,  1.58s/it]Epoch 86
# Loss = 5.3463e-02, PNorm = 47.6952, GNorm = 2.7804, lr_0 = 1.2809e-04
# Loss = 4.7257e-02, PNorm = 47.7066, GNorm = 1.7793, lr_0 = 1.2702e-04
# Validation prc-auc = 0.593171
#  87%|████████▋ | 87/100 [02:16<00:20,  1.56s/it]Epoch 87
# Loss = 8.3426e-02, PNorm = 47.7075, GNorm = 2.2929, lr_0 = 1.2596e-04
# Loss = 4.8308e-02, PNorm = 47.7183, GNorm = 0.6900, lr_0 = 1.2490e-04
# Loss = 4.1030e-02, PNorm = 47.7222, GNorm = 1.5160, lr_0 = 1.2386e-04
# Validation prc-auc = 0.592350
#  88%|████████▊ | 88/100 [02:17<00:18,  1.57s/it]Epoch 88
# Loss = 3.3629e-02, PNorm = 47.7297, GNorm = 1.0513, lr_0 = 1.2272e-04
# Loss = 3.6809e-02, PNorm = 47.7346, GNorm = 1.0382, lr_0 = 1.2170e-04
# Loss = 2.8736e-02, PNorm = 47.7379, GNorm = 1.7130, lr_0 = 1.2068e-04
# Validation prc-auc = 0.585385
#  89%|████████▉ | 89/100 [02:19<00:17,  1.58s/it]Epoch 89
# Loss = 3.3704e-02, PNorm = 47.7412, GNorm = 0.9226, lr_0 = 1.1967e-04
# Loss = 3.3990e-02, PNorm = 47.7512, GNorm = 1.4850, lr_0 = 1.1867e-04
# Loss = 4.6529e-02, PNorm = 47.7552, GNorm = 0.5004, lr_0 = 1.1768e-04
# Validation prc-auc = 0.588569
#  90%|█████████ | 90/100 [02:21<00:15,  1.56s/it]Epoch 90
# Loss = 4.0256e-02, PNorm = 47.7639, GNorm = 1.0111, lr_0 = 1.1670e-04
# Loss = 4.3510e-02, PNorm = 47.7694, GNorm = 0.9921, lr_0 = 1.1572e-04
# Loss = 4.3568e-02, PNorm = 47.7740, GNorm = 1.2702, lr_0 = 1.1475e-04
# Validation prc-auc = 0.589786
#  91%|█████████ | 91/100 [02:22<00:14,  1.56s/it]Epoch 91
# Loss = 3.9701e-02, PNorm = 47.7767, GNorm = 0.7485, lr_0 = 1.1379e-04
# Loss = 5.3199e-02, PNorm = 47.7840, GNorm = 2.6013, lr_0 = 1.1284e-04
# Loss = 2.6751e-02, PNorm = 47.7867, GNorm = 1.7968, lr_0 = 1.1190e-04
# Validation prc-auc = 0.595595
#  92%|█████████▏| 92/100 [02:24<00:12,  1.62s/it]Epoch 92
# Loss = 3.1688e-02, PNorm = 47.7977, GNorm = 1.1007, lr_0 = 1.1097e-04
# Loss = 4.2598e-02, PNorm = 47.7964, GNorm = 1.6025, lr_0 = 1.1004e-04
# Loss = 4.7578e-02, PNorm = 47.8030, GNorm = 2.0210, lr_0 = 1.0912e-04
# Validation prc-auc = 0.591225
#  93%|█████████▎| 93/100 [02:25<00:11,  1.61s/it]Epoch 93
# Loss = 4.1054e-02, PNorm = 47.8089, GNorm = 0.0349, lr_0 = 1.0821e-04
# Loss = 3.4507e-02, PNorm = 47.8094, GNorm = 1.4941, lr_0 = 1.0730e-04
# Loss = 4.6338e-02, PNorm = 47.8213, GNorm = 1.2789, lr_0 = 1.0641e-04
# Loss = 1.3426e-01, PNorm = 47.8218, GNorm = 2.5270, lr_0 = 1.0632e-04
# Validation prc-auc = 0.583820
#  94%|█████████▍| 94/100 [02:27<00:09,  1.59s/it]Epoch 94
# Loss = 4.7408e-02, PNorm = 47.8216, GNorm = 0.9730, lr_0 = 1.0543e-04
# Loss = 4.0293e-02, PNorm = 47.8273, GNorm = 1.4127, lr_0 = 1.0455e-04
# Validation prc-auc = 0.585329
#  95%|█████████▌| 95/100 [02:28<00:07,  1.58s/it]Epoch 95
# Loss = 1.4193e-02, PNorm = 47.8365, GNorm = 0.5067, lr_0 = 1.0367e-04
# Loss = 4.0475e-02, PNorm = 47.8338, GNorm = 1.3294, lr_0 = 1.0281e-04
# Loss = 2.3493e-02, PNorm = 47.8429, GNorm = 0.1932, lr_0 = 1.0195e-04
# Validation prc-auc = 0.590012
#  96%|█████████▌| 96/100 [02:30<00:06,  1.56s/it]Epoch 96
# Loss = 5.5239e-02, PNorm = 47.8471, GNorm = 1.7978, lr_0 = 1.0110e-04
# Loss = 3.0791e-02, PNorm = 47.8541, GNorm = 0.8465, lr_0 = 1.0025e-04
# Loss = 4.7294e-02, PNorm = 47.8559, GNorm = 1.7837, lr_0 = 1.0000e-04
# Validation prc-auc = 0.585977
#  97%|█████████▋| 97/100 [02:32<00:04,  1.56s/it]Epoch 97
# Loss = 1.6540e-02, PNorm = 47.8651, GNorm = 0.1703, lr_0 = 1.0000e-04
# Loss = 3.9490e-02, PNorm = 47.8673, GNorm = 0.4196, lr_0 = 1.0000e-04
# Loss = 3.7408e-02, PNorm = 47.8705, GNorm = 1.3278, lr_0 = 1.0000e-04
# Validation prc-auc = 0.594674
#  98%|█████████▊| 98/100 [02:33<00:03,  1.56s/it]Epoch 98
# Loss = 3.7577e-02, PNorm = 47.8761, GNorm = 1.5511, lr_0 = 1.0000e-04
# Loss = 2.7796e-02, PNorm = 47.8836, GNorm = 0.2043, lr_0 = 1.0000e-04
# Loss = 3.7349e-02, PNorm = 47.8873, GNorm = 2.1124, lr_0 = 1.0000e-04
# Validation prc-auc = 0.596524
#  99%|█████████▉| 99/100 [02:35<00:01,  1.55s/it]Epoch 99
# Loss = 2.4342e-02, PNorm = 47.8878, GNorm = 0.5819, lr_0 = 1.0000e-04
# Loss = 4.1507e-02, PNorm = 47.8977, GNorm = 1.2705, lr_0 = 1.0000e-04
# Loss = 3.9016e-02, PNorm = 47.9013, GNorm = 1.6056, lr_0 = 1.0000e-04
# Validation prc-auc = 0.595188
# 100%|██████████| 100/100 [02:36<00:00,  1.57s/it]
# Model 0 best validation prc-auc = 0.690704 on epoch 27
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Moving model to cuda
# Model 0 test prc-auc = 0.690704
# Ensemble test prc-auc = 0.690704
# 1-fold cross validation
# 	Seed 0 ==> test prc-auc = 0.690704
# Overall test prc-auc = 0.690704 +/- 0.000000
# Elapsed time = 0:03:59

# %%
max_epoch = 27
