# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
import chemprop

# %%
import sys
sys.path.append('../../../../code')

from metrics import get_hi_metrics

def chemprop_prepare_df(original_data):
    result = pd.DataFrame({
        'smiles': original_data['smiles'],
        'targets': original_data['value'].astype(float)
    })
    return result

def chemprop_process_folder(input_path, output_path):
    files = ['train_1.csv', 'train_2.csv', 'train_3.csv', 'test_1.csv', 'test_2.csv', 'test_3.csv']
    for file in files:
        input_data = pd.read_csv(input_path + file)
        output_data = chemprop_prepare_df(input_data)
        output_data.to_csv(output_path + file, index=False)
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_geometric'
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (/home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/deepchem/models/torch_models/__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'pytorch_lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'

# %%
train = pd.read_csv('../../../../data/hi/kdr/train_1.csv')
test = pd.read_csv('../../../../data/hi/kdr/test_1.csv')

train
# Out:
#      Unnamed: 0                                             smiles  value
# 0             0     Brc1ccc(-c2nc3ccc(Nc4ccnc5ccccc45)cc3[nH]2)cc1   True
# 1          1064     CCc1ccc(-c2nc3ccc(Nc4ccnc5ccccc45)cc3[nH]2)cc1  False
# 2          1065     CCc1ccc(-c2nc3ccc(Nc4ncnc5ccccc45)cc3[nH]2)cc1  False
# 3          3722       COc1ccccc1-c1nc2ccc(Nc3ccnc4ccccc34)cc2[nH]1  False
# 4          4159      Cc1ccc(-c2nc3ccc(Nc4ccnc5ccccc45)cc3[nH]2)cc1  False
# ..          ...                                                ...    ...
# 495         454  CC(C)S(=O)(=O)c1ccccc1Nc1nc(Nc2cccc(NC(=O)CN)c...  False
# 496        1850       COC(=O)c1cn2ncnc(Oc3ccc4[nH]c(C)cc4c3F)c2c1C   True
# 497        4120  Cc1cc2c(F)c(Oc3ncnn4cc(OCCCNS(C)(=O)=O)c(C)c34...   True
# 498        2979  COc1cc2c(Oc3ccc(N/C=C4\C(=O)NC(=O)N(c5ccc(C)cc...   True
# 499        2986  COc1cc2c(Oc3ccc(NC(=O)NS(=O)(=O)Cc4ccc(F)cc4)c...   True
#
# [500 rows x 3 columns]

# %%
import os
import os
import shutil

temp_datapath = '/tmp/chemprop/'
if os.path.exists(temp_datapath) and os.path.isdir(temp_datapath):
    shutil.rmtree(temp_datapath)
os.mkdir(temp_datapath)

input_paths = [
    '/home/simon/papers/lohi/data/hi/kdr/'
]

output_paths = [
    temp_datapath
]

for i in range(len(input_paths)):
    chemprop_process_folder(input_paths[i], output_paths[i])

# %%
base_arguments = [
    '--dataset_type', 'classification', 
    '--data_path', temp_datapath + 'train_1.csv',
    '--separate_val_path', temp_datapath + 'test_1.csv',
    '--separate_test_path', temp_datapath + 'test_1.csv',
    '--save_preds',
    '--metric', 'prc-auc',
    '--epochs', '100',
    '--gpu', '0',
    '--save_dir', temp_datapath + 'checkpoint',
    '--features_generator', 'rdkit_2d_normalized',
    '--no_features_scaling'
]

# %%
param_dict = {
    '--depth': ['3', '4', '5', '6'],
    '--dropout': ['0.0', '0.2', '0.3', '0.5', '0.7'],
    '--ffn_hidden_size': ['600', '1200', '2400', '3600'],
    '--ffn_num_layers': ['1', '2', '3'],
    '--hidden_size': ['600', '1200', '2400', '3600']
}

# %%
from copy import copy
from tqdm import tqdm
from sklearn.model_selection import ParameterSampler

hyperparam_list = list(ParameterSampler(param_dict, n_iter=20))

best_score = 0.0
best_hyperparams = None

for i, hyperparam in tqdm(enumerate(hyperparam_list)):
    print('HYPERPARAMETER', i)
    print(hyperparam)
    result_arguments = copy(base_arguments)
    for key, value in hyperparam.items():
        result_arguments.append(key)
        result_arguments.append(value)
    # Train
    args = chemprop.args.TrainArgs().parse_args(result_arguments)
    mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)

    test_preds = pd.read_csv(temp_datapath + 'checkpoint/test_preds.csv')
    metrics = get_hi_metrics(test, test_preds['targets'].to_list())

    score = metrics['prc_auc']
    if score > best_score:
        print('New best PRC AUC:', score)
        best_score = score
        best_hyperparams = hyperparam
# Out:
# 0it [00:00, ?it/s]Command line
# python /home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/ipykernel_launcher.py --ip=127.0.0.1 --stdin=9003 --control=9001 --hb=9000 --Session.signature_scheme="hmac-sha256" --Session.key=b"d5b0fee2-9f68-4872-9f25-d0fd39dd4883" --shell=9002 --transport="tcp" --iopub=9004 --f=/home/simon/.local/share/jupyter/runtime/kernel-v2-48783Ee3ZnGwS7bEj.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': True,
#  'data_path': '/tmp/chemprop/train_1.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 5,
#  'depth_solvent': 3,
#  'device': device(type='cuda', index=0),
#  'dropout': 0.3,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 100,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': ['rdkit_2d_normalized'],
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': False,
#  'features_size': None,
#  'ffn_hidden_size': 1200,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': 0,
#  'grad_clip': None,
#  'hidden_size': 2400,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'prc-auc',
#  'metrics': ['prc-auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': True,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': '/tmp/chemprop/checkpoint',
#  'save_preds': True,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': '/tmp/chemprop/test_1.csv',
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': '/tmp/chemprop/test_1.csv',
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [1.0, 0.0, 0.0],
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['targets'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': True,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# HYPERPARAMETER 0
# {'--hidden_size': '2400', '--ffn_num_layers': '2', '--ffn_hidden_size': '1200', '--dropout': '0.3', '--depth': '5'}
# 500it [00:00, 417094.67it/s]
# 100%|██████████| 500/500 [00:12<00:00, 40.78it/s]
# 100%|██████████| 500/500 [00:00<00:00, 226645.63it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# 3116it [00:00, 478471.58it/s]
# 100%|██████████| 3116/3116 [01:12<00:00, 43.04it/s]
# 100%|██████████| 3116/3116 [00:00<00:00, 260300.97it/s]
# 3116it [00:00, 483802.89it/s]
# 100%|██████████| 3116/3116 [01:12<00:00, 42.78it/s]
# 100%|██████████| 3116/3116 [00:00<00:00, 252535.14it/s]
# Class sizes
# targets 0: 22.20%, 1: 77.80%
# Total size = 500 | train size = 500 | val size = 3,116 | test size = 3,116
# Building model 0
# MoleculeModel(
#   (sigmoid): Sigmoid()
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout): Dropout(p=0.3, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=2400, bias=False)
#         (W_h): Linear(in_features=2400, out_features=2400, bias=False)
#         (W_o): Linear(in_features=2533, out_features=2400, bias=True)
#       )
#     )
#   )
#   (readout): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Linear(in_features=2600, out_features=1200, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=1200, out_features=1, bias=True)
#   )
# )
# Number of parameters = 15,319,201
# Moving model to cuda
# Epoch 0
#
#
#
#
#
#
# Loss = 6.3243e-01, PNorm = 82.4509, GNorm = 0.6038, lr_0 = 5.9500e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.702159
# Epoch 1
#
#
#
#
#
# Loss = 4.6633e-01, PNorm = 82.7312, GNorm = 0.9305, lr_0 = 9.9765e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.700316
# Epoch 2
#
#
#
#
#
# Loss = 4.1082e-01, PNorm = 82.9971, GNorm = 0.5495, lr_0 = 9.7449e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.681406
# Epoch 3
#
#
#
#
#
# Loss = 3.9536e-01, PNorm = 83.1553, GNorm = 0.6140, lr_0 = 9.5186e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.680592
# Epoch 4
#
#
#
#
#
# Loss = 3.7014e-01, PNorm = 83.2699, GNorm = 0.7422, lr_0 = 9.2975e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.679832
# Epoch 5
#
#
#
#
#
# Loss = 3.5732e-01, PNorm = 83.3685, GNorm = 1.4944, lr_0 = 9.0816e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.658904
# Epoch 6
#
#
#
#
#
# Loss = 3.8535e-01, PNorm = 83.4695, GNorm = 0.5205, lr_0 = 8.8707e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.668640
# Epoch 7
#
#
#
#
#
# Loss = 3.6473e-01, PNorm = 83.5593, GNorm = 0.5092, lr_0 = 8.6647e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.663071
# Epoch 8
#
#
#
#
#
# Loss = 3.2453e-01, PNorm = 83.6533, GNorm = 0.4833, lr_0 = 8.4635e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.668662
# Epoch 9
#
#
#
#
#
# Loss = 3.0018e-01, PNorm = 83.7629, GNorm = 0.4961, lr_0 = 8.2670e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.625598
# Epoch 10
#
#
#
#
#
# Loss = 2.9621e-01, PNorm = 83.8863, GNorm = 0.5219, lr_0 = 8.0750e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.676203
# Epoch 11
#
#
#
#
#
# Loss = 2.7045e-01, PNorm = 84.0362, GNorm = 1.1825, lr_0 = 7.8875e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.631011
# Epoch 12
#
#
#
#
#
# Loss = 2.7150e-01, PNorm = 84.1873, GNorm = 1.7513, lr_0 = 7.7043e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.663747
# Epoch 13
#
#
#
#
#
# Loss = 2.5071e-01, PNorm = 84.3572, GNorm = 1.4115, lr_0 = 7.5254e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.649041
# Epoch 14
#
#
#
#
#
# Loss = 2.5660e-01, PNorm = 84.5358, GNorm = 2.3001, lr_0 = 7.3507e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.643983
# Epoch 15
#
#
#
#
#
# Loss = 2.3752e-01, PNorm = 84.7241, GNorm = 0.7987, lr_0 = 7.1800e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.676651
# Epoch 16
#
#
#
#
#
# Loss = 2.4870e-01, PNorm = 84.9078, GNorm = 1.1429, lr_0 = 7.0132e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.645437
# Epoch 17
#
#
#
#
#
# Loss = 2.2016e-01, PNorm = 85.0880, GNorm = 0.5906, lr_0 = 6.8504e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.654278
# Epoch 18
#
#
#
#
#
# Loss = 1.9019e-01, PNorm = 85.2698, GNorm = 1.3631, lr_0 = 6.6913e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.654414
# Epoch 19
#
#
#
#
#
# Loss = 2.0451e-01, PNorm = 85.4432, GNorm = 0.6303, lr_0 = 6.5359e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.649550
# Epoch 20
#
#
#
#
#
# Loss = 1.8020e-01, PNorm = 85.6240, GNorm = 0.4803, lr_0 = 6.3841e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.650314
# Epoch 21
#
#
#
#
#
# Loss = 1.6179e-01, PNorm = 85.8000, GNorm = 0.6262, lr_0 = 6.2359e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.660578
# Epoch 22
#
#
#
#
#
# Loss = 1.8268e-01, PNorm = 85.9541, GNorm = 2.0769, lr_0 = 6.0911e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.665826
# Epoch 23
#
#
#
#
#
# Loss = 1.5501e-01, PNorm = 86.1167, GNorm = 0.2595, lr_0 = 5.9496e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.644161
# Epoch 24
#
#
#
#
#
# Loss = 1.4023e-01, PNorm = 86.2666, GNorm = 0.7467, lr_0 = 5.8115e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.653528
# Epoch 25
#
#
#
#
#
# Loss = 1.3097e-01, PNorm = 86.4185, GNorm = 0.7550, lr_0 = 5.6765e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.667678
# Epoch 26
#
#
#
#
#
# Loss = 2.1263e-01, PNorm = 86.5774, GNorm = 2.3369, lr_0 = 5.5447e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.678883
# Epoch 27
#
#
#
#
#
# Loss = 1.4683e-01, PNorm = 86.7452, GNorm = 0.7850, lr_0 = 5.4159e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.658019
# Epoch 28
#
#
#
#
#
# Loss = 1.2616e-01, PNorm = 86.8792, GNorm = 0.4411, lr_0 = 5.2902e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.657613
# Epoch 29
#
#
#
#
#
# Loss = 1.4297e-01, PNorm = 86.9961, GNorm = 0.9194, lr_0 = 5.1673e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.651661
# Epoch 30
#
#
#
#
#
# Loss = 1.2125e-01, PNorm = 87.1101, GNorm = 1.5572, lr_0 = 5.0473e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.665119
# Epoch 31
#
#
#
#
#
# Loss = 1.3984e-01, PNorm = 87.2146, GNorm = 1.0021, lr_0 = 4.9301e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.668637
# Epoch 32
#
#
#
#
#
# Loss = 1.1046e-01, PNorm = 87.3241, GNorm = 0.3259, lr_0 = 4.8156e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.668378
# Epoch 33
#
#
#
#
#
# Loss = 1.0268e-01, PNorm = 87.4203, GNorm = 0.8828, lr_0 = 4.7038e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.655908
# Epoch 34
#
#
#
#
#
# Loss = 1.5074e-01, PNorm = 87.5292, GNorm = 2.2528, lr_0 = 4.5946e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.672190
# Epoch 35
#
#
#
#
#
# Loss = 1.8643e-01, PNorm = 87.6641, GNorm = 2.4097, lr_0 = 4.4879e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.654936
# Epoch 36
#
#
#
#
#
# Loss = 1.5104e-01, PNorm = 87.8050, GNorm = 0.5783, lr_0 = 4.3837e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.658704
# Epoch 37
#
#
#
#
#
# Loss = 1.1676e-01, PNorm = 87.9185, GNorm = 0.4239, lr_0 = 4.2819e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.655140
# Epoch 38
#
#
#
#
#
# Loss = 1.1201e-01, PNorm = 88.0039, GNorm = 0.3129, lr_0 = 4.1824e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.656724
# Epoch 39
#
#
#
#
#
# Loss = 9.2746e-02, PNorm = 88.0804, GNorm = 0.7338, lr_0 = 4.0853e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.675610
# Epoch 40
#
#
#
#
#
# Loss = 8.5472e-02, PNorm = 88.1543, GNorm = 0.8863, lr_0 = 3.9904e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.674728
# Epoch 41
#
#
#
#
#
# Loss = 8.6571e-02, PNorm = 88.2285, GNorm = 0.8014, lr_0 = 3.8978e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.672924
# Epoch 42
#
#
#
#
#
# Loss = 7.9439e-02, PNorm = 88.2976, GNorm = 0.7681, lr_0 = 3.8073e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.681361
# Epoch 43
#
#
#
#
#
# Loss = 8.8645e-02, PNorm = 88.3693, GNorm = 0.6842, lr_0 = 3.7188e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.672641
# Epoch 44
#
#
#
#
#
# Loss = 7.9404e-02, PNorm = 88.4409, GNorm = 0.7742, lr_0 = 3.6325e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.669180
# Epoch 45
#
#
#
#
#
# Loss = 8.5282e-02, PNorm = 88.5110, GNorm = 0.4349, lr_0 = 3.5481e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.680509
# Epoch 46
#
#
#
#
#
# Loss = 7.7594e-02, PNorm = 88.5832, GNorm = 0.9295, lr_0 = 3.4657e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.680847
# Epoch 47
#
#
#
#
#
# Loss = 6.6950e-02, PNorm = 88.6536, GNorm = 0.8608, lr_0 = 3.3853e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.683529
# Epoch 48
#
#
#
#
#
# Loss = 6.7379e-02, PNorm = 88.7189, GNorm = 0.7954, lr_0 = 3.3066e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.689644
# Epoch 49
#
#
#
#
#
# Loss = 7.0614e-02, PNorm = 88.7911, GNorm = 0.7774, lr_0 = 3.2299e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.677605
# Epoch 50
#
#
#
#
#
# Loss = 8.5963e-02, PNorm = 88.8669, GNorm = 0.2477, lr_0 = 3.1549e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.663541
# Epoch 51
#
#
#
#
#
# Loss = 5.8777e-02, PNorm = 88.9288, GNorm = 0.8126, lr_0 = 3.0816e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.674357
# Epoch 52
#
#
#
#
#
# Loss = 5.5464e-02, PNorm = 88.9805, GNorm = 0.1088, lr_0 = 3.0100e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.682057
# Epoch 53
#
#
#
#
#
# Loss = 5.6061e-02, PNorm = 89.0241, GNorm = 0.2332, lr_0 = 2.9401e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.685185
# Epoch 54
#
#
#
#
#
# Loss = 5.0234e-02, PNorm = 89.0714, GNorm = 0.3511, lr_0 = 2.8719e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.686969
# Epoch 55
#
#
#
#
#
# Loss = 5.1908e-02, PNorm = 89.1219, GNorm = 0.9056, lr_0 = 2.8052e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.685340
# Epoch 56
#
#
#
#
#
# Loss = 4.3531e-02, PNorm = 89.1665, GNorm = 0.7976, lr_0 = 2.7400e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.676935
# Epoch 57
#
#
#
#
#
# Loss = 5.2345e-02, PNorm = 89.2165, GNorm = 0.2651, lr_0 = 2.6764e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.678139
# Epoch 58
#
#
#
#
#
# Loss = 4.2666e-02, PNorm = 89.2613, GNorm = 0.3313, lr_0 = 2.6142e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.661769
# Epoch 59
#
#
#
#
#
# Loss = 4.1427e-02, PNorm = 89.3016, GNorm = 0.5964, lr_0 = 2.5535e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.665120
# Epoch 60
#
#
#
#
#
# Loss = 4.3679e-02, PNorm = 89.3375, GNorm = 0.2715, lr_0 = 2.4942e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.687653
# Epoch 61
#
#
#
#
#
# Loss = 5.3514e-02, PNorm = 89.3815, GNorm = 0.6268, lr_0 = 2.4363e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.681589
# Epoch 62
#
#
#
#
#
# Loss = 4.6311e-02, PNorm = 89.4291, GNorm = 0.9554, lr_0 = 2.3797e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.679513
# Epoch 63
#
#
#
#
#
# Loss = 3.4315e-02, PNorm = 89.4665, GNorm = 0.2483, lr_0 = 2.3245e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.676936
# Epoch 64
#
#
#
#
#
# Loss = 2.9184e-02, PNorm = 89.4962, GNorm = 0.6867, lr_0 = 2.2705e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.679541
# Epoch 65
#
#
#
#
#
# Loss = 3.0523e-02, PNorm = 89.5179, GNorm = 0.7390, lr_0 = 2.2178e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.676303
# Epoch 66
#
#
#
#
#
# Loss = 3.1621e-02, PNorm = 89.5413, GNorm = 0.3323, lr_0 = 2.1663e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.670443
# Epoch 67
#
#
#
#
#
# Loss = 3.2217e-02, PNorm = 89.5674, GNorm = 0.4093, lr_0 = 2.1160e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.668611
# Epoch 68
#
#
#
#
#
# Loss = 3.2744e-02, PNorm = 89.5950, GNorm = 0.1745, lr_0 = 2.0668e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.674283
# Epoch 69
#
#
#
#
#
# Loss = 3.5655e-02, PNorm = 89.6190, GNorm = 1.1637, lr_0 = 2.0188e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.674050
# Epoch 70
#
#
#
#
#
# Loss = 3.1299e-02, PNorm = 89.6409, GNorm = 1.4721, lr_0 = 1.9720e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.676856
# Epoch 71
#
#
#
#
#
# Loss = 2.8968e-02, PNorm = 89.6672, GNorm = 0.2681, lr_0 = 1.9262e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.676033
# Epoch 72
#
#
#
#
#
# Loss = 3.4250e-02, PNorm = 89.6929, GNorm = 0.4743, lr_0 = 1.8814e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.681587
# Epoch 73
#
#
#
#
#
# Loss = 2.3995e-02, PNorm = 89.7162, GNorm = 0.2541, lr_0 = 1.8377e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.684745
# Epoch 74
#
#
#
#
#
# Loss = 3.2572e-02, PNorm = 89.7376, GNorm = 0.2774, lr_0 = 1.7951e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.685230
# Epoch 75
#
#
#
#
#
# Loss = 2.4116e-02, PNorm = 89.7583, GNorm = 0.5846, lr_0 = 1.7534e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.688744
# Epoch 76
#
#
#
#
#
# Loss = 2.6621e-02, PNorm = 89.7777, GNorm = 0.5972, lr_0 = 1.7127e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.691551
# Epoch 77
#
#
#
#
#
# Loss = 2.2793e-02, PNorm = 89.8002, GNorm = 0.1399, lr_0 = 1.6729e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.687581
# Epoch 78
#
#
#
#
#
# Loss = 2.3893e-02, PNorm = 89.8184, GNorm = 0.8223, lr_0 = 1.6340e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.686356
# Epoch 79
#
#
#
#
#
# Loss = 2.3661e-02, PNorm = 89.8380, GNorm = 0.8781, lr_0 = 1.5961e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.687122
# Epoch 80
#
#
#
#
#
# Loss = 2.3428e-02, PNorm = 89.8589, GNorm = 1.1207, lr_0 = 1.5590e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.685666
# Epoch 81
#
#
#
#
#
# Loss = 2.1917e-02, PNorm = 89.8757, GNorm = 0.1781, lr_0 = 1.5228e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.681427
# Epoch 82
#
#
#
#
#
# Loss = 1.9921e-02, PNorm = 89.8899, GNorm = 0.8394, lr_0 = 1.4875e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.681648
# Epoch 83
#
#
#
#
#
# Loss = 1.9836e-02, PNorm = 89.9053, GNorm = 0.1027, lr_0 = 1.4529e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.678198
# Epoch 84
#
#
#
#
#
# Loss = 2.0265e-02, PNorm = 89.9178, GNorm = 1.1278, lr_0 = 1.4192e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.680358
# Epoch 85
#
#
#
#
#
# Loss = 2.1797e-02, PNorm = 89.9316, GNorm = 0.6490, lr_0 = 1.3862e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.679144
# Epoch 86
#
#
#
#
#
# Loss = 1.8183e-02, PNorm = 89.9437, GNorm = 0.0980, lr_0 = 1.3540e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.676514
# Epoch 87
#
#
#
#
#
# Loss = 1.8466e-02, PNorm = 89.9545, GNorm = 0.4901, lr_0 = 1.3226e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.676290
# Epoch 88
#
#
#
#
#
# Loss = 1.3981e-02, PNorm = 89.9673, GNorm = 0.0986, lr_0 = 1.2919e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.675651
# Epoch 89
#
#
#
#
#
# Loss = 1.6824e-02, PNorm = 89.9785, GNorm = 0.0973, lr_0 = 1.2619e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.675442
# Epoch 90
#
#
#
#
#
# Loss = 1.8987e-02, PNorm = 89.9898, GNorm = 0.4365, lr_0 = 1.2326e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.669865
# Epoch 91
#
#
#
#
#
# Loss = 2.5546e-02, PNorm = 90.0004, GNorm = 0.0388, lr_0 = 1.2040e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.680342
# Epoch 92
#
#
#
#
#
# Loss = 2.7602e-02, PNorm = 90.0171, GNorm = 1.5699, lr_0 = 1.1760e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.679367
# Epoch 93
#
#
#
#
#
# Loss = 1.7406e-02, PNorm = 90.0316, GNorm = 0.4957, lr_0 = 1.1487e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.681461
# Epoch 94
#
#
#
#
#
# Loss = 1.9897e-02, PNorm = 90.0419, GNorm = 1.2153, lr_0 = 1.1220e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.679597
# Epoch 95
#
#
#
#
#
# Loss = 1.8853e-02, PNorm = 90.0511, GNorm = 0.1013, lr_0 = 1.0960e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.679592
# Epoch 96
#
#
#
#
#
# Loss = 1.4210e-02, PNorm = 90.0583, GNorm = 0.1997, lr_0 = 1.0705e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.679918
# Epoch 97
#
#
#
#
#
# Loss = 1.7143e-02, PNorm = 90.0656, GNorm = 0.2368, lr_0 = 1.0457e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.678206
# Epoch 98
#
#
#
#
#
# Loss = 1.9401e-02, PNorm = 90.0735, GNorm = 0.6607, lr_0 = 1.0214e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.680819
# Epoch 99
#
#
#
#
#
# Loss = 1.8834e-02, PNorm = 90.0824, GNorm = 0.5436, lr_0 = 1.0000e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.678758
# 100%|██████████| 100/100 [08:04<00:00,  4.85s/it]
# Model 0 best validation prc-auc = 0.702159 on epoch 0
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
# Moving model to cuda
# Model 0 test prc-auc = 0.702159
# Ensemble test prc-auc = 0.702159
# 1-fold cross validation
# 	Seed 0 ==> test prc-auc = 0.702159
# Overall test prc-auc = 0.702159 +/- 0.000000
# Elapsed time = 0:10:47
# 1it [10:46, 646.96s/it]Command line
# python /home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/ipykernel_launcher.py --ip=127.0.0.1 --stdin=9003 --control=9001 --hb=9000 --Session.signature_scheme="hmac-sha256" --Session.key=b"d5b0fee2-9f68-4872-9f25-d0fd39dd4883" --shell=9002 --transport="tcp" --iopub=9004 --f=/home/simon/.local/share/jupyter/runtime/kernel-v2-48783Ee3ZnGwS7bEj.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': True,
#  'data_path': '/tmp/chemprop/train_1.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 5,
#  'depth_solvent': 3,
#  'device': device(type='cuda', index=0),
#  'dropout': 0.7,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 100,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': ['rdkit_2d_normalized'],
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': False,
#  'features_size': None,
#  'ffn_hidden_size': 1200,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': 0,
#  'grad_clip': None,
#  'hidden_size': 2400,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'prc-auc',
#  'metrics': ['prc-auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': True,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': '/tmp/chemprop/checkpoint',
#  'save_preds': True,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': '/tmp/chemprop/test_1.csv',
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': '/tmp/chemprop/test_1.csv',
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [1.0, 0.0, 0.0],
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['targets'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': True,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# New best PRC AUC: 0.702322029260872
# HYPERPARAMETER 1
# {'--hidden_size': '2400', '--ffn_num_layers': '2', '--ffn_hidden_size': '1200', '--dropout': '0.7', '--depth': '5'}
# Setting molecule featurization parameters to default.
# Loading data
# 500it [00:00, 280367.91it/s]
# 100%|██████████| 500/500 [00:17<00:00, 28.60it/s]
# 100%|██████████| 500/500 [00:00<00:00, 146183.74it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# 3116it [00:00, 253539.44it/s]
# 100%|██████████| 3116/3116 [01:22<00:00, 37.93it/s]
# 100%|██████████| 3116/3116 [00:00<00:00, 266033.98it/s]
# 3116it [00:00, 471685.12it/s]
# 100%|██████████| 3116/3116 [01:05<00:00, 47.38it/s]
# 100%|██████████| 3116/3116 [00:00<00:00, 268653.41it/s]
# Class sizes
# targets 0: 22.20%, 1: 77.80%
# Total size = 500 | train size = 500 | val size = 3,116 | test size = 3,116
# Building model 0
# MoleculeModel(
#   (sigmoid): Sigmoid()
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout): Dropout(p=0.7, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=2400, bias=False)
#         (W_h): Linear(in_features=2400, out_features=2400, bias=False)
#         (W_o): Linear(in_features=2533, out_features=2400, bias=True)
#       )
#     )
#   )
#   (readout): Sequential(
#     (0): Dropout(p=0.7, inplace=False)
#     (1): Linear(in_features=2600, out_features=1200, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.7, inplace=False)
#     (4): Linear(in_features=1200, out_features=1, bias=True)
#   )
# )
# Number of parameters = 15,319,201
# Moving model to cuda
# Epoch 0
#
#
#
#
#
# Loss = 8.4992e-01, PNorm = 82.4701, GNorm = 4.2972, lr_0 = 5.9500e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.688424
# Epoch 1
#
#
#
#
#
# Loss = 5.5707e-01, PNorm = 82.8032, GNorm = 2.9586, lr_0 = 9.9765e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.702723
# Epoch 2
#
#
#
#
#
# Loss = 5.0622e-01, PNorm = 83.1132, GNorm = 1.8219, lr_0 = 9.7449e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.698367
# Epoch 3
#
#
#
#
#
# Loss = 4.8479e-01, PNorm = 83.2881, GNorm = 1.6969, lr_0 = 9.5186e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.694299
# Epoch 4
#
#
#
#
#
# Loss = 4.9847e-01, PNorm = 83.3780, GNorm = 1.7350, lr_0 = 9.2975e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.690064
# Epoch 5
#
#
#
#
#
# Loss = 4.6260e-01, PNorm = 83.4329, GNorm = 1.2466, lr_0 = 9.0816e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.690336
# Epoch 6
#
#
#
#
#
# Loss = 4.5671e-01, PNorm = 83.4704, GNorm = 1.4232, lr_0 = 8.8707e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.689673
# Epoch 7
#
#
#
#
#
# Loss = 4.7014e-01, PNorm = 83.5014, GNorm = 1.1951, lr_0 = 8.6647e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.683860
# Epoch 8
#
#
#
#
#
# Loss = 4.6750e-01, PNorm = 83.5288, GNorm = 1.3755, lr_0 = 8.4635e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.677817
# Epoch 9
#
#
#
#
#
# Loss = 4.5176e-01, PNorm = 83.5568, GNorm = 1.2850, lr_0 = 8.2670e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.677393
# Epoch 10
#
#
#
#
#
# Loss = 4.2571e-01, PNorm = 83.5851, GNorm = 1.2900, lr_0 = 8.0750e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.678976
# Epoch 11
#
#
#
#
#
# Loss = 4.2460e-01, PNorm = 83.6137, GNorm = 1.2580, lr_0 = 7.8875e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.672700
# Epoch 12
#
#
#
#
#
# Loss = 4.6201e-01, PNorm = 83.6413, GNorm = 1.3968, lr_0 = 7.7043e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.669965
# Epoch 13
#
#
#
#
#
# Loss = 4.4354e-01, PNorm = 83.6703, GNorm = 1.4502, lr_0 = 7.5254e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.668843
# Epoch 14
#
#
#
#
#
# Loss = 4.3222e-01, PNorm = 83.7012, GNorm = 1.3747, lr_0 = 7.3507e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.678652
# Epoch 15
#
#
#
#
#
# Loss = 4.1461e-01, PNorm = 83.7366, GNorm = 1.2373, lr_0 = 7.1800e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.692608
# Epoch 16
#
#
#
#
#
# Loss = 4.5694e-01, PNorm = 83.7700, GNorm = 2.5739, lr_0 = 7.0132e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.677430
# Epoch 17
#
#
#
#
#
# Loss = 4.1880e-01, PNorm = 83.8071, GNorm = 1.4007, lr_0 = 6.8504e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.681670
# Epoch 18
#
#
#
#
#
# Loss = 4.0518e-01, PNorm = 83.8397, GNorm = 1.5578, lr_0 = 6.6913e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.686190
# Epoch 19
#
#
#
#
#
# Loss = 3.8404e-01, PNorm = 83.8729, GNorm = 1.2542, lr_0 = 6.5359e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.674346
# Epoch 20
#
#
#
#
#
# Loss = 3.9394e-01, PNorm = 83.9111, GNorm = 1.3386, lr_0 = 6.3841e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.668749
# Epoch 21
#
#
#
#
#
# Loss = 3.6761e-01, PNorm = 83.9542, GNorm = 1.2252, lr_0 = 6.2359e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.667335
# Epoch 22
#
#
#
#
#
# Loss = 3.8237e-01, PNorm = 83.9954, GNorm = 1.4802, lr_0 = 6.0911e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.665204
# Epoch 23
#
#
#
#
#
# Loss = 3.5586e-01, PNorm = 84.0369, GNorm = 1.0277, lr_0 = 5.9496e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.666931
# Epoch 24
#
#
#
#
#
# Loss = 3.4312e-01, PNorm = 84.0797, GNorm = 1.2017, lr_0 = 5.8115e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.649575
# Epoch 25
#
#
#
#
#
# Loss = 3.3842e-01, PNorm = 84.1267, GNorm = 2.1127, lr_0 = 5.6765e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.656862
# Epoch 26
#
#
#
#
#
# Loss = 4.0285e-01, PNorm = 84.1693, GNorm = 1.2425, lr_0 = 5.5447e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.666282
# Epoch 27
#
#
#
#
#
# Loss = 3.2067e-01, PNorm = 84.2093, GNorm = 1.1896, lr_0 = 5.4159e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.661760
# Epoch 28
#
#
#
#
#
# Loss = 3.2944e-01, PNorm = 84.2491, GNorm = 1.1234, lr_0 = 5.2902e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.665657
# Epoch 29
#
#
#
#
#
# Loss = 3.2307e-01, PNorm = 84.2869, GNorm = 1.9001, lr_0 = 5.1673e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.649604
# Epoch 30
#
#
#
#
#
# Loss = 3.0589e-01, PNorm = 84.3253, GNorm = 3.5726, lr_0 = 5.0473e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.653513
# Epoch 31
#
#
#
#
#
# Loss = 3.1334e-01, PNorm = 84.3610, GNorm = 2.6144, lr_0 = 4.9301e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.666523
# Epoch 32
#
#
#
#
#
# Loss = 3.3064e-01, PNorm = 84.3978, GNorm = 1.1642, lr_0 = 4.8156e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.661415
# Epoch 33
#
#
#
#
#
# Loss = 3.1580e-01, PNorm = 84.4320, GNorm = 1.0859, lr_0 = 4.7038e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.640054
# Epoch 34
#
#
#
#
#
# Loss = 3.0012e-01, PNorm = 84.4654, GNorm = 2.5082, lr_0 = 4.5946e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.626106
# Epoch 35
#
#
#
#
#
# Loss = 2.8309e-01, PNorm = 84.4959, GNorm = 2.3217, lr_0 = 4.4879e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.632121
# Epoch 36
#
#
#
#
#
# Loss = 3.0520e-01, PNorm = 84.5218, GNorm = 1.2878, lr_0 = 4.3837e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.629193
# Epoch 37
#
#
#
#
#
# Loss = 3.0165e-01, PNorm = 84.5526, GNorm = 0.9748, lr_0 = 4.2819e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.647744
# Epoch 38
#
#
#
#
#
# Loss = 2.6696e-01, PNorm = 84.5853, GNorm = 1.6840, lr_0 = 4.1824e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.639762
# Epoch 39
#
#
#
#
#
# Loss = 2.5807e-01, PNorm = 84.6110, GNorm = 1.2472, lr_0 = 4.0853e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.637839
# Epoch 40
#
#
#
#
#
# Loss = 2.5852e-01, PNorm = 84.6370, GNorm = 2.3309, lr_0 = 3.9904e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.645539
# Epoch 41
#
#
#
#
#
# Loss = 2.4438e-01, PNorm = 84.6629, GNorm = 1.5191, lr_0 = 3.8978e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.639805
# Epoch 42
#
#
#
#
#
# Loss = 2.4451e-01, PNorm = 84.6887, GNorm = 1.5070, lr_0 = 3.8073e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.642921
# Epoch 43
#
#
#
#
#
# Loss = 2.6101e-01, PNorm = 84.7123, GNorm = 1.7197, lr_0 = 3.7188e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.656612
# Epoch 44
#
#
#
#
#
# Loss = 2.4903e-01, PNorm = 84.7350, GNorm = 1.8409, lr_0 = 3.6325e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.642301
# Epoch 45
#
#
#
#
#
# Loss = 2.7205e-01, PNorm = 84.7543, GNorm = 2.8269, lr_0 = 3.5481e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.656125
# Epoch 46
#
#
#
#
#
# Loss = 2.2603e-01, PNorm = 84.7780, GNorm = 1.1159, lr_0 = 3.4657e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.659092
# Epoch 47
#
#
#
#
#
# Loss = 2.3655e-01, PNorm = 84.8009, GNorm = 3.1892, lr_0 = 3.3853e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.660063
# Epoch 48
#
#
#
#
#
# Loss = 2.1982e-01, PNorm = 84.8207, GNorm = 1.1749, lr_0 = 3.3066e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.657860
# Epoch 49
#
#
#
#
#
# Loss = 2.3324e-01, PNorm = 84.8442, GNorm = 0.7597, lr_0 = 3.2299e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.663447
# Epoch 50
#
#
#
#
#
# Loss = 2.2205e-01, PNorm = 84.8643, GNorm = 1.2644, lr_0 = 3.1549e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.670360
# Epoch 51
#
#
#
#
#
# Loss = 2.1881e-01, PNorm = 84.8836, GNorm = 1.3329, lr_0 = 3.0816e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.670695
# Epoch 52
#
#
#
#
#
# Loss = 2.3439e-01, PNorm = 84.9033, GNorm = 2.3944, lr_0 = 3.0100e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.659731
# Epoch 53
#
#
#
#
#
# Loss = 2.2597e-01, PNorm = 84.9246, GNorm = 2.3843, lr_0 = 2.9401e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.646228
# Epoch 54
#
#
#
#
#
# Loss = 2.3584e-01, PNorm = 84.9435, GNorm = 1.1317, lr_0 = 2.8719e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.660221
# Epoch 55
#
#
#
#
#
# Loss = 2.1101e-01, PNorm = 84.9645, GNorm = 1.0878, lr_0 = 2.8052e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.670615
# Epoch 56
#
#
#
#
#
# Loss = 2.1470e-01, PNorm = 84.9827, GNorm = 1.2571, lr_0 = 2.7400e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.662560
# Epoch 57
#
#
#
#
#
# Loss = 2.1612e-01, PNorm = 84.9993, GNorm = 1.3786, lr_0 = 2.6764e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.666048
# Epoch 58
#
#
#
#
#
# Loss = 2.3068e-01, PNorm = 85.0155, GNorm = 1.9784, lr_0 = 2.6142e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.652450
# Epoch 59
#
#
#
#
#
# Loss = 1.9540e-01, PNorm = 85.0331, GNorm = 0.9712, lr_0 = 2.5535e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.654383
# Epoch 60
#
#
#
#
#
# Loss = 1.9527e-01, PNorm = 85.0484, GNorm = 1.6917, lr_0 = 2.4942e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.666958
# Epoch 61
#
#
#
#
#
# Loss = 2.2475e-01, PNorm = 85.0637, GNorm = 0.8548, lr_0 = 2.4363e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.678799
# Epoch 62
#
#
#
#
#
# Loss = 2.4286e-01, PNorm = 85.0797, GNorm = 2.1631, lr_0 = 2.3797e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.666896
# Epoch 63
#
#
#
#
#
# Loss = 2.0942e-01, PNorm = 85.0947, GNorm = 1.6132, lr_0 = 2.3245e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.660672
# Epoch 64
#
#
#
#
#
# Loss = 2.0521e-01, PNorm = 85.1102, GNorm = 1.3624, lr_0 = 2.2705e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.658999
# Epoch 65
#
#
#
#
#
# Loss = 1.9392e-01, PNorm = 85.1234, GNorm = 1.9926, lr_0 = 2.2178e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.652914
# Epoch 66
#
#
#
#
#
# Loss = 1.9166e-01, PNorm = 85.1344, GNorm = 1.9359, lr_0 = 2.1663e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.651921
# Epoch 67
#
#
#
#
#
# Loss = 1.8250e-01, PNorm = 85.1474, GNorm = 0.9532, lr_0 = 2.1160e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.660958
# Epoch 68
#
#
#
#
#
# Loss = 1.9519e-01, PNorm = 85.1577, GNorm = 1.2981, lr_0 = 2.0668e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.662750
# Epoch 69
#
#
#
#
#
# Loss = 1.8476e-01, PNorm = 85.1692, GNorm = 3.3640, lr_0 = 2.0188e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.660706
# Epoch 70
#
#
#
#
#
# Loss = 1.9063e-01, PNorm = 85.1798, GNorm = 2.6523, lr_0 = 1.9720e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.668964
# Epoch 71
#
#
#
#
#
# Loss = 1.6764e-01, PNorm = 85.1921, GNorm = 3.1970, lr_0 = 1.9262e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.670450
# Epoch 72
#
#
#
#
#
# Loss = 1.6929e-01, PNorm = 85.2037, GNorm = 1.5647, lr_0 = 1.8814e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.672617
# Epoch 73
#
#
#
#
#
# Loss = 1.9236e-01, PNorm = 85.2140, GNorm = 1.5651, lr_0 = 1.8377e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.676480
# Epoch 74
#
#
#
#
#
# Loss = 1.7968e-01, PNorm = 85.2247, GNorm = 1.2556, lr_0 = 1.7951e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.682379
# Epoch 75
#
#
#
#
#
# Loss = 1.9052e-01, PNorm = 85.2341, GNorm = 0.8870, lr_0 = 1.7534e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.679323
# Epoch 76
#
#
#
#
#
# Loss = 1.9147e-01, PNorm = 85.2446, GNorm = 2.3575, lr_0 = 1.7127e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.672461
# Epoch 77
#
#
#
#
#
# Loss = 1.7889e-01, PNorm = 85.2544, GNorm = 1.1984, lr_0 = 1.6729e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.677054
# Epoch 78
#
#
#
#
#
# Loss = 1.7514e-01, PNorm = 85.2625, GNorm = 1.4042, lr_0 = 1.6340e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.682027
# Epoch 79
#
#
#
#
#
# Loss = 1.7993e-01, PNorm = 85.2713, GNorm = 1.0084, lr_0 = 1.5961e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.676864
# Epoch 80
#
#
#
#
#
# Loss = 1.7762e-01, PNorm = 85.2801, GNorm = 2.3392, lr_0 = 1.5590e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.674761
# Epoch 81
#
#
#
#
#
# Loss = 1.6839e-01, PNorm = 85.2873, GNorm = 1.7951, lr_0 = 1.5228e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.677583
# Epoch 82
#
#
#
#
#
# Loss = 1.7820e-01, PNorm = 85.2943, GNorm = 2.1666, lr_0 = 1.4875e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.670370
# Epoch 83
#
#
#
#
#
# Loss = 1.5625e-01, PNorm = 85.3023, GNorm = 1.3902, lr_0 = 1.4529e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.668649
# Epoch 84
#
#
#
#
#
# Loss = 1.6214e-01, PNorm = 85.3099, GNorm = 1.3556, lr_0 = 1.4192e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.677252
# Epoch 85
#
#
#
#
#
# Loss = 1.7888e-01, PNorm = 85.3182, GNorm = 2.3381, lr_0 = 1.3862e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.677671
# Epoch 86
#
#
#
#
#
# Loss = 1.7025e-01, PNorm = 85.3254, GNorm = 2.3392, lr_0 = 1.3540e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.678708
# Epoch 87
#
#
#
#
#
# Loss = 1.6779e-01, PNorm = 85.3315, GNorm = 0.9959, lr_0 = 1.3226e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.678812
# Epoch 88
#
#
#
#
#
# Loss = 1.5898e-01, PNorm = 85.3374, GNorm = 1.7413, lr_0 = 1.2919e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.674848
# Epoch 89
#
#
#
#
#
# Loss = 1.6021e-01, PNorm = 85.3432, GNorm = 2.8232, lr_0 = 1.2619e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.671093
# Epoch 90
#
#
#
#
#
# Loss = 1.6674e-01, PNorm = 85.3489, GNorm = 2.9991, lr_0 = 1.2326e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.669715
# Epoch 91
#
#
#
#
#
# Loss = 1.7093e-01, PNorm = 85.3536, GNorm = 1.2782, lr_0 = 1.2040e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.673641
# Epoch 92
#
#
#
#
#
# Loss = 1.4849e-01, PNorm = 85.3593, GNorm = 1.0971, lr_0 = 1.1760e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.671937
# Epoch 93
#
#
#
#
#
# Loss = 1.8231e-01, PNorm = 85.3636, GNorm = 2.2738, lr_0 = 1.1487e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.669098
# Epoch 94
#
#
#
#
#
# Loss = 1.7428e-01, PNorm = 85.3690, GNorm = 4.5236, lr_0 = 1.1220e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.670327
# Epoch 95
#
#
#
#
#
# Loss = 1.7167e-01, PNorm = 85.3745, GNorm = 1.1953, lr_0 = 1.0960e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.668269
# Epoch 96
#
#
#
#
#
# Loss = 1.6233e-01, PNorm = 85.3800, GNorm = 1.3610, lr_0 = 1.0705e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.669260
# Epoch 97
#
#
#
#
#
# Loss = 1.7127e-01, PNorm = 85.3846, GNorm = 1.0388, lr_0 = 1.0457e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.670272
# Epoch 98
#
#
#
#
#
# Loss = 1.7370e-01, PNorm = 85.3888, GNorm = 1.5814, lr_0 = 1.0214e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.673671
# Epoch 99
#
#
#
#
#
# Loss = 1.5936e-01, PNorm = 85.3929, GNorm = 0.9549, lr_0 = 1.0000e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.675937
# 100%|██████████| 100/100 [07:29<00:00,  4.49s/it]
# Model 0 best validation prc-auc = 0.702723 on epoch 1
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
# Moving model to cuda
# Model 0 test prc-auc = 0.702723
# Ensemble test prc-auc = 0.702723
# 1-fold cross validation
# 	Seed 0 ==> test prc-auc = 0.702723
# Overall test prc-auc = 0.702723 +/- 0.000000
# Elapsed time = 0:10:19
# 2it [21:05, 630.30s/it]Command line
# python /home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/ipykernel_launcher.py --ip=127.0.0.1 --stdin=9003 --control=9001 --hb=9000 --Session.signature_scheme="hmac-sha256" --Session.key=b"d5b0fee2-9f68-4872-9f25-d0fd39dd4883" --shell=9002 --transport="tcp" --iopub=9004 --f=/home/simon/.local/share/jupyter/runtime/kernel-v2-48783Ee3ZnGwS7bEj.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': True,
#  'data_path': '/tmp/chemprop/train_1.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 6,
#  'depth_solvent': 3,
#  'device': device(type='cuda', index=0),
#  'dropout': 0.3,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 100,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': ['rdkit_2d_normalized'],
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': False,
#  'features_size': None,
#  'ffn_hidden_size': 2400,
#  'ffn_num_layers': 3,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': 0,
#  'grad_clip': None,
#  'hidden_size': 3600,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'prc-auc',
#  'metrics': ['prc-auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': True,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': '/tmp/chemprop/checkpoint',
#  'save_preds': True,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': '/tmp/chemprop/test_1.csv',
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': '/tmp/chemprop/test_1.csv',
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [1.0, 0.0, 0.0],
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['targets'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': True,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# New best PRC AUC: 0.7028840257350342
# HYPERPARAMETER 2
# {'--hidden_size': '3600', '--ffn_num_layers': '3', '--ffn_hidden_size': '2400', '--dropout': '0.3', '--depth': '6'}
# 500it [00:00, 310321.40it/s]
# 100%|██████████| 500/500 [00:11<00:00, 42.86it/s]
# 100%|██████████| 500/500 [00:00<00:00, 249008.79it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# 3116it [00:00, 474924.64it/s]
# 100%|██████████| 3116/3116 [01:07<00:00, 45.87it/s]
# 100%|██████████| 3116/3116 [00:00<00:00, 257080.36it/s]
# 3116it [00:00, 479700.91it/s]
# 100%|██████████| 3116/3116 [01:05<00:00, 47.39it/s]
# 100%|██████████| 3116/3116 [00:00<00:00, 256837.86it/s]
# Class sizes
# targets 0: 22.20%, 1: 77.80%
# Total size = 500 | train size = 500 | val size = 3,116 | test size = 3,116
# Building model 0
# MoleculeModel(
#   (sigmoid): Sigmoid()
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout): Dropout(p=0.3, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=3600, bias=False)
#         (W_h): Linear(in_features=3600, out_features=3600, bias=False)
#         (W_o): Linear(in_features=3733, out_features=3600, bias=True)
#       )
#     )
#   )
#   (readout): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Linear(in_features=3800, out_features=2400, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=2400, out_features=2400, bias=True)
#     (5): ReLU()
#     (6): Dropout(p=0.3, inplace=False)
#     (7): Linear(in_features=2400, out_features=1, bias=True)
#   )
# )
# Number of parameters = 41,822,401
# Moving model to cuda
# Epoch 0
#
#
#
#
#
#
#
#
#
#
# ...
# Fold 0
# Splitting data with seed 0
# 3116it [00:00, 252228.10it/s]
# 100%|██████████| 3116/3116 [01:53<00:00, 27.46it/s]
# 100%|██████████| 3116/3116 [00:00<00:00, 247804.39it/s]
# 3116it [00:00, 433322.88it/s]
# 100%|██████████| 3116/3116 [01:13<00:00, 42.52it/s]
# 100%|██████████| 3116/3116 [00:00<00:00, 246244.96it/s]
# Class sizes
# targets 0: 22.20%, 1: 77.80%
# Total size = 500 | train size = 500 | val size = 3,116 | test size = 3,116
# Building model 0
# MoleculeModel(
#   (sigmoid): Sigmoid()
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout): Dropout(p=0.3, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=1200, bias=False)
#         (W_h): Linear(in_features=1200, out_features=1200, bias=False)
#         (W_o): Linear(in_features=1333, out_features=1200, bias=True)
#       )
#     )
#   )
#   (readout): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Linear(in_features=1400, out_features=1200, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=1200, out_features=1, bias=True)
#   )
# )
# Number of parameters = 4,900,801
# Moving model to cuda
# Epoch 0
#
#
#
#
# Loss = 6.0558e-01, PNorm = 63.4254, GNorm = 1.1332, lr_0 = 5.9500e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.707286
# Epoch 1
#
#
#
#
# Loss = 4.6738e-01, PNorm = 63.5495, GNorm = 1.2005, lr_0 = 9.9765e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.689797
# Epoch 2
#
#
#
#
# Loss = 4.1662e-01, PNorm = 63.6903, GNorm = 0.8201, lr_0 = 9.7449e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.671198
# Epoch 3
#
#
#
#
# Loss = 3.8424e-01, PNorm = 63.7867, GNorm = 0.6782, lr_0 = 9.5186e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.671829
# Epoch 4
#
#
#
#
# Loss = 3.5360e-01, PNorm = 63.8566, GNorm = 0.7332, lr_0 = 9.2975e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.664405
# Epoch 5
#
#
#
#
# Loss = 3.6342e-01, PNorm = 63.9185, GNorm = 0.4812, lr_0 = 9.0816e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.662543
# Epoch 6
#
#
#
#
# Loss = 3.7680e-01, PNorm = 63.9805, GNorm = 0.5543, lr_0 = 8.8707e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.659238
# Epoch 7
#
#
#
#
# Loss = 3.6909e-01, PNorm = 64.0376, GNorm = 0.4858, lr_0 = 8.6647e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.659264
# Epoch 8
#
#
#
#
# Loss = 3.3182e-01, PNorm = 64.0957, GNorm = 0.5875, lr_0 = 8.4635e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.670543
# Epoch 9
#
#
#
#
# Loss = 3.2161e-01, PNorm = 64.1587, GNorm = 0.5796, lr_0 = 8.2670e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.663448
# Epoch 10
#
#
#
#
# Loss = 3.1791e-01, PNorm = 64.2427, GNorm = 0.4452, lr_0 = 8.0750e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.664828
# Epoch 11
#
#
#
#
# Loss = 2.7996e-01, PNorm = 64.3384, GNorm = 0.5179, lr_0 = 7.8875e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.636776
# Epoch 12
#
#
#
#
# Loss = 2.9222e-01, PNorm = 64.4303, GNorm = 0.9768, lr_0 = 7.7043e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.640275
# Epoch 13
#
#
#
#
# Loss = 2.7913e-01, PNorm = 64.5238, GNorm = 0.8907, lr_0 = 7.5254e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.631959
# Epoch 14
#
#
#
#
# Loss = 2.7177e-01, PNorm = 64.6188, GNorm = 0.7520, lr_0 = 7.3507e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.638650
# Epoch 15
#
#
#
#
# Loss = 2.6224e-01, PNorm = 64.7076, GNorm = 0.8728, lr_0 = 7.1800e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.642533
# Epoch 16
#
#
#
#
# Loss = 2.5240e-01, PNorm = 64.7886, GNorm = 0.5940, lr_0 = 7.0132e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.646463
# Epoch 17
#
#
#
#
# Loss = 3.0261e-01, PNorm = 64.8700, GNorm = 1.0297, lr_0 = 6.8504e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.653290
# Epoch 18
#
#
#
#
# Loss = 2.8117e-01, PNorm = 64.9492, GNorm = 1.8310, lr_0 = 6.6913e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.655151
# Epoch 19
#
#
#
#
# Loss = 2.4089e-01, PNorm = 65.0305, GNorm = 0.4609, lr_0 = 6.5359e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.641845
# Epoch 20
#
#
#
#
# Loss = 2.5772e-01, PNorm = 65.1234, GNorm = 0.4452, lr_0 = 6.3841e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.646852
# Epoch 21
#
#
#
#
# Loss = 2.1731e-01, PNorm = 65.2196, GNorm = 0.9449, lr_0 = 6.2359e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.632403
# Epoch 22
#
#
#
#
# Loss = 2.2926e-01, PNorm = 65.3095, GNorm = 1.3315, lr_0 = 6.0911e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.655024
# Epoch 23
#
#
#
#
# Loss = 2.3271e-01, PNorm = 65.3939, GNorm = 0.2773, lr_0 = 5.9496e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.653856
# Epoch 24
#
#
#
#
# Loss = 2.3353e-01, PNorm = 65.4734, GNorm = 0.6326, lr_0 = 5.8115e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.642875
# Epoch 25
#
#
#
#
# Loss = 2.4066e-01, PNorm = 65.5661, GNorm = 2.3300, lr_0 = 5.6765e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.641239
# Epoch 26
#
#
#
#
# Loss = 2.1190e-01, PNorm = 65.6571, GNorm = 0.4660, lr_0 = 5.5447e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.655196
# Epoch 27
#
#
#
#
# Loss = 1.9708e-01, PNorm = 65.7461, GNorm = 0.5374, lr_0 = 5.4159e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.646829
# Epoch 28
#
#
#
#
# Loss = 1.9190e-01, PNorm = 65.8337, GNorm = 1.3886, lr_0 = 5.2902e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.651990
# Epoch 29
#
#
#
#
# Loss = 1.8667e-01, PNorm = 65.9171, GNorm = 1.3613, lr_0 = 5.1673e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.652056
# Epoch 30
#
#
#
#
# Loss = 1.7869e-01, PNorm = 65.9955, GNorm = 1.7945, lr_0 = 5.0473e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.652455
# Epoch 31
#
#
#
#
# Loss = 1.6662e-01, PNorm = 66.0745, GNorm = 1.0733, lr_0 = 4.9301e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.656968
# Epoch 32
#
#
#
#
# Loss = 1.5562e-01, PNorm = 66.1562, GNorm = 0.6154, lr_0 = 4.8156e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.655352
# Epoch 33
#
#
#
#
# Loss = 1.8541e-01, PNorm = 66.2164, GNorm = 0.9276, lr_0 = 4.7038e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.637356
# Epoch 34
#
#
#
#
# Loss = 1.8307e-01, PNorm = 66.2811, GNorm = 3.1845, lr_0 = 4.5946e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.651103
# Epoch 35
#
#
#
#
# Loss = 1.8324e-01, PNorm = 66.3531, GNorm = 2.1260, lr_0 = 4.4879e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.644849
# Epoch 36
#
#
#
#
# Loss = 1.9812e-01, PNorm = 66.4179, GNorm = 0.4721, lr_0 = 4.3837e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.640506
# Epoch 37
#
#
#
#
# Loss = 1.5335e-01, PNorm = 66.4964, GNorm = 0.6526, lr_0 = 4.2819e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.658681
# Epoch 38
#
#
#
#
# Loss = 1.4431e-01, PNorm = 66.5654, GNorm = 0.7143, lr_0 = 4.1824e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.653988
# Epoch 39
#
#
#
#
# Loss = 1.2158e-01, PNorm = 66.6273, GNorm = 1.5494, lr_0 = 4.0853e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.635021
# Epoch 40
#
#
#
#
# Loss = 1.1883e-01, PNorm = 66.6881, GNorm = 0.7687, lr_0 = 3.9904e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.644926
# Epoch 41
#
#
#
#
# Loss = 1.1377e-01, PNorm = 66.7415, GNorm = 0.8057, lr_0 = 3.8978e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.655744
# Epoch 42
#
#
#
#
# Loss = 1.1275e-01, PNorm = 66.7937, GNorm = 1.4538, lr_0 = 3.8073e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.695830
# Epoch 43
#
#
#
#
# Loss = 1.8474e-01, PNorm = 66.8510, GNorm = 0.7041, lr_0 = 3.7188e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.684182
# Epoch 44
#
#
#
#
# Loss = 1.2092e-01, PNorm = 66.9083, GNorm = 0.5421, lr_0 = 3.6325e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.654335
# Epoch 45
#
#
#
#
# Loss = 1.1652e-01, PNorm = 66.9674, GNorm = 0.4884, lr_0 = 3.5481e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.653331
# Epoch 46
#
#
#
#
# Loss = 9.9046e-02, PNorm = 67.0182, GNorm = 1.5550, lr_0 = 3.4657e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.645746
# Epoch 47
#
#
#
#
# Loss = 9.3540e-02, PNorm = 67.0620, GNorm = 1.4725, lr_0 = 3.3853e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.647543
# Epoch 48
#
#
#
#
# Loss = 1.0164e-01, PNorm = 67.1058, GNorm = 1.6409, lr_0 = 3.3066e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.653559
# Epoch 49
#
#
#
#
#
# Loss = 9.1872e-02, PNorm = 67.1474, GNorm = 0.9027, lr_0 = 3.2299e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.671390
# Epoch 50
#
#
#
#
#
# Loss = 9.5960e-02, PNorm = 67.1851, GNorm = 0.9758, lr_0 = 3.1549e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.674547
# Epoch 51
#
#
#
#
#
# Loss = 8.5450e-02, PNorm = 67.2230, GNorm = 0.4876, lr_0 = 3.0816e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.689815
# Epoch 52
#
#
#
#
#
# Loss = 7.6157e-02, PNorm = 67.2568, GNorm = 0.4086, lr_0 = 3.0100e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.702874
# Epoch 53
#
#
#
#
#
# Loss = 7.2840e-02, PNorm = 67.2898, GNorm = 0.6247, lr_0 = 2.9401e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.687563
# Epoch 54
#
#
#
#
#
# Loss = 9.8833e-02, PNorm = 67.3346, GNorm = 1.9972, lr_0 = 2.8719e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.677450
# Epoch 55
#
#
#
#
#
# Loss = 8.0314e-02, PNorm = 67.3753, GNorm = 0.9835, lr_0 = 2.8052e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.682990
# Epoch 56
#
#
#
#
#
# Loss = 7.3764e-02, PNorm = 67.4109, GNorm = 1.2188, lr_0 = 2.7400e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.663296
# Epoch 57
#
#
#
#
#
# Loss = 8.3798e-02, PNorm = 67.4482, GNorm = 0.3868, lr_0 = 2.6764e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.677174
# Epoch 58
#
#
#
#
#
# Loss = 7.0186e-02, PNorm = 67.4844, GNorm = 0.4813, lr_0 = 2.6142e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.656656
# Epoch 59
#
#
#
#
#
# Loss = 7.1164e-02, PNorm = 67.5166, GNorm = 0.5216, lr_0 = 2.5535e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.653848
# Epoch 60
#
#
#
#
#
# Loss = 6.7572e-02, PNorm = 67.5433, GNorm = 0.5862, lr_0 = 2.4942e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.681241
# Epoch 61
#
#
#
#
#
# Loss = 8.9870e-02, PNorm = 67.5702, GNorm = 0.5770, lr_0 = 2.4363e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.699740
# Epoch 62
#
#
#
#
#
# Loss = 9.6424e-02, PNorm = 67.5988, GNorm = 1.0219, lr_0 = 2.3797e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.685789
# Epoch 63
#
#
#
#
#
# Loss = 8.0729e-02, PNorm = 67.6292, GNorm = 0.8361, lr_0 = 2.3245e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.676664
# Epoch 64
#
#
#
#
#
# Loss = 6.9265e-02, PNorm = 67.6597, GNorm = 0.8823, lr_0 = 2.2705e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.682673
# Epoch 65
#
#
#
#
#
# Loss = 5.3877e-02, PNorm = 67.6848, GNorm = 0.6981, lr_0 = 2.2178e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.672076
# Epoch 66
#
#
#
#
#
# Loss = 6.5780e-02, PNorm = 67.7100, GNorm = 2.4237, lr_0 = 2.1663e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.675638
# Epoch 67
#
#
#
#
# Loss = 5.5141e-02, PNorm = 67.7362, GNorm = 0.8417, lr_0 = 2.1160e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.679858
# Epoch 68
#
#
#
#
# Loss = 5.5563e-02, PNorm = 67.7565, GNorm = 0.5656, lr_0 = 2.0668e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.689066
# Epoch 69
#
#
#
#
# Loss = 5.3600e-02, PNorm = 67.7775, GNorm = 1.4219, lr_0 = 2.0188e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.685167
# Epoch 70
#
#
#
#
# Loss = 7.3188e-02, PNorm = 67.7970, GNorm = 2.2884, lr_0 = 1.9720e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.685639
# Epoch 71
#
#
#
#
# Loss = 6.0224e-02, PNorm = 67.8178, GNorm = 0.7543, lr_0 = 1.9262e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.682132
# Epoch 72
#
#
#
#
# Loss = 4.6644e-02, PNorm = 67.8393, GNorm = 0.4865, lr_0 = 1.8814e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.694921
# Epoch 73
#
#
#
#
# Loss = 4.7879e-02, PNorm = 67.8546, GNorm = 0.3486, lr_0 = 1.8377e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.695793
# Epoch 74
#
#
#
#
# Loss = 4.9079e-02, PNorm = 67.8715, GNorm = 0.2193, lr_0 = 1.7951e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.693684
# Epoch 75
#
#
#
#
# Loss = 4.5249e-02, PNorm = 67.8854, GNorm = 0.1969, lr_0 = 1.7534e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.687594
# Epoch 76
#
#
#
#
# Loss = 3.8627e-02, PNorm = 67.8982, GNorm = 0.5271, lr_0 = 1.7127e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.688105
# Epoch 77
#
#
#
#
# Loss = 4.3701e-02, PNorm = 67.9127, GNorm = 0.8387, lr_0 = 1.6729e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.691230
# Epoch 78
#
#
#
#
# Loss = 4.4442e-02, PNorm = 67.9265, GNorm = 0.6910, lr_0 = 1.6340e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.693008
# Epoch 79
#
#
#
#
# Loss = 6.2968e-02, PNorm = 67.9431, GNorm = 1.4143, lr_0 = 1.5961e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.697903
# Epoch 80
#
#
#
#
# Loss = 4.9245e-02, PNorm = 67.9579, GNorm = 0.8443, lr_0 = 1.5590e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.691253
# Epoch 81
#
#
#
#
# Loss = 5.0798e-02, PNorm = 67.9697, GNorm = 0.9991, lr_0 = 1.5228e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.695802
# Epoch 82
#
#
#
#
# Loss = 5.2821e-02, PNorm = 67.9835, GNorm = 0.2622, lr_0 = 1.4875e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.690371
# Epoch 83
#
#
#
#
# Loss = 4.7347e-02, PNorm = 67.9948, GNorm = 0.7433, lr_0 = 1.4529e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.681177
# Epoch 84
#
#
#
#
# Loss = 3.9691e-02, PNorm = 68.0070, GNorm = 0.6113, lr_0 = 1.4192e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.687718
# Epoch 85
#
#
#
#
# Loss = 3.6892e-02, PNorm = 68.0189, GNorm = 0.7716, lr_0 = 1.3862e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.689754
# Epoch 86
#
#
#
#
# Loss = 5.2169e-02, PNorm = 68.0282, GNorm = 0.9341, lr_0 = 1.3540e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.689646
# Epoch 87
#
#
#
#
# Loss = 3.4734e-02, PNorm = 68.0389, GNorm = 0.6289, lr_0 = 1.3226e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.687725
# Epoch 88
#
#
#
#
# Loss = 3.7105e-02, PNorm = 68.0478, GNorm = 0.7725, lr_0 = 1.2919e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.689746
# Epoch 89
#
#
#
#
# Loss = 3.5850e-02, PNorm = 68.0584, GNorm = 0.6743, lr_0 = 1.2619e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.691311
# Epoch 90
#
#
#
#
# Loss = 3.2555e-02, PNorm = 68.0677, GNorm = 0.9955, lr_0 = 1.2326e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.691675
# Epoch 91
#
#
#
#
#
# Loss = 2.7521e-02, PNorm = 68.0754, GNorm = 0.6201, lr_0 = 1.2040e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.692216
# Epoch 92
#
#
#
#
#
# Loss = 4.0729e-02, PNorm = 68.0837, GNorm = 0.0472, lr_0 = 1.1760e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.692367
# Epoch 93
#
#
#
#
#
# Loss = 3.3156e-02, PNorm = 68.0922, GNorm = 0.8813, lr_0 = 1.1487e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.691934
# Epoch 94
#
#
#
#
#
# Loss = 4.7266e-02, PNorm = 68.1011, GNorm = 1.7445, lr_0 = 1.1220e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.696594
# Epoch 95
#
#
#
#
#
# Loss = 3.3847e-02, PNorm = 68.1096, GNorm = 0.2182, lr_0 = 1.0960e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.689028
# Epoch 96
#
#
#
#
#
# Loss = 3.4730e-02, PNorm = 68.1176, GNorm = 0.1333, lr_0 = 1.0705e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.692799
# Epoch 97
#
#
#
#
#
# Loss = 3.6158e-02, PNorm = 68.1257, GNorm = 0.3660, lr_0 = 1.0457e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.692166
# Epoch 98
#
#
#
#
#
# Loss = 2.6740e-02, PNorm = 68.1344, GNorm = 0.2870, lr_0 = 1.0214e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.685036
# Epoch 99
#
#
#
#
#
# Loss = 3.3606e-02, PNorm = 68.1436, GNorm = 0.7987, lr_0 = 1.0000e-04
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Validation prc-auc = 0.696093
# 100%|██████████| 100/100 [05:37<00:00,  3.38s/it]
# Model 0 best validation prc-auc = 0.707286 on epoch 0
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
# Moving model to cuda
# Model 0 test prc-auc = 0.707286
# Ensemble test prc-auc = 0.707286
# 1-fold cross validation
# 	Seed 0 ==> test prc-auc = 0.707286
# Overall test prc-auc = 0.707286 +/- 0.000000
# Elapsed time = 0:09:12
# 20it [3:37:08, 651.42s/it]
# New best PRC AUC: 0.7075586126299451

# %%
print(best_hyperparams)
# Out:
# {'--hidden_size': '1200', '--ffn_num_layers': '2', '--ffn_hidden_size': '1200', '--dropout': '0.3', '--depth': '5'}

# %%
print(best_score)
# Out:
# 0.7075586126299451

# %%
from copy import copy

result_arguments = copy(base_arguments)
result_arguments.extend([
    '--hidden_size', '1200',
    '--ffn_num_layers', '2',
    '--ffn_hidden_size', '1200',
    '--dropout', '0.3',
    '--depth', '4'
])

args = chemprop.args.TrainArgs().parse_args(result_arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python /home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/ipykernel_launcher.py --ip=127.0.0.1 --stdin=9003 --control=9001 --hb=9000 --Session.signature_scheme="hmac-sha256" --Session.key=b"5f7ed2af-df14-4584-88a9-9c2d0be5caca" --shell=9002 --transport="tcp" --iopub=9004 --f=/home/simon/.local/share/jupyter/runtime/kernel-v2-28351303lbL6ZQwtmM.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': True,
#  'data_path': '/tmp/chemprop/train_1.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 4,
#  'depth_solvent': 3,
#  'device': device(type='cuda', index=0),
#  'dropout': 0.3,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 100,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': ['rdkit_2d_normalized'],
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': False,
#  'features_size': None,
#  'ffn_hidden_size': 500,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': 0,
#  'grad_clip': None,
#  'hidden_size': 600,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'binary_cross_entropy',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'prc-auc',
#  'metrics': ['prc-auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': True,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': '/tmp/chemprop/checkpoint',
#  'save_preds': True,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': '/tmp/chemprop/test_1.csv',
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': '/tmp/chemprop/test_1.csv',
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [1.0, 0.0, 0.0],
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['targets'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': True,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# 500it [00:00, 410642.65it/s]
# 100%|██████████| 500/500 [00:13<00:00, 35.88it/s]
# 100%|██████████| 500/500 [00:00<00:00, 214850.12it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# 3116it [00:00, 385415.84it/s]
#  34%|███▎      | 1045/3116 [00:33<01:02, 32.88it/s]function application failed (Chi4v->COC(=O)c1ccc(-c2nnc(Nc3ccc(Cl)cc3)c3ccccc23)cc1)
# Traceback (most recent call last):
#   File "/home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/descriptastorus/descriptors/rdDescriptors.py", line 336, in applyFunc
#     return FUNCS[name](m)
#   File "/home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/rdkit/Chem/GraphDescriptors.py", line 436, in <lambda>
#     Chi4v = lambda x: rdMolDescriptors.CalcChi4v(x)
# KeyboardInterrupt
# Could not compute Chi4v for molecule
# Traceback (most recent call last):
#   File "/home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/descriptastorus/descriptors/rdNormalizedDescriptors.py", line 66, in applyNormalizedFunc
#     return cdfs[name](rdDescriptors.applyFunc(name,m))
#   File "/home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/descriptastorus/descriptors/rdNormalizedDescriptors.py", line 53, in cdf
#     v = dist.cdf(np.clip(v, minV, maxV), loc=loc, scale=scale, *arg)
#   File "<__array_function__ internals>", line 200, in clip
#   File "/home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 2180, in clip
#     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#   File "/home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 54, in _wrapfunc
#     return _wrapit(obj, method, *args, **kwds)
#   File "/home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 43, in _wrapit
#     result = getattr(asarray(obj), method)(*args, **kwds)
#   File "/home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/numpy/core/_methods.py", line 161, in _clip
#     return _clip_dep_invoke_with_casting(
#   File "/home/simon/miniconda3/envs/chemprop/lib/python3.8/site-packages/numpy/core/_methods.py", line 115, in _clip_dep_invoke_with_casting
#     return ufunc(*args, out=out, **kwargs)
# TypeError: '>=' not supported between instances of 'NoneType' and 'float'
#  52%|█████▏    | 1620/3116 [00:50<00:41, 36.13it/s]
#  52%|█████▏    | 1632/3116 [00:51<00:50, 29.45it/s]

# %%
max_epoch = 1
